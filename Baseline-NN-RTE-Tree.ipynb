# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.io import arff
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
import numpy as np
import pickle
from sklearn.metrics import accuracy_score, precision_score, recall_score
from tensorflow.keras import layers, losses
from tensorflow.keras.models import Model
from keras.callbacks import ModelCheckpoint
from sklearn.impute import KNNImputer
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import MinMaxScaler
from scipy.stats import norm
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score,f1_score,precision_score,recall_score
from sklearn.metrics import make_scorer
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomTreesEmbedding
from sklearn.decomposition import PCA
import os

# %%
path_to_directory="MDP/"
files = [arff for arff in os.listdir(path_to_directory) if arff.endswith(".arff")]

def toCsv(content): 
    data = False
    header = ""
    newContent = []
    for line in content:
        if not data:
            if "@attribute" in line:
                attri = line.split()
                columnName = attri[attri.index("@attribute")+1]
                header = header + columnName + ","
            elif "@data" in line:
                data = True
                header = header[:-1]
                header += '\n'
                newContent.append(header)
        else:
            newContent.append(line)
    return newContent

# %%
# Main loop for reading and writing files
for zzzz,file in enumerate(files):
    with open(path_to_directory+file , "r") as inFile:
        content = inFile.readlines()
        name,ext = os.path.splitext(inFile.name)
        new = toCsv(content)
        with open(name+".csv", "w") as outFile:
            outFile.writelines(new)

# %%
cm1 = pd.read_csv('MDP/CM1.csv')
kc3 = pd.read_csv('MDP/KC3.csv')
#kc4 = pd.read_csv('MDP/KC4.csv')
mc2 = pd.read_csv('MDP/MC2.csv')
mw1 = pd.read_csv('MDP/MW1.csv')
pc1 = pd.read_csv('MDP/PC1.csv')
pc2 = pd.read_csv('MDP/PC2.csv')
pc3 = pd.read_csv('MDP/PC3.csv')
pc4 = pd.read_csv('MDP/PC4.csv')
jm1 = pd.read_csv('MDP/JM1.csv')
jm1.rename(columns={"label": "Defective"}, errors="raise", inplace=True)
kc1 = pd.read_csv('MDP/KC1.csv')
mc1 = pd.read_csv('MDP/MC1.csv')
pc5 = pd.read_csv('MDP/PC5.csv')

ar1 = pd.read_csv('SOFTLAB/ar1.csv')
ar3 = pd.read_csv('SOFTLAB/ar3.csv')
ar4 = pd.read_csv('SOFTLAB/ar4.csv')
ar5 = pd.read_csv('SOFTLAB/ar5.csv')
ar6 = pd.read_csv('SOFTLAB/ar6.csv')

# %%
list_softlab = ['ar1','ar3','ar4','ar5','ar6']
list_data_softlab = [ar1,ar3,ar4,ar5,ar6]

# %%
for dt in list_data_softlab:
    dt['Category'] = dt['Defective']
    dt.loc[dt['Defective'] == 'clean', 'Category'] = 'N'
    dt.loc[dt['Defective'] == 'buggy', 'Category'] = 'Y'
    dt['Defective'] = dt['Category']

# %%
list_dataset = [kc1,pc2,mc1]
label_dataset = ['kc1','pc2','mc1']

list_test = [cm1,kc3,mc2,mw1,pc1,pc3,pc4,pc5,pc2,jm1,kc1,mc1] + list_dataset + list_data_softlab
label_test = ['cm1','kc3','mc2','mw1','pc1','pc3','pc4','pc5','pc2','jm1','kc1','mc1'] + label_dataset + ['ar1','ar3','ar4','ar5','ar6']

my_index = range(0,len(list_test))
my_dataset = dict(zip(label_test,list_test))

df = list_dataset
df = pd.concat(df)
df
# Out:
#       LOC_BLANK  BRANCH_COUNT  LOC_CODE_AND_COMMENT  LOC_COMMENTS  \
# 0           6.0            15                     1             3
# 1           5.0            17                     0             7
# 2          12.0            31                     0             0
# 3           1.0             1                     0             0
# 4           0.0             1                     0             0
# ...         ...           ...                   ...           ...
# 1947        0.0             1                     0             0
# 1948        2.0             1                     0             0
# 1949        8.0             1                    15            10
# 1950       38.0            61                    16            32
# 1951        1.0             3                     2             0
#
#       CYCLOMATIC_COMPLEXITY  DESIGN_COMPLEXITY  ESSENTIAL_COMPLEXITY  \
# 0                         8                  8                     1
# 1                         9                  8                     1
# 2                        16                 13                    10
# 3                         1                  1                     1
# 4                         1                  1                     1
# ...                     ...                ...                   ...
# 1947                      1                  1                     1
# 1948                      1                  1                     1
# 1949                      1                  1                     1
# 1950                     35                 28                    18
# 1951                      2                  2                     1
#
#       LOC_EXECUTABLE  HALSTEAD_CONTENT  HALSTEAD_DIFFICULTY  ...  \
# 0                 45             23.87                27.06  ...
# 1                 82             69.72                22.29  ...
# 2                 95             59.66                33.33  ...
# 3                 12             89.39                 2.50  ...
# 4                  3             16.84                 1.50  ...
# ...              ...               ...                  ...  ...
# 1947               2              7.83                 4.67  ...
# 1948               2              5.33                 1.50  ...
# 1949              20            108.08                 8.29  ...
# 1950             198             73.58                80.67  ...
# 1951               3             13.95                 2.50  ...
#
#       PARAMETER_COUNT  MAINTENANCE_SEVERITY  MODIFIED_CONDITION_COUNT  \
# 0                 NaN                   NaN                       NaN
# 1                 NaN                   NaN                       NaN
# 2                 NaN                   NaN                       NaN
# 3                 NaN                   NaN                       NaN
# 4                 NaN                   NaN                       NaN
# ...               ...                   ...                       ...
# 1947              0.0                   1.0                       0.0
# 1948              0.0                   1.0                       0.0
# 1949              0.0                   1.0                       0.0
# 1950              0.0                   0.0                      24.0
# 1951              1.0                   0.0                       1.0
#
#       MULTIPLE_CONDITION_COUNT  NODE_COUNT  NORMALIZED_CYLOMATIC_COMPLEXITY  \
# 0                          NaN         NaN                              NaN
# 1                          NaN         NaN                              NaN
# 2                          NaN         NaN                              NaN
# 3                          NaN         NaN                              NaN
# 4                          NaN         NaN                              NaN
# ...                        ...         ...                              ...
# 1947                       0.0         2.0                             0.17
# 1948                       0.0         2.0                             0.17
# 1949                       0.0         7.0                             0.02
# 1950                      47.0       133.0                             0.12
# 1951                       2.0         7.0                             0.25
#
#       NUMBER_OF_LINES  PERCENT_COMMENTS  GLOBAL_DATA_COMPLEXITY  \
# 0                 NaN               NaN                     NaN
# 1                 NaN               NaN                     NaN
# 2                 NaN               NaN                     NaN
# 3                 NaN               NaN                     NaN
# 4                 NaN               NaN                     NaN
# ...               ...               ...                     ...
# 1947              6.0              0.00                     1.0
# 1948              6.0              0.00                     1.0
# 1949             55.0             55.56                     0.0
# 1950            286.0             19.51                    24.0
# 1951              8.0             40.00                     2.0
#
#       GLOBAL_DATA_DENSITY
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 1947                  1.0
# 1948                  1.0
# 1949                  0.0
# 1950                  0.0
# 1951                  1.0
#
# [3836 rows x 40 columns]

# %%
def adjustdataset_list(list_df):
    dt_result = list_df.pop()
    
    for dt in list_df:
        if len(dt.columns) > len(dt_result.columns):
            dt_result = adjustdataset(dt,dt_result)
        else:
            dt_result = adjustdataset(dt_result,dt)    
    return dt_result

# %%
def adjustdataset(dt,dataframe):
    dt_copy = dt.copy()
    counter = 0
    
    for col in dataframe.columns:
        if not col in dt.columns:
            #print("Not Exist ",col)
            dt_copy.insert(counter,col,-1)
        counter += 1

    return pd.concat([dt_copy[dataframe.columns], dataframe])

# %%
list_dataset = [kc1,pc2,mc1]
label_dataset = ['kc1','pc2','mc1']

list_test = [cm1,kc3,mc2,mw1,pc1,pc3,pc4,pc5,pc2,jm1,kc1,mc1] + list_dataset + list_data_softlab
label_test = ['cm1','kc3','mc2','mw1','pc1','pc3','pc4','pc5','pc2','jm1','kc1','mc1'] + label_dataset + ['ar1','ar3','ar4','ar5','ar6']

my_index = range(0,len(list_test))
my_dataset = dict(zip(label_test,list_test))

df = list_dataset
df = pd.concat(df)
df
# Out:
#       LOC_BLANK  BRANCH_COUNT  LOC_CODE_AND_COMMENT  LOC_COMMENTS  \
# 0           6.0            15                     1             3
# 1           5.0            17                     0             7
# 2          12.0            31                     0             0
# 3           1.0             1                     0             0
# 4           0.0             1                     0             0
# ...         ...           ...                   ...           ...
# 1947        0.0             1                     0             0
# 1948        2.0             1                     0             0
# 1949        8.0             1                    15            10
# 1950       38.0            61                    16            32
# 1951        1.0             3                     2             0
#
#       CYCLOMATIC_COMPLEXITY  DESIGN_COMPLEXITY  ESSENTIAL_COMPLEXITY  \
# 0                         8                  8                     1
# 1                         9                  8                     1
# 2                        16                 13                    10
# 3                         1                  1                     1
# 4                         1                  1                     1
# ...                     ...                ...                   ...
# 1947                      1                  1                     1
# 1948                      1                  1                     1
# 1949                      1                  1                     1
# 1950                     35                 28                    18
# 1951                      2                  2                     1
#
#       LOC_EXECUTABLE  HALSTEAD_CONTENT  HALSTEAD_DIFFICULTY  ...  \
# 0                 45             23.87                27.06  ...
# 1                 82             69.72                22.29  ...
# 2                 95             59.66                33.33  ...
# 3                 12             89.39                 2.50  ...
# 4                  3             16.84                 1.50  ...
# ...              ...               ...                  ...  ...
# 1947               2              7.83                 4.67  ...
# 1948               2              5.33                 1.50  ...
# 1949              20            108.08                 8.29  ...
# 1950             198             73.58                80.67  ...
# 1951               3             13.95                 2.50  ...
#
#       PARAMETER_COUNT  MAINTENANCE_SEVERITY  MODIFIED_CONDITION_COUNT  \
# 0                 NaN                   NaN                       NaN
# 1                 NaN                   NaN                       NaN
# 2                 NaN                   NaN                       NaN
# 3                 NaN                   NaN                       NaN
# 4                 NaN                   NaN                       NaN
# ...               ...                   ...                       ...
# 1947              0.0                   1.0                       0.0
# 1948              0.0                   1.0                       0.0
# 1949              0.0                   1.0                       0.0
# 1950              0.0                   0.0                      24.0
# 1951              1.0                   0.0                       1.0
#
#       MULTIPLE_CONDITION_COUNT  NODE_COUNT  NORMALIZED_CYLOMATIC_COMPLEXITY  \
# 0                          NaN         NaN                              NaN
# 1                          NaN         NaN                              NaN
# 2                          NaN         NaN                              NaN
# 3                          NaN         NaN                              NaN
# 4                          NaN         NaN                              NaN
# ...                        ...         ...                              ...
# 1947                       0.0         2.0                             0.17
# 1948                       0.0         2.0                             0.17
# 1949                       0.0         7.0                             0.02
# 1950                      47.0       133.0                             0.12
# 1951                       2.0         7.0                             0.25
#
#       NUMBER_OF_LINES  PERCENT_COMMENTS  GLOBAL_DATA_COMPLEXITY  \
# 0                 NaN               NaN                     NaN
# 1                 NaN               NaN                     NaN
# 2                 NaN               NaN                     NaN
# 3                 NaN               NaN                     NaN
# 4                 NaN               NaN                     NaN
# ...               ...               ...                     ...
# 1947              6.0              0.00                     1.0
# 1948              6.0              0.00                     1.0
# 1949             55.0             55.56                     0.0
# 1950            286.0             19.51                    24.0
# 1951              8.0             40.00                     2.0
#
#       GLOBAL_DATA_DENSITY
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 1947                  1.0
# 1948                  1.0
# 1949                  0.0
# 1950                  0.0
# 1951                  1.0
#
# [3836 rows x 40 columns]

# %%
def show_distribution(df, columns):
    
    counter = 0
    # Create a figure and a grid of subplots with 4 rows and 10 columns
    fig, axes = plt.subplots(5, 8, figsize=(20, 8))
    
    # Loop through each subplot and add content (optional)
    for i in range(5):
        for j in range(8):
            try:
                ax = axes[i, j]
                ax.set_title(columns[counter])
                ax.plot(df[columns[counter]].sort_values(), norm.pdf(df[columns[counter]].sort_values(), df[columns[counter]].mean(), df[columns[counter]].std())) 
                ax.set_xticks([])
                ax.set_yticks([])
                counter += 1
            except:
                pass

# Adjust layout to prevent overlapping titles/labels
plt.tight_layout()

# Display the plot
plt.show()

# %%
def preprocessing(dataframe, imputer = None, pt = None, scaler = None, show = True):
    
    df = dataframe.copy()
    
    df.loc[(df['Defective'] == 'N'),'Defective']=0
    df.loc[(df['Defective'] == 'Y'),'Defective']=1
    
    change_dtypes = ['Defective']
    dict_dtypes = {d:'int64' for d in change_dtypes }
    df = df.astype(dict_dtypes)
    
    try:
        df.loc[(df['DECISION_DENSITY'] == '?'),'DECISION_DENSITY']= -1
        
        change_dtypes = ['DECISION_DENSITY']
        dict_dtypes = {d:'float64' for d in change_dtypes }
        df = df.astype(dict_dtypes)
    
    except:
        pass
        
    
    columns = df.columns
    
    if show:
        show_distribution(df,df.columns)
    
    if imputer :
        df = imputer.transform(df)
    else:
        imputer = KNNImputer(n_neighbors=2)
        df = imputer.fit_transform(df)
    
    df = pd.DataFrame(df)
    df.columns = columns
    
    if show:
        show_distribution(df,df.columns)
    
    y = df['Defective']
    X = df.drop('Defective',axis=1)
    
    if pt:
        X_norm = pt.transform(X)
    else:
        pt = PowerTransformer()
        X_norm = pt.fit_transform(X)
    
    X_norm = pd.DataFrame(X)
    X_norm.columns = X.columns
    
    if show:
        show_distribution(X_norm,X_norm.columns)

    if scaler:
        X_norm_scale = scaler.transform(X_norm)
    else:
        scaler = MinMaxScaler()
        X_norm_scale = scaler.fit_transform(X_norm)
        
    return pt, scaler, imputer, X_norm_scale, y

# %%
def heat_map(y,result,title):
    import seaborn as sns
    from sklearn.metrics import confusion_matrix
    sns.set
    _, ax = plt.subplots(figsize=(10,10))
    ax = sns.heatmap(confusion_matrix(y, result), annot=True, fmt='d', cmap= ['#09acec','#089dd9','#078fc5','#0681b1','#05668d','#05368d'], annot_kws={"size": 40, "weight": "bold"})  
    labels = ['No Defect','Defect']
    ax.set_xticklabels(labels, fontsize=30);
    ax.set_yticklabels(labels, fontsize=30,rotation=0);
    ax.set_ylabel('Prediction', fontsize=30,rotation=0);
    ax.set_xlabel('Ground Truth', fontsize=30) #0,1
    ax.set_title(title)

# %%
def score(y,result):
    accuracy = accuracy_score(y, result)
    f1 = f1_score(y, result, average='weighted')
    precision = precision_score(y, result, average='weighted')
    recall = recall_score(y, result, average='weighted')
    print("Accuracy = " , accuracy, " Precision = ",precision, " Recall = ",recall, " F1-Score = ",f1 )

# %%
from sklearn.metrics import make_scorer

scorers = {
            'f1_score': make_scorer(f1_score, average='micro'),
            'precision_score': make_scorer(precision_score, average='micro'),
            'recall_score': make_scorer(recall_score, average='micro'),
            'accuracy_score': make_scorer(accuracy_score)
          }
search_space={}

# %%
pt, scaler, imputer, X_norm_scale, y = preprocessing(df, show=False)
#X_norm_scale_smote, y_smote = X_norm_scale, y 
smote = SMOTE(random_state=42)
X_norm_scale_smote, y_smote = smote.fit_resample(X_norm_scale, y)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(

# %% [raw]
# smote = SMOTE(random_state=42)
# X_norm_scale_smote, y_smote = smote.fit_resample(X_norm_scale, y)
# X_norm_scale_smote, y_smote = X_norm_scale, y

# %%
counter = 0
histories = []

lst_accu_stratified = []
lst_f1_stratified = []
lst_precision_stratified = []
lst_recall_stratified = []

lst_accu_stratified_val = []
lst_f1_stratified_val = []
lst_precision_stratified_val = []
lst_recall_stratified_val = []

skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=19)

for train_index, test_index in skf.split(X_norm_scale_smote, y_smote):

    x_train_fold, x_test_fold = X_norm_scale_smote[train_index], X_norm_scale_smote[test_index]
    y_train_fold, y_test_fold = y_smote[train_index], y_smote[test_index]
 
    rte = RandomTreesEmbedding(n_estimators=50, random_state=0, max_depth=10).fit(x_train_fold)
    x_sparse_embedding_train = rte.transform(x_train_fold)
    x_sparse_embedding_test = rte.transform(x_test_fold)
    
    with open('rte-tree-{0}.pickle'.format(counter), 'wb') as handle:
        pickle.dump(rte, handle, protocol=pickle.HIGHEST_PROTOCOL)
        
    input_X_train1 = layers.Input(
    shape=(x_sparse_embedding_train.toarray().shape[1],), name="X_train1")  
    
    input_X_train2 = layers.Input(shape=(x_train_fold.shape[1],), name="X_train2")

    layer_X_train1 = layers.Dense(512,activation='relu',name="X_train1_layer")(input_X_train1)
    layer_X_train1 = layers.BatchNormalization()(layer_X_train1)
    layer_X_train1 = layers.Dropout(0.1)(layer_X_train1)
    layer_X_train1 = layers.Dense(128,activation='relu',name="X_train1_layer")(input_X_train1)
    layer_X_train1 = layers.BatchNormalization()(layer_X_train1)
    layer_X_train1 = layers.Dropout(0.1)(layer_X_train1)

    layer_X_train2 = layers.Dense(512,activation='relu',name="X_train2_layer")(input_X_train2)
    layer_X_train2 = layers.BatchNormalization()(layer_X_train2)
    layer_X_train2 = layers.Dropout(0.1)(layer_X_train2)
    layer_X_train2 = layers.Dense(128,activation='relu',name="X_train2_layer")(input_X_train2)
    layer_X_train2 = layers.BatchNormalization()(layer_X_train2)
    layer_X_train2 = layers.Dropout(0.1)(layer_X_train2)

    # Merge all available features into a single large vector via concatenation
    concat = layers.concatenate([layer_X_train1, layer_X_train2])

    layer_final = layers.Dense(1, activation='sigmoid', name="classifier")(concat)
    sdp_classifier = Model(inputs=[input_X_train1, input_X_train2], outputs=layer_final)

    checkpointer=ModelCheckpoint(filepath='sdp-tree-{0}.weights.best.keras'.format(counter),verbose=1,save_best_only=True)

    sdp_classifier.compile(optimizer="adam", loss='binary_crossentropy', metrics=['accuracy'] )
    
    hist = sdp_classifier.fit([x_sparse_embedding_train.toarray(),x_train_fold], y_train_fold, 
                    batch_size=32, epochs=100, validation_split= 0.1, callbacks=[checkpointer], 
                    verbose=2, shuffle=True)
    
    with open('sdp-classifier-tree-{0}.pickle'.format(counter), 'wb') as handle:
        pickle.dump(sdp_classifier, handle, protocol=pickle.HIGHEST_PROTOCOL)
    

    sdp_classifier.load_weights('sdp-tree-{0}.weights.best.keras'.format(counter))

    histories.append(hist)

    results = sdp_classifier.predict([x_sparse_embedding_train.toarray(),x_train_fold])
    results = np.round(results)
    
    lst_accu_stratified.append(accuracy_score(results, y_train_fold))
    lst_f1_stratified.append(f1_score(y_train_fold, results, average='weighted') )
    lst_precision_stratified.append(precision_score(results, y_train_fold, average='weighted') )
    lst_recall_stratified.append(recall_score(results, y_train_fold, average='weighted') )
    
    results = sdp_classifier.predict([x_sparse_embedding_test.toarray(),x_test_fold])
    results = np.round(results)
    
    lst_accu_stratified_val.append(accuracy_score(results, y_test_fold))
    lst_f1_stratified_val.append(f1_score(results, y_test_fold, average='weighted') )
    lst_precision_stratified_val.append(precision_score(results, y_test_fold, average='weighted') )
    lst_recall_stratified_val.append(recall_score(results, y_test_fold, average='weighted') )

    print("Evaluate on training data")
    results = sdp_classifier.evaluate([x_sparse_embedding_train.toarray(), x_train_fold], y_train_fold)
    print("test loss, test acc:", results)

    print("Evaluate on test data")
    results = sdp_classifier.evaluate([x_sparse_embedding_test.toarray() , x_test_fold], y_test_fold)
    print("test loss, test acc:", results)
    counter += 1
    

dict_test = {"train_accu":lst_accu_stratified, 
           "train_precision":lst_precision_stratified, "train_recall":lst_recall_stratified, "train_f1":lst_f1_stratified,
           "test_accu":lst_accu_stratified_val, 
           "test_precision":lst_precision_stratified_val, "test_recall":lst_recall_stratified_val, 
           "test_f1":lst_f1_stratified_val,"Input": x_train_fold.shape[1] ,"RTE": x_sparse_embedding_train.toarray().shape[1]}

dict_test_result = pd.DataFrame.from_dict(dict_test)
dict_test_result.to_csv("hasil.csv")

with open('histories-tree.pickle'.format(counter), 'wb') as handle:
        pickle.dump(histories, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.76158, saving model to sdp-tree-0.weights.best.keras
# 177/177 - 8s - loss: 0.3888 - accuracy: 0.8277 - val_loss: 0.7616 - val_accuracy: 0.3688 - 8s/epoch - 43ms/step
# Epoch 2/100
#
# Epoch 2: val_loss improved from 0.76158 to 0.34097, saving model to sdp-tree-0.weights.best.keras
# 177/177 - 1s - loss: 0.2242 - accuracy: 0.9052 - val_loss: 0.3410 - val_accuracy: 0.9062 - 1s/epoch - 8ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 0.34097 to 0.12270, saving model to sdp-tree-0.weights.best.keras
# 177/177 - 2s - loss: 0.1595 - accuracy: 0.9360 - val_loss: 0.1227 - val_accuracy: 0.9634 - 2s/epoch - 10ms/step
# Epoch 4/100
#
# Epoch 4: val_loss did not improve from 0.12270
# 177/177 - 1s - loss: 0.1351 - accuracy: 0.9498 - val_loss: 0.1770 - val_accuracy: 0.9428 - 1s/epoch - 8ms/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 0.12270 to 0.08373, saving model to sdp-tree-0.weights.best.keras
# 177/177 - 2s - loss: 0.1094 - accuracy: 0.9591 - val_loss: 0.0837 - val_accuracy: 0.9698 - 2s/epoch - 9ms/step
# Epoch 6/100
#
# Epoch 6: val_loss did not improve from 0.08373
# 177/177 - 2s - loss: 0.1050 - accuracy: 0.9621 - val_loss: 0.2028 - val_accuracy: 0.9189 - 2s/epoch - 9ms/step
# Epoch 7/100
#
# Epoch 7: val_loss did not improve from 0.08373
# 177/177 - 2s - loss: 0.0910 - accuracy: 0.9678 - val_loss: 0.1142 - val_accuracy: 0.9555 - 2s/epoch - 9ms/step
# Epoch 8/100
#
# Epoch 8: val_loss did not improve from 0.08373
# 177/177 - 2s - loss: 0.0808 - accuracy: 0.9715 - val_loss: 0.1851 - val_accuracy: 0.9253 - 2s/epoch - 10ms/step
# Epoch 9/100
#
# Epoch 9: val_loss did not improve from 0.08373
# 177/177 - 3s - loss: 0.0759 - accuracy: 0.9713 - val_loss: 0.1794 - val_accuracy: 0.9221 - 3s/epoch - 14ms/step
# Epoch 10/100
#
# Epoch 10: val_loss improved from 0.08373 to 0.07743, saving model to sdp-tree-0.weights.best.keras
# 177/177 - 3s - loss: 0.0668 - accuracy: 0.9772 - val_loss: 0.0774 - val_accuracy: 0.9746 - 3s/epoch - 20ms/step
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 0.07743
# 177/177 - 2s - loss: 0.0634 - accuracy: 0.9763 - val_loss: 0.1102 - val_accuracy: 0.9571 - 2s/epoch - 12ms/step
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 0.07743
# 177/177 - 2s - loss: 0.0506 - accuracy: 0.9837 - val_loss: 0.1151 - val_accuracy: 0.9555 - 2s/epoch - 11ms/step
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 0.07743
# 177/177 - 2s - loss: 0.0588 - accuracy: 0.9772 - val_loss: 0.0979 - val_accuracy: 0.9666 - 2s/epoch - 9ms/step
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 0.07743
# 177/177 - 2s - loss: 0.0525 - accuracy: 0.9814 - val_loss: 0.1703 - val_accuracy: 0.9412 - 2s/epoch - 9ms/step
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 0.07743
# 177/177 - 1s - loss: 0.0490 - accuracy: 0.9848 - val_loss: 0.1709 - val_accuracy: 0.9428 - 1s/epoch - 8ms/step
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.07743
# 177/177 - 2s - loss: 0.0503 - accuracy: 0.9814 - val_loss: 0.1309 - val_accuracy: 0.9571 - 2s/epoch - 9ms/step
# Epoch 17/100
#
# Epoch 17: val_loss improved from 0.07743 to 0.05372, saving model to sdp-tree-0.weights.best.keras
# 177/177 - 2s - loss: 0.0445 - accuracy: 0.9843 - val_loss: 0.0537 - val_accuracy: 0.9746 - 2s/epoch - 11ms/step
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 0.05372
# 177/177 - 1s - loss: 0.0426 - accuracy: 0.9855 - val_loss: 0.1455 - val_accuracy: 0.9571 - 1s/epoch - 8ms/step
# Epoch 19/100
#
# Epoch 19: val_loss did not improve from 0.05372
# 177/177 - 1s - loss: 0.0409 - accuracy: 0.9858 - val_loss: 0.1505 - val_accuracy: 0.9428 - 1s/epoch - 8ms/step
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 0.05372
# 177/177 - 2s - loss: 0.0369 - accuracy: 0.9883 - val_loss: 0.1660 - val_accuracy: 0.9459 - 2s/epoch - 9ms/step
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 0.05372
# 177/177 - 1s - loss: 0.0430 - accuracy: 0.9843 - val_loss: 0.1948 - val_accuracy: 0.9189 - 1s/epoch - 8ms/step
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.05372
# 177/177 - 1s - loss: 0.0408 - accuracy: 0.9866 - val_loss: 0.1252 - val_accuracy: 0.9459 - 1s/epoch - 8ms/step
# Epoch 23/100
#
# Epoch 23: val_loss did not improve from 0.05372
# 177/177 - 1s - loss: 0.0391 - accuracy: 0.9876 - val_loss: 0.1487 - val_accuracy: 0.9380 - 1s/epoch - 8ms/step
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 0.05372
# 177/177 - 1s - loss: 0.0395 - accuracy: 0.9871 - val_loss: 0.1114 - val_accuracy: 0.9587 - 1s/epoch - 8ms/step
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 0.05372
# 177/177 - 1s - loss: 0.0378 - accuracy: 0.9876 - val_loss: 0.0794 - val_accuracy: 0.9730 - 1s/epoch - 7ms/step
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.05372
# 177/177 - 1s - loss: 0.0438 - accuracy: 0.9857 - val_loss: 0.1167 - val_accuracy: 0.9491 - 1s/epoch - 8ms/step
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 0.05372
# 177/177 - 1s - loss: 0.0409 - accuracy: 0.9851 - val_loss: 0.0704 - val_accuracy: 0.9746 - 1s/epoch - 8ms/step
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 0.05372
# 177/177 - 2s - loss: 0.0415 - accuracy: 0.9867 - val_loss: 0.0963 - val_accuracy: 0.9634 - 2s/epoch - 9ms/step
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 0.05372
# 177/177 - 2s - loss: 0.0301 - accuracy: 0.9913 - val_loss: 0.1037 - val_accuracy: 0.9555 - 2s/epoch - 10ms/step
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 0.05372
# 177/177 - 2s - loss: 0.0322 - accuracy: 0.9885 - val_loss: 0.2114 - val_accuracy: 0.9173 - 2s/epoch - 11ms/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 0.05372
# 177/177 - 2s - loss: 0.0313 - accuracy: 0.9896 - val_loss: 0.0559 - val_accuracy: 0.9762 - 2s/epoch - 10ms/step
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 0.05372
# 177/177 - 2s - loss: 0.0314 - accuracy: 0.9894 - val_loss: 0.1347 - val_accuracy: 0.9507 - 2s/epoch - 12ms/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 0.05372
# 177/177 - 2s - loss: 0.0312 - accuracy: 0.9896 - val_loss: 0.1413 - val_accuracy: 0.9491 - 2s/epoch - 12ms/step
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 0.05372
# 177/177 - 2s - loss: 0.0352 - accuracy: 0.9880 - val_loss: 0.2353 - val_accuracy: 0.9173 - 2s/epoch - 9ms/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 0.05372
# 177/177 - 1s - loss: 0.0345 - accuracy: 0.9887 - val_loss: 0.0867 - val_accuracy: 0.9634 - 1s/epoch - 8ms/step
# Epoch 36/100
#
# Epoch 36: val_loss did not improve from 0.05372
# 177/177 - 2s - loss: 0.0250 - accuracy: 0.9926 - val_loss: 0.1064 - val_accuracy: 0.9523 - 2s/epoch - 9ms/step
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 0.05372
# 177/177 - 1s - loss: 0.0268 - accuracy: 0.9903 - val_loss: 0.0894 - val_accuracy: 0.9650 - 1s/epoch - 8ms/step
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 0.05372
# 177/177 - 2s - loss: 0.0301 - accuracy: 0.9903 - val_loss: 0.1289 - val_accuracy: 0.9539 - 2s/epoch - 9ms/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 0.05372
# 177/177 - 1s - loss: 0.0316 - accuracy: 0.9904 - val_loss: 0.0685 - val_accuracy: 0.9714 - 1s/epoch - 7ms/step
# Epoch 40/100
#
# Epoch 40: val_loss improved from 0.05372 to 0.05046, saving model to sdp-tree-0.weights.best.keras
# 177/177 - 1s - loss: 0.0260 - accuracy: 0.9919 - val_loss: 0.0505 - val_accuracy: 0.9825 - 1s/epoch - 8ms/step
# Epoch 41/100
#
# Epoch 41: val_loss did not improve from 0.05046
# 177/177 - 1s - loss: 0.0255 - accuracy: 0.9912 - val_loss: 0.1257 - val_accuracy: 0.9491 - 1s/epoch - 7ms/step
# Epoch 42/100
#
# Epoch 42: val_loss did not improve from 0.05046
# 177/177 - 1s - loss: 0.0303 - accuracy: 0.9894 - val_loss: 0.1181 - val_accuracy: 0.9523 - 1s/epoch - 7ms/step
# Epoch 43/100
#
# Epoch 43: val_loss did not improve from 0.05046
# 177/177 - 2s - loss: 0.0302 - accuracy: 0.9889 - val_loss: 0.0889 - val_accuracy: 0.9634 - 2s/epoch - 9ms/step
# Epoch 44/100
#
# Epoch 44: val_loss did not improve from 0.05046
# 177/177 - 1s - loss: 0.0302 - accuracy: 0.9896 - val_loss: 0.1511 - val_accuracy: 0.9412 - 1s/epoch - 7ms/step
# Epoch 45/100
#
# Epoch 45: val_loss did not improve from 0.05046
# 177/177 - 1s - loss: 0.0333 - accuracy: 0.9889 - val_loss: 0.0578 - val_accuracy: 0.9777 - 1s/epoch - 7ms/step
# Epoch 46/100
#
# Epoch 46: val_loss did not improve from 0.05046
# 177/177 - 1s - loss: 0.0331 - accuracy: 0.9880 - val_loss: 0.0998 - val_accuracy: 0.9555 - 1s/epoch - 7ms/step
# Epoch 47/100
#
# Epoch 47: val_loss did not improve from 0.05046
# 177/177 - 1s - loss: 0.0267 - accuracy: 0.9906 - val_loss: 0.1155 - val_accuracy: 0.9618 - 1s/epoch - 7ms/step
# Epoch 48/100
#
# Epoch 48: val_loss did not improve from 0.05046
# 177/177 - 1s - loss: 0.0311 - accuracy: 0.9892 - val_loss: 0.1108 - val_accuracy: 0.9603 - 1s/epoch - 8ms/step
# Epoch 49/100
#
# Epoch 49: val_loss did not improve from 0.05046
# 177/177 - 1s - loss: 0.0280 - accuracy: 0.9894 - val_loss: 0.1003 - val_accuracy: 0.9618 - 1s/epoch - 7ms/step
# Epoch 50/100
#
# Epoch 50: val_loss did not improve from 0.05046
# 177/177 - 1s - loss: 0.0190 - accuracy: 0.9935 - val_loss: 0.1354 - val_accuracy: 0.9539 - 1s/epoch - 8ms/step
# Epoch 51/100
#
# Epoch 51: val_loss did not improve from 0.05046
# 177/177 - 1s - loss: 0.0226 - accuracy: 0.9920 - val_loss: 0.0778 - val_accuracy: 0.9682 - 1s/epoch - 8ms/step
# Epoch 52/100
#
# Epoch 52: val_loss did not improve from 0.05046
# 177/177 - 2s - loss: 0.0183 - accuracy: 0.9936 - val_loss: 0.1129 - val_accuracy: 0.9555 - 2s/epoch - 10ms/step
# Epoch 53/100
#
# Epoch 53: val_loss did not improve from 0.05046
# 177/177 - 2s - loss: 0.0310 - accuracy: 0.9899 - val_loss: 0.0929 - val_accuracy: 0.9603 - 2s/epoch - 13ms/step
# Epoch 54/100
#
# Epoch 54: val_loss did not improve from 0.05046
# 177/177 - 2s - loss: 0.0244 - accuracy: 0.9919 - val_loss: 0.0823 - val_accuracy: 0.9714 - 2s/epoch - 12ms/step
# Epoch 55/100
#
# Epoch 55: val_loss did not improve from 0.05046
# 177/177 - 3s - loss: 0.0196 - accuracy: 0.9936 - val_loss: 0.0997 - val_accuracy: 0.9634 - 3s/epoch - 16ms/step
# Epoch 56/100
#
# Epoch 56: val_loss did not improve from 0.05046
# 177/177 - 2s - loss: 0.0205 - accuracy: 0.9936 - val_loss: 0.1150 - val_accuracy: 0.9603 - 2s/epoch - 13ms/step
# Epoch 57/100
#
# Epoch 57: val_loss did not improve from 0.05046
# 177/177 - 2s - loss: 0.0193 - accuracy: 0.9947 - val_loss: 0.0874 - val_accuracy: 0.9698 - 2s/epoch - 11ms/step
# Epoch 58/100
#
# Epoch 58: val_loss did not improve from 0.05046
# 177/177 - 2s - loss: 0.0168 - accuracy: 0.9956 - val_loss: 0.1017 - val_accuracy: 0.9666 - 2s/epoch - 9ms/step
# Epoch 59/100
#
# Epoch 59: val_loss did not improve from 0.05046
# 177/177 - 1s - loss: 0.0259 - accuracy: 0.9926 - val_loss: 0.1196 - val_accuracy: 0.9618 - 1s/epoch - 7ms/step
# Epoch 60/100
#
# Epoch 60: val_loss did not improve from 0.05046
# 177/177 - 1s - loss: 0.0201 - accuracy: 0.9935 - val_loss: 0.1001 - val_accuracy: 0.9650 - 1s/epoch - 7ms/step
# Epoch 61/100
#
# Epoch 61: val_loss did not improve from 0.05046
# 177/177 - 1s - loss: 0.0257 - accuracy: 0.9922 - val_loss: 0.1066 - val_accuracy: 0.9603 - 1s/epoch - 7ms/step
# Epoch 62/100
#
# Epoch 62: val_loss improved from 0.05046 to 0.03640, saving model to sdp-tree-0.weights.best.keras
# 177/177 - 1s - loss: 0.0301 - accuracy: 0.9887 - val_loss: 0.0364 - val_accuracy: 0.9889 - 1s/epoch - 7ms/step
# Epoch 63/100
#
# Epoch 63: val_loss did not improve from 0.03640
# 177/177 - 1s - loss: 0.0242 - accuracy: 0.9913 - val_loss: 0.1987 - val_accuracy: 0.9364 - 1s/epoch - 6ms/step
# Epoch 64/100
#
# Epoch 64: val_loss did not improve from 0.03640
# 177/177 - 1s - loss: 0.0238 - accuracy: 0.9919 - val_loss: 0.0876 - val_accuracy: 0.9682 - 1s/epoch - 6ms/step
# Epoch 65/100
#
# Epoch 65: val_loss did not improve from 0.03640
# 177/177 - 1s - loss: 0.0226 - accuracy: 0.9922 - val_loss: 0.1123 - val_accuracy: 0.9666 - 1s/epoch - 6ms/step
# Epoch 66/100
#
# Epoch 66: val_loss did not improve from 0.03640
# 177/177 - 1s - loss: 0.0233 - accuracy: 0.9924 - val_loss: 0.1010 - val_accuracy: 0.9666 - 1s/epoch - 6ms/step
# Epoch 67/100
#
# Epoch 67: val_loss did not improve from 0.03640
# 177/177 - 1s - loss: 0.0288 - accuracy: 0.9908 - val_loss: 0.0882 - val_accuracy: 0.9666 - 1s/epoch - 6ms/step
# Epoch 68/100
#
# Epoch 68: val_loss did not improve from 0.03640
# 177/177 - 1s - loss: 0.0245 - accuracy: 0.9927 - val_loss: 0.0962 - val_accuracy: 0.9650 - 1s/epoch - 6ms/step
# Epoch 69/100
#
# Epoch 69: val_loss did not improve from 0.03640
# 177/177 - 1s - loss: 0.0205 - accuracy: 0.9929 - val_loss: 0.1067 - val_accuracy: 0.9666 - 1s/epoch - 6ms/step
# Epoch 70/100
#
# Epoch 70: val_loss did not improve from 0.03640
# 177/177 - 1s - loss: 0.0170 - accuracy: 0.9940 - val_loss: 0.1038 - val_accuracy: 0.9698 - 1s/epoch - 7ms/step
# Epoch 71/100
#
# Epoch 71: val_loss did not improve from 0.03640
# 177/177 - 1s - loss: 0.0181 - accuracy: 0.9950 - val_loss: 0.1351 - val_accuracy: 0.9618 - 1s/epoch - 7ms/step
# Epoch 72/100
#
# Epoch 72: val_loss did not improve from 0.03640
# 177/177 - 1s - loss: 0.0172 - accuracy: 0.9935 - val_loss: 0.0872 - val_accuracy: 0.9603 - 1s/epoch - 6ms/step
# Epoch 73/100
#
# Epoch 73: val_loss did not improve from 0.03640
# 177/177 - 1s - loss: 0.0178 - accuracy: 0.9952 - val_loss: 0.1210 - val_accuracy: 0.9555 - 1s/epoch - 8ms/step
# Epoch 74/100
#
# Epoch 74: val_loss did not improve from 0.03640
# 177/177 - 2s - loss: 0.0209 - accuracy: 0.9926 - val_loss: 0.0963 - val_accuracy: 0.9746 - 2s/epoch - 10ms/step
# Epoch 75/100
#
# Epoch 75: val_loss did not improve from 0.03640
# 177/177 - 2s - loss: 0.0241 - accuracy: 0.9922 - val_loss: 0.1044 - val_accuracy: 0.9587 - 2s/epoch - 11ms/step
# Epoch 76/100
#
# Epoch 76: val_loss did not improve from 0.03640
# 177/177 - 2s - loss: 0.0190 - accuracy: 0.9949 - val_loss: 0.0903 - val_accuracy: 0.9682 - 2s/epoch - 10ms/step
# Epoch 77/100
#
# Epoch 77: val_loss did not improve from 0.03640
# 177/177 - 3s - loss: 0.0227 - accuracy: 0.9920 - val_loss: 0.0980 - val_accuracy: 0.9634 - 3s/epoch - 14ms/step
# Epoch 78/100
#
# Epoch 78: val_loss did not improve from 0.03640
# 177/177 - 3s - loss: 0.0235 - accuracy: 0.9924 - val_loss: 0.1142 - val_accuracy: 0.9507 - 3s/epoch - 14ms/step
# Epoch 79/100
#
# Epoch 79: val_loss did not improve from 0.03640
# 177/177 - 3s - loss: 0.0187 - accuracy: 0.9942 - val_loss: 0.1259 - val_accuracy: 0.9555 - 3s/epoch - 16ms/step
# Epoch 80/100
#
# Epoch 80: val_loss did not improve from 0.03640
# 177/177 - 2s - loss: 0.0216 - accuracy: 0.9936 - val_loss: 0.1189 - val_accuracy: 0.9539 - 2s/epoch - 14ms/step
# Epoch 81/100
#
# Epoch 81: val_loss did not improve from 0.03640
# 177/177 - 3s - loss: 0.0203 - accuracy: 0.9924 - val_loss: 0.0968 - val_accuracy: 0.9618 - 3s/epoch - 17ms/step
# Epoch 82/100
#
# Epoch 82: val_loss did not improve from 0.03640
# 177/177 - 3s - loss: 0.0157 - accuracy: 0.9947 - val_loss: 0.0903 - val_accuracy: 0.9634 - 3s/epoch - 14ms/step
# Epoch 83/100
#
# Epoch 83: val_loss did not improve from 0.03640
# 177/177 - 2s - loss: 0.0143 - accuracy: 0.9952 - val_loss: 0.1527 - val_accuracy: 0.9475 - 2s/epoch - 13ms/step
# Epoch 84/100
#
# Epoch 84: val_loss did not improve from 0.03640
# 177/177 - 2s - loss: 0.0191 - accuracy: 0.9936 - val_loss: 0.1026 - val_accuracy: 0.9587 - 2s/epoch - 12ms/step
# Epoch 85/100
#
# Epoch 85: val_loss did not improve from 0.03640
# 177/177 - 2s - loss: 0.0189 - accuracy: 0.9933 - val_loss: 0.1218 - val_accuracy: 0.9587 - 2s/epoch - 12ms/step
# Epoch 86/100
#
# Epoch 86: val_loss did not improve from 0.03640
# 177/177 - 2s - loss: 0.0187 - accuracy: 0.9943 - val_loss: 0.1076 - val_accuracy: 0.9587 - 2s/epoch - 11ms/step
# Epoch 87/100
#
# Epoch 87: val_loss did not improve from 0.03640
# 177/177 - 2s - loss: 0.0224 - accuracy: 0.9933 - val_loss: 0.1147 - val_accuracy: 0.9650 - 2s/epoch - 13ms/step
# Epoch 88/100
#
# Epoch 88: val_loss did not improve from 0.03640
# 177/177 - 2s - loss: 0.0180 - accuracy: 0.9942 - val_loss: 0.1070 - val_accuracy: 0.9650 - 2s/epoch - 11ms/step
# Epoch 89/100
#
# Epoch 89: val_loss did not improve from 0.03640
# 177/177 - 2s - loss: 0.0174 - accuracy: 0.9950 - val_loss: 0.1540 - val_accuracy: 0.9444 - 2s/epoch - 11ms/step
# Epoch 90/100
#
# Epoch 90: val_loss did not improve from 0.03640
# 177/177 - 2s - loss: 0.0177 - accuracy: 0.9942 - val_loss: 0.1353 - val_accuracy: 0.9459 - 2s/epoch - 10ms/step
# Epoch 91/100
#
# Epoch 91: val_loss did not improve from 0.03640
# 177/177 - 2s - loss: 0.0161 - accuracy: 0.9947 - val_loss: 0.1249 - val_accuracy: 0.9634 - 2s/epoch - 10ms/step
# Epoch 92/100
#
# Epoch 92: val_loss did not improve from 0.03640
# 177/177 - 2s - loss: 0.0140 - accuracy: 0.9954 - val_loss: 0.1357 - val_accuracy: 0.9523 - 2s/epoch - 11ms/step
# Epoch 93/100
#
# Epoch 93: val_loss did not improve from 0.03640
# 177/177 - 2s - loss: 0.0173 - accuracy: 0.9950 - val_loss: 0.1319 - val_accuracy: 0.9571 - 2s/epoch - 11ms/step
# Epoch 94/100
#
# Epoch 94: val_loss did not improve from 0.03640
# 177/177 - 2s - loss: 0.0186 - accuracy: 0.9940 - val_loss: 0.1073 - val_accuracy: 0.9650 - 2s/epoch - 12ms/step
# Epoch 95/100
#
# Epoch 95: val_loss did not improve from 0.03640
# 177/177 - 2s - loss: 0.0191 - accuracy: 0.9935 - val_loss: 0.1290 - val_accuracy: 0.9507 - 2s/epoch - 13ms/step
# Epoch 96/100
#
# Epoch 96: val_loss did not improve from 0.03640
# 177/177 - 3s - loss: 0.0134 - accuracy: 0.9959 - val_loss: 0.1638 - val_accuracy: 0.9523 - 3s/epoch - 15ms/step
# Epoch 97/100
#
# Epoch 97: val_loss did not improve from 0.03640
# 177/177 - 2s - loss: 0.0201 - accuracy: 0.9947 - val_loss: 0.0901 - val_accuracy: 0.9714 - 2s/epoch - 12ms/step
# Epoch 98/100
#
# Epoch 98: val_loss did not improve from 0.03640
# 177/177 - 3s - loss: 0.0169 - accuracy: 0.9958 - val_loss: 0.1427 - val_accuracy: 0.9475 - 3s/epoch - 15ms/step
# Epoch 99/100
#
# Epoch 99: val_loss did not improve from 0.03640
# 177/177 - 2s - loss: 0.0166 - accuracy: 0.9949 - val_loss: 0.1638 - val_accuracy: 0.9571 - 2s/epoch - 13ms/step
# Epoch 100/100
#
# Epoch 100: val_loss did not improve from 0.03640
# 177/177 - 2s - loss: 0.0153 - accuracy: 0.9949 - val_loss: 0.1698 - val_accuracy: 0.9444 - 2s/epoch - 13ms/step
# 197/197 [==============================] - 2s 6ms/step
# 22/22 [==============================] - 0s 8ms/step
# Evaluate on training data
# 197/197 [==============================] - 1s 5ms/step - loss: 0.0176 - accuracy: 0.9944
# test loss, test acc: [0.01756146550178528, 0.9944285154342651]
# Evaluate on test data
# 22/22 [==============================] - 0s 6ms/step - loss: 0.3797 - accuracy: 0.9097
# test loss, test acc: [0.3797382712364197, 0.9097421169281006]
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.59763, saving model to sdp-tree-1.weights.best.keras
# 177/177 - 8s - loss: 0.3668 - accuracy: 0.8450 - val_loss: 0.5976 - val_accuracy: 0.7107 - 8s/epoch - 47ms/step
# Epoch 2/100
#
# Epoch 2: val_loss improved from 0.59763 to 0.34668, saving model to sdp-tree-1.weights.best.keras
# 177/177 - 2s - loss: 0.1998 - accuracy: 0.9215 - val_loss: 0.3467 - val_accuracy: 0.8760 - 2s/epoch - 11ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 0.34668 to 0.25967, saving model to sdp-tree-1.weights.best.keras
# 177/177 - 2s - loss: 0.1421 - accuracy: 0.9478 - val_loss: 0.2597 - val_accuracy: 0.8887 - 2s/epoch - 11ms/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 0.25967 to 0.05604, saving model to sdp-tree-1.weights.best.keras
# 177/177 - 2s - loss: 0.1189 - accuracy: 0.9544 - val_loss: 0.0560 - val_accuracy: 0.9857 - 2s/epoch - 13ms/step
# Epoch 5/100
#
# Epoch 5: val_loss did not improve from 0.05604
# 177/177 - 2s - loss: 0.0995 - accuracy: 0.9618 - val_loss: 0.1470 - val_accuracy: 0.9380 - 2s/epoch - 11ms/step
# Epoch 6/100
#
# Epoch 6: val_loss did not improve from 0.05604
# 177/177 - 2s - loss: 0.0909 - accuracy: 0.9659 - val_loss: 0.1196 - val_accuracy: 0.9555 - 2s/epoch - 12ms/step
# Epoch 7/100
#
# Epoch 7: val_loss did not improve from 0.05604
# 177/177 - 2s - loss: 0.0738 - accuracy: 0.9729 - val_loss: 0.0947 - val_accuracy: 0.9682 - 2s/epoch - 14ms/step
# Epoch 8/100
#
# Epoch 8: val_loss did not improve from 0.05604
# 177/177 - 3s - loss: 0.0705 - accuracy: 0.9738 - val_loss: 0.1090 - val_accuracy: 0.9555 - 3s/epoch - 17ms/step
# Epoch 9/100
#
# Epoch 9: val_loss did not improve from 0.05604
# 177/177 - 3s - loss: 0.0593 - accuracy: 0.9793 - val_loss: 0.0857 - val_accuracy: 0.9666 - 3s/epoch - 17ms/step
# Epoch 10/100
#
# Epoch 10: val_loss did not improve from 0.05604
# 177/177 - 3s - loss: 0.0533 - accuracy: 0.9805 - val_loss: 0.1306 - val_accuracy: 0.9571 - 3s/epoch - 18ms/step
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 0.05604
# 177/177 - 3s - loss: 0.0518 - accuracy: 0.9835 - val_loss: 0.0830 - val_accuracy: 0.9682 - 3s/epoch - 16ms/step
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 0.05604
# 177/177 - 2s - loss: 0.0561 - accuracy: 0.9814 - val_loss: 0.0766 - val_accuracy: 0.9777 - 2s/epoch - 14ms/step
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 0.05604
# 177/177 - 2s - loss: 0.0560 - accuracy: 0.9812 - val_loss: 0.0836 - val_accuracy: 0.9698 - 2s/epoch - 12ms/step
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 0.05604
# 177/177 - 2s - loss: 0.0539 - accuracy: 0.9805 - val_loss: 0.1158 - val_accuracy: 0.9571 - 2s/epoch - 13ms/step
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 0.05604
# 177/177 - 2s - loss: 0.0459 - accuracy: 0.9821 - val_loss: 0.0619 - val_accuracy: 0.9841 - 2s/epoch - 12ms/step
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.05604
# 177/177 - 2s - loss: 0.0449 - accuracy: 0.9843 - val_loss: 0.1174 - val_accuracy: 0.9539 - 2s/epoch - 12ms/step
# Epoch 17/100
#
# Epoch 17: val_loss did not improve from 0.05604
# 177/177 - 2s - loss: 0.0385 - accuracy: 0.9862 - val_loss: 0.1346 - val_accuracy: 0.9539 - 2s/epoch - 11ms/step
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 0.05604
# 177/177 - 2s - loss: 0.0449 - accuracy: 0.9844 - val_loss: 0.1136 - val_accuracy: 0.9698 - 2s/epoch - 12ms/step
# Epoch 19/100
#
# Epoch 19: val_loss did not improve from 0.05604
# 177/177 - 2s - loss: 0.0419 - accuracy: 0.9860 - val_loss: 0.1206 - val_accuracy: 0.9587 - 2s/epoch - 11ms/step
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 0.05604
# 177/177 - 2s - loss: 0.0426 - accuracy: 0.9846 - val_loss: 0.1091 - val_accuracy: 0.9603 - 2s/epoch - 11ms/step
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 0.05604
# 177/177 - 2s - loss: 0.0488 - accuracy: 0.9830 - val_loss: 0.0854 - val_accuracy: 0.9682 - 2s/epoch - 10ms/step
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.05604
# 177/177 - 2s - loss: 0.0463 - accuracy: 0.9832 - val_loss: 0.1101 - val_accuracy: 0.9650 - 2s/epoch - 13ms/step
# Epoch 23/100
#
# Epoch 23: val_loss did not improve from 0.05604
# 177/177 - 2s - loss: 0.0430 - accuracy: 0.9850 - val_loss: 0.1698 - val_accuracy: 0.9539 - 2s/epoch - 12ms/step
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 0.05604
# 177/177 - 2s - loss: 0.0358 - accuracy: 0.9873 - val_loss: 0.1757 - val_accuracy: 0.9380 - 2s/epoch - 13ms/step
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 0.05604
# 177/177 - 2s - loss: 0.0401 - accuracy: 0.9850 - val_loss: 0.1371 - val_accuracy: 0.9555 - 2s/epoch - 14ms/step
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.05604
# 177/177 - 3s - loss: 0.0344 - accuracy: 0.9883 - val_loss: 0.0811 - val_accuracy: 0.9746 - 3s/epoch - 15ms/step
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 0.05604
# 177/177 - 3s - loss: 0.0323 - accuracy: 0.9883 - val_loss: 0.1373 - val_accuracy: 0.9539 - 3s/epoch - 15ms/step
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 0.05604
# 177/177 - 2s - loss: 0.0250 - accuracy: 0.9912 - val_loss: 0.1336 - val_accuracy: 0.9666 - 2s/epoch - 13ms/step
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 0.05604
# 177/177 - 2s - loss: 0.0369 - accuracy: 0.9860 - val_loss: 0.0946 - val_accuracy: 0.9746 - 2s/epoch - 14ms/step
# Epoch 30/100
#
# Epoch 30: val_loss improved from 0.05604 to 0.05449, saving model to sdp-tree-1.weights.best.keras
# 177/177 - 3s - loss: 0.0337 - accuracy: 0.9887 - val_loss: 0.0545 - val_accuracy: 0.9857 - 3s/epoch - 17ms/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0338 - accuracy: 0.9899 - val_loss: 0.1026 - val_accuracy: 0.9634 - 2s/epoch - 14ms/step
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 0.05449
# 177/177 - 3s - loss: 0.0372 - accuracy: 0.9866 - val_loss: 0.0997 - val_accuracy: 0.9762 - 3s/epoch - 14ms/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0339 - accuracy: 0.9904 - val_loss: 0.1311 - val_accuracy: 0.9682 - 2s/epoch - 12ms/step
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0304 - accuracy: 0.9894 - val_loss: 0.1329 - val_accuracy: 0.9571 - 2s/epoch - 13ms/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0365 - accuracy: 0.9876 - val_loss: 0.0995 - val_accuracy: 0.9714 - 2s/epoch - 11ms/step
# Epoch 36/100
#
# Epoch 36: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0328 - accuracy: 0.9881 - val_loss: 0.0848 - val_accuracy: 0.9746 - 2s/epoch - 12ms/step
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0362 - accuracy: 0.9862 - val_loss: 0.1369 - val_accuracy: 0.9571 - 2s/epoch - 12ms/step
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0321 - accuracy: 0.9894 - val_loss: 0.0980 - val_accuracy: 0.9666 - 2s/epoch - 11ms/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0303 - accuracy: 0.9901 - val_loss: 0.0858 - val_accuracy: 0.9762 - 2s/epoch - 11ms/step
# Epoch 40/100
#
# Epoch 40: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0312 - accuracy: 0.9878 - val_loss: 0.0753 - val_accuracy: 0.9777 - 2s/epoch - 11ms/step
# Epoch 41/100
#
# Epoch 41: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0287 - accuracy: 0.9901 - val_loss: 0.1439 - val_accuracy: 0.9618 - 2s/epoch - 11ms/step
# Epoch 42/100
#
# Epoch 42: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0296 - accuracy: 0.9890 - val_loss: 0.0969 - val_accuracy: 0.9682 - 2s/epoch - 12ms/step
# Epoch 43/100
#
# Epoch 43: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0288 - accuracy: 0.9903 - val_loss: 0.1048 - val_accuracy: 0.9603 - 2s/epoch - 11ms/step
# Epoch 44/100
#
# Epoch 44: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0260 - accuracy: 0.9913 - val_loss: 0.1400 - val_accuracy: 0.9618 - 2s/epoch - 12ms/step
# Epoch 45/100
#
# Epoch 45: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0265 - accuracy: 0.9913 - val_loss: 0.1191 - val_accuracy: 0.9682 - 2s/epoch - 13ms/step
# Epoch 46/100
#
# Epoch 46: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0254 - accuracy: 0.9901 - val_loss: 0.1258 - val_accuracy: 0.9587 - 2s/epoch - 12ms/step
# Epoch 47/100
#
# Epoch 47: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0264 - accuracy: 0.9903 - val_loss: 0.1270 - val_accuracy: 0.9666 - 2s/epoch - 13ms/step
# Epoch 48/100
#
# Epoch 48: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0305 - accuracy: 0.9889 - val_loss: 0.1022 - val_accuracy: 0.9666 - 2s/epoch - 12ms/step
# Epoch 49/100
#
# Epoch 49: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0205 - accuracy: 0.9926 - val_loss: 0.0920 - val_accuracy: 0.9698 - 2s/epoch - 12ms/step
# Epoch 50/100
#
# Epoch 50: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0200 - accuracy: 0.9929 - val_loss: 0.1179 - val_accuracy: 0.9603 - 2s/epoch - 13ms/step
# Epoch 51/100
#
# Epoch 51: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0349 - accuracy: 0.9887 - val_loss: 0.1167 - val_accuracy: 0.9682 - 2s/epoch - 12ms/step
# Epoch 52/100
#
# Epoch 52: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0292 - accuracy: 0.9903 - val_loss: 0.0800 - val_accuracy: 0.9682 - 2s/epoch - 13ms/step
# Epoch 53/100
#
# Epoch 53: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0238 - accuracy: 0.9927 - val_loss: 0.0889 - val_accuracy: 0.9698 - 2s/epoch - 12ms/step
# Epoch 54/100
#
# Epoch 54: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0259 - accuracy: 0.9897 - val_loss: 0.1349 - val_accuracy: 0.9650 - 2s/epoch - 12ms/step
# Epoch 55/100
#
# Epoch 55: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0269 - accuracy: 0.9903 - val_loss: 0.1768 - val_accuracy: 0.9523 - 2s/epoch - 11ms/step
# Epoch 56/100
#
# Epoch 56: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0238 - accuracy: 0.9912 - val_loss: 0.0944 - val_accuracy: 0.9714 - 2s/epoch - 12ms/step
# Epoch 57/100
#
# Epoch 57: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0292 - accuracy: 0.9889 - val_loss: 0.1245 - val_accuracy: 0.9682 - 2s/epoch - 11ms/step
# Epoch 58/100
#
# Epoch 58: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0229 - accuracy: 0.9917 - val_loss: 0.1347 - val_accuracy: 0.9603 - 2s/epoch - 12ms/step
# Epoch 59/100
#
# Epoch 59: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0201 - accuracy: 0.9940 - val_loss: 0.1342 - val_accuracy: 0.9634 - 2s/epoch - 11ms/step
# Epoch 60/100
#
# Epoch 60: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0241 - accuracy: 0.9915 - val_loss: 0.1031 - val_accuracy: 0.9762 - 2s/epoch - 11ms/step
# Epoch 61/100
#
# Epoch 61: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0266 - accuracy: 0.9913 - val_loss: 0.1575 - val_accuracy: 0.9571 - 2s/epoch - 10ms/step
# Epoch 62/100
#
# Epoch 62: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0253 - accuracy: 0.9915 - val_loss: 0.1259 - val_accuracy: 0.9666 - 2s/epoch - 10ms/step
# Epoch 63/100
#
# Epoch 63: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0177 - accuracy: 0.9943 - val_loss: 0.1108 - val_accuracy: 0.9746 - 2s/epoch - 11ms/step
# Epoch 64/100
#
# Epoch 64: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0195 - accuracy: 0.9943 - val_loss: 0.1135 - val_accuracy: 0.9682 - 2s/epoch - 10ms/step
# Epoch 65/100
#
# Epoch 65: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0240 - accuracy: 0.9910 - val_loss: 0.1210 - val_accuracy: 0.9587 - 2s/epoch - 11ms/step
# Epoch 66/100
#
# Epoch 66: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0198 - accuracy: 0.9920 - val_loss: 0.0913 - val_accuracy: 0.9730 - 2s/epoch - 11ms/step
# Epoch 67/100
#
# Epoch 67: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0202 - accuracy: 0.9940 - val_loss: 0.1423 - val_accuracy: 0.9682 - 2s/epoch - 11ms/step
# Epoch 68/100
#
# Epoch 68: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0227 - accuracy: 0.9919 - val_loss: 0.1523 - val_accuracy: 0.9587 - 2s/epoch - 11ms/step
# Epoch 69/100
#
# Epoch 69: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0240 - accuracy: 0.9926 - val_loss: 0.1171 - val_accuracy: 0.9634 - 2s/epoch - 12ms/step
# Epoch 70/100
#
# Epoch 70: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0246 - accuracy: 0.9919 - val_loss: 0.0847 - val_accuracy: 0.9698 - 2s/epoch - 11ms/step
# Epoch 71/100
#
# Epoch 71: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0202 - accuracy: 0.9920 - val_loss: 0.1429 - val_accuracy: 0.9650 - 2s/epoch - 12ms/step
# Epoch 72/100
#
# Epoch 72: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0208 - accuracy: 0.9926 - val_loss: 0.1659 - val_accuracy: 0.9555 - 2s/epoch - 11ms/step
# Epoch 73/100
#
# Epoch 73: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0194 - accuracy: 0.9936 - val_loss: 0.1468 - val_accuracy: 0.9587 - 2s/epoch - 11ms/step
# Epoch 74/100
#
# Epoch 74: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0260 - accuracy: 0.9922 - val_loss: 0.1081 - val_accuracy: 0.9682 - 2s/epoch - 12ms/step
# Epoch 75/100
#
# Epoch 75: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0193 - accuracy: 0.9938 - val_loss: 0.0995 - val_accuracy: 0.9746 - 2s/epoch - 12ms/step
# Epoch 76/100
#
# Epoch 76: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0244 - accuracy: 0.9926 - val_loss: 0.1294 - val_accuracy: 0.9666 - 2s/epoch - 12ms/step
# Epoch 77/100
#
# Epoch 77: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0209 - accuracy: 0.9942 - val_loss: 0.1247 - val_accuracy: 0.9634 - 2s/epoch - 12ms/step
# Epoch 78/100
#
# Epoch 78: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0242 - accuracy: 0.9926 - val_loss: 0.1595 - val_accuracy: 0.9475 - 2s/epoch - 12ms/step
# Epoch 79/100
#
# Epoch 79: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0204 - accuracy: 0.9929 - val_loss: 0.1254 - val_accuracy: 0.9618 - 2s/epoch - 11ms/step
# Epoch 80/100
#
# Epoch 80: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0239 - accuracy: 0.9917 - val_loss: 0.1155 - val_accuracy: 0.9666 - 2s/epoch - 13ms/step
# Epoch 81/100
#
# Epoch 81: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0262 - accuracy: 0.9906 - val_loss: 0.0762 - val_accuracy: 0.9777 - 2s/epoch - 11ms/step
# Epoch 82/100
#
# Epoch 82: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0200 - accuracy: 0.9933 - val_loss: 0.1386 - val_accuracy: 0.9603 - 2s/epoch - 13ms/step
# Epoch 83/100
#
# Epoch 83: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0214 - accuracy: 0.9929 - val_loss: 0.1281 - val_accuracy: 0.9698 - 2s/epoch - 12ms/step
# Epoch 84/100
#
# Epoch 84: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0212 - accuracy: 0.9929 - val_loss: 0.1125 - val_accuracy: 0.9571 - 2s/epoch - 11ms/step
# Epoch 85/100
#
# Epoch 85: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0212 - accuracy: 0.9926 - val_loss: 0.0899 - val_accuracy: 0.9666 - 2s/epoch - 11ms/step
# Epoch 86/100
#
# Epoch 86: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0182 - accuracy: 0.9936 - val_loss: 0.1083 - val_accuracy: 0.9650 - 2s/epoch - 11ms/step
# Epoch 87/100
#
# Epoch 87: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0197 - accuracy: 0.9943 - val_loss: 0.1027 - val_accuracy: 0.9666 - 2s/epoch - 11ms/step
# Epoch 88/100
#
# Epoch 88: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0219 - accuracy: 0.9913 - val_loss: 0.1165 - val_accuracy: 0.9618 - 2s/epoch - 10ms/step
# Epoch 89/100
#
# Epoch 89: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0220 - accuracy: 0.9927 - val_loss: 0.1056 - val_accuracy: 0.9714 - 2s/epoch - 10ms/step
# Epoch 90/100
#
# Epoch 90: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0221 - accuracy: 0.9919 - val_loss: 0.1098 - val_accuracy: 0.9618 - 2s/epoch - 11ms/step
# Epoch 91/100
#
# Epoch 91: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0172 - accuracy: 0.9938 - val_loss: 0.1041 - val_accuracy: 0.9603 - 2s/epoch - 10ms/step
# Epoch 92/100
#
# Epoch 92: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0179 - accuracy: 0.9924 - val_loss: 0.1193 - val_accuracy: 0.9587 - 2s/epoch - 11ms/step
# Epoch 93/100
#
# Epoch 93: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0190 - accuracy: 0.9940 - val_loss: 0.1022 - val_accuracy: 0.9698 - 2s/epoch - 10ms/step
# Epoch 94/100
#
# Epoch 94: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0198 - accuracy: 0.9942 - val_loss: 0.1225 - val_accuracy: 0.9634 - 2s/epoch - 11ms/step
# Epoch 95/100
#
# Epoch 95: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0226 - accuracy: 0.9924 - val_loss: 0.0893 - val_accuracy: 0.9666 - 2s/epoch - 12ms/step
# Epoch 96/100
#
# Epoch 96: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0154 - accuracy: 0.9938 - val_loss: 0.1127 - val_accuracy: 0.9666 - 2s/epoch - 14ms/step
# Epoch 97/100
#
# Epoch 97: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0169 - accuracy: 0.9940 - val_loss: 0.1105 - val_accuracy: 0.9682 - 2s/epoch - 12ms/step
# Epoch 98/100
#
# Epoch 98: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0207 - accuracy: 0.9919 - val_loss: 0.1106 - val_accuracy: 0.9714 - 2s/epoch - 14ms/step
# Epoch 99/100
#
# Epoch 99: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0210 - accuracy: 0.9933 - val_loss: 0.1268 - val_accuracy: 0.9650 - 2s/epoch - 13ms/step
# Epoch 100/100
#
# Epoch 100: val_loss did not improve from 0.05449
# 177/177 - 2s - loss: 0.0148 - accuracy: 0.9952 - val_loss: 0.1147 - val_accuracy: 0.9714 - 2s/epoch - 13ms/step
# 197/197 [==============================] - 2s 6ms/step
# 22/22 [==============================] - 0s 6ms/step
# Evaluate on training data
# 197/197 [==============================] - 2s 8ms/step - loss: 0.0263 - accuracy: 0.9924
# test loss, test acc: [0.02629147469997406, 0.9923591017723083]
# Evaluate on test data
# 22/22 [==============================] - 0s 6ms/step - loss: 0.3696 - accuracy: 0.9155
# test loss, test acc: [0.36959677934646606, 0.9154728055000305]
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.60643, saving model to sdp-tree-2.weights.best.keras
# 177/177 - 8s - loss: 0.3973 - accuracy: 0.8208 - val_loss: 0.6064 - val_accuracy: 0.7075 - 8s/epoch - 44ms/step
# Epoch 2/100
#
# Epoch 2: val_loss improved from 0.60643 to 0.36962, saving model to sdp-tree-2.weights.best.keras
# 177/177 - 2s - loss: 0.2219 - accuracy: 0.9144 - val_loss: 0.3696 - val_accuracy: 0.8458 - 2s/epoch - 13ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 0.36962 to 0.22866, saving model to sdp-tree-2.weights.best.keras
# 177/177 - 2s - loss: 0.1694 - accuracy: 0.9317 - val_loss: 0.2287 - val_accuracy: 0.9205 - 2s/epoch - 13ms/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 0.22866 to 0.20085, saving model to sdp-tree-2.weights.best.keras
# 177/177 - 2s - loss: 0.1242 - accuracy: 0.9533 - val_loss: 0.2009 - val_accuracy: 0.9110 - 2s/epoch - 12ms/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 0.20085 to 0.16111, saving model to sdp-tree-2.weights.best.keras
# 177/177 - 2s - loss: 0.1111 - accuracy: 0.9579 - val_loss: 0.1611 - val_accuracy: 0.9428 - 2s/epoch - 12ms/step
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.16111 to 0.12879, saving model to sdp-tree-2.weights.best.keras
# 177/177 - 2s - loss: 0.0906 - accuracy: 0.9643 - val_loss: 0.1288 - val_accuracy: 0.9539 - 2s/epoch - 13ms/step
# Epoch 7/100
#
# Epoch 7: val_loss did not improve from 0.12879
# 177/177 - 2s - loss: 0.0771 - accuracy: 0.9738 - val_loss: 0.1327 - val_accuracy: 0.9539 - 2s/epoch - 12ms/step
# Epoch 8/100
#
# Epoch 8: val_loss did not improve from 0.12879
# 177/177 - 2s - loss: 0.0776 - accuracy: 0.9705 - val_loss: 0.1804 - val_accuracy: 0.9285 - 2s/epoch - 12ms/step
# Epoch 9/100
#
# Epoch 9: val_loss did not improve from 0.12879
# 177/177 - 2s - loss: 0.0705 - accuracy: 0.9761 - val_loss: 0.1882 - val_accuracy: 0.9332 - 2s/epoch - 13ms/step
# Epoch 10/100
#
# Epoch 10: val_loss improved from 0.12879 to 0.11486, saving model to sdp-tree-2.weights.best.keras
# 177/177 - 3s - loss: 0.0654 - accuracy: 0.9765 - val_loss: 0.1149 - val_accuracy: 0.9571 - 3s/epoch - 15ms/step
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 0.11486
# 177/177 - 2s - loss: 0.0571 - accuracy: 0.9812 - val_loss: 0.1259 - val_accuracy: 0.9523 - 2s/epoch - 14ms/step
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 0.11486
# 177/177 - 2s - loss: 0.0481 - accuracy: 0.9841 - val_loss: 0.1739 - val_accuracy: 0.9396 - 2s/epoch - 13ms/step
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 0.11486
# 177/177 - 2s - loss: 0.0469 - accuracy: 0.9858 - val_loss: 0.1930 - val_accuracy: 0.9364 - 2s/epoch - 14ms/step
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 0.11486
# 177/177 - 2s - loss: 0.0506 - accuracy: 0.9823 - val_loss: 0.1578 - val_accuracy: 0.9459 - 2s/epoch - 13ms/step
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 0.11486
# 177/177 - 2s - loss: 0.0484 - accuracy: 0.9823 - val_loss: 0.1730 - val_accuracy: 0.9412 - 2s/epoch - 13ms/step
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.11486
# 177/177 - 2s - loss: 0.0402 - accuracy: 0.9867 - val_loss: 0.1655 - val_accuracy: 0.9380 - 2s/epoch - 12ms/step
# Epoch 17/100
#
# Epoch 17: val_loss improved from 0.11486 to 0.10946, saving model to sdp-tree-2.weights.best.keras
# 177/177 - 3s - loss: 0.0442 - accuracy: 0.9853 - val_loss: 0.1095 - val_accuracy: 0.9603 - 3s/epoch - 15ms/step
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 0.10946
# 177/177 - 2s - loss: 0.0388 - accuracy: 0.9857 - val_loss: 0.1156 - val_accuracy: 0.9618 - 2s/epoch - 12ms/step
# Epoch 19/100
#
# Epoch 19: val_loss did not improve from 0.10946
# 177/177 - 2s - loss: 0.0439 - accuracy: 0.9843 - val_loss: 0.1239 - val_accuracy: 0.9571 - 2s/epoch - 11ms/step
# Epoch 20/100
#
# Epoch 20: val_loss improved from 0.10946 to 0.10517, saving model to sdp-tree-2.weights.best.keras
# 177/177 - 2s - loss: 0.0466 - accuracy: 0.9830 - val_loss: 0.1052 - val_accuracy: 0.9571 - 2s/epoch - 13ms/step
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 0.10517
# 177/177 - 2s - loss: 0.0490 - accuracy: 0.9818 - val_loss: 0.1546 - val_accuracy: 0.9571 - 2s/epoch - 11ms/step
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.10517
# 177/177 - 2s - loss: 0.0326 - accuracy: 0.9881 - val_loss: 0.1448 - val_accuracy: 0.9523 - 2s/epoch - 12ms/step
# Epoch 23/100
#
# Epoch 23: val_loss did not improve from 0.10517
# 177/177 - 2s - loss: 0.0339 - accuracy: 0.9880 - val_loss: 0.2761 - val_accuracy: 0.9157 - 2s/epoch - 12ms/step
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 0.10517
# 177/177 - 2s - loss: 0.0451 - accuracy: 0.9846 - val_loss: 0.1136 - val_accuracy: 0.9634 - 2s/epoch - 11ms/step
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 0.10517
# 177/177 - 2s - loss: 0.0430 - accuracy: 0.9864 - val_loss: 0.1172 - val_accuracy: 0.9634 - 2s/epoch - 11ms/step
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.10517
# 177/177 - 2s - loss: 0.0328 - accuracy: 0.9887 - val_loss: 0.1184 - val_accuracy: 0.9587 - 2s/epoch - 11ms/step
# Epoch 27/100
#
# Epoch 27: val_loss improved from 0.10517 to 0.09087, saving model to sdp-tree-2.weights.best.keras
# 177/177 - 2s - loss: 0.0304 - accuracy: 0.9903 - val_loss: 0.0909 - val_accuracy: 0.9634 - 2s/epoch - 13ms/step
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 0.09087
# 177/177 - 2s - loss: 0.0299 - accuracy: 0.9915 - val_loss: 0.1207 - val_accuracy: 0.9587 - 2s/epoch - 11ms/step
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 0.09087
# 177/177 - 2s - loss: 0.0393 - accuracy: 0.9858 - val_loss: 0.1671 - val_accuracy: 0.9444 - 2s/epoch - 12ms/step
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 0.09087
# 177/177 - 2s - loss: 0.0342 - accuracy: 0.9885 - val_loss: 0.1380 - val_accuracy: 0.9523 - 2s/epoch - 13ms/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 0.09087
# 177/177 - 2s - loss: 0.0299 - accuracy: 0.9883 - val_loss: 0.1964 - val_accuracy: 0.9332 - 2s/epoch - 12ms/step
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 0.09087
# 177/177 - 2s - loss: 0.0278 - accuracy: 0.9913 - val_loss: 0.1197 - val_accuracy: 0.9634 - 2s/epoch - 11ms/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 0.09087
# 177/177 - 3s - loss: 0.0267 - accuracy: 0.9915 - val_loss: 0.0925 - val_accuracy: 0.9666 - 3s/epoch - 14ms/step
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 0.09087
# 177/177 - 3s - loss: 0.0288 - accuracy: 0.9906 - val_loss: 0.1840 - val_accuracy: 0.9364 - 3s/epoch - 18ms/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 0.09087
# 177/177 - 4s - loss: 0.0298 - accuracy: 0.9897 - val_loss: 0.1544 - val_accuracy: 0.9603 - 4s/epoch - 20ms/step
# Epoch 36/100
#
# Epoch 36: val_loss did not improve from 0.09087
# 177/177 - 3s - loss: 0.0286 - accuracy: 0.9903 - val_loss: 0.1080 - val_accuracy: 0.9618 - 3s/epoch - 18ms/step
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 0.09087
# 177/177 - 2s - loss: 0.0325 - accuracy: 0.9899 - val_loss: 0.1605 - val_accuracy: 0.9459 - 2s/epoch - 12ms/step
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 0.09087
# 177/177 - 3s - loss: 0.0258 - accuracy: 0.9919 - val_loss: 0.1896 - val_accuracy: 0.9428 - 3s/epoch - 14ms/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 0.09087
# 177/177 - 2s - loss: 0.0271 - accuracy: 0.9920 - val_loss: 0.1023 - val_accuracy: 0.9618 - 2s/epoch - 14ms/step
# Epoch 40/100
#
# Epoch 40: val_loss improved from 0.09087 to 0.09084, saving model to sdp-tree-2.weights.best.keras
# 177/177 - 3s - loss: 0.0262 - accuracy: 0.9908 - val_loss: 0.0908 - val_accuracy: 0.9650 - 3s/epoch - 15ms/step
# Epoch 41/100
#
# Epoch 41: val_loss did not improve from 0.09084
# 177/177 - 2s - loss: 0.0264 - accuracy: 0.9901 - val_loss: 0.1337 - val_accuracy: 0.9491 - 2s/epoch - 11ms/step
# Epoch 42/100
#
# Epoch 42: val_loss did not improve from 0.09084
# 177/177 - 2s - loss: 0.0249 - accuracy: 0.9912 - val_loss: 0.1257 - val_accuracy: 0.9603 - 2s/epoch - 13ms/step
# Epoch 43/100
#
# Epoch 43: val_loss did not improve from 0.09084
# 177/177 - 2s - loss: 0.0247 - accuracy: 0.9917 - val_loss: 0.1442 - val_accuracy: 0.9555 - 2s/epoch - 12ms/step
# Epoch 44/100
#
# Epoch 44: val_loss did not improve from 0.09084
# 177/177 - 2s - loss: 0.0246 - accuracy: 0.9927 - val_loss: 0.1335 - val_accuracy: 0.9539 - 2s/epoch - 13ms/step
# Epoch 45/100
#
# Epoch 45: val_loss did not improve from 0.09084
# 177/177 - 3s - loss: 0.0246 - accuracy: 0.9913 - val_loss: 0.0994 - val_accuracy: 0.9650 - 3s/epoch - 15ms/step
# Epoch 46/100
#
# Epoch 46: val_loss did not improve from 0.09084
# 177/177 - 3s - loss: 0.0276 - accuracy: 0.9908 - val_loss: 0.1237 - val_accuracy: 0.9571 - 3s/epoch - 16ms/step
# Epoch 47/100
#
# Epoch 47: val_loss did not improve from 0.09084
# 177/177 - 2s - loss: 0.0173 - accuracy: 0.9943 - val_loss: 0.1737 - val_accuracy: 0.9444 - 2s/epoch - 14ms/step
# Epoch 48/100
#
# Epoch 48: val_loss did not improve from 0.09084
# 177/177 - 2s - loss: 0.0278 - accuracy: 0.9913 - val_loss: 0.1112 - val_accuracy: 0.9650 - 2s/epoch - 14ms/step
# Epoch 49/100
#
# Epoch 49: val_loss did not improve from 0.09084
# 177/177 - 2s - loss: 0.0207 - accuracy: 0.9945 - val_loss: 0.1399 - val_accuracy: 0.9523 - 2s/epoch - 13ms/step
# Epoch 50/100
#
# Epoch 50: val_loss did not improve from 0.09084
# 177/177 - 3s - loss: 0.0237 - accuracy: 0.9913 - val_loss: 0.1221 - val_accuracy: 0.9634 - 3s/epoch - 17ms/step
# Epoch 51/100
#
# Epoch 51: val_loss did not improve from 0.09084
# 177/177 - 3s - loss: 0.0356 - accuracy: 0.9889 - val_loss: 0.1012 - val_accuracy: 0.9682 - 3s/epoch - 14ms/step
# Epoch 52/100
#
# Epoch 52: val_loss improved from 0.09084 to 0.08734, saving model to sdp-tree-2.weights.best.keras
# 177/177 - 3s - loss: 0.0218 - accuracy: 0.9936 - val_loss: 0.0873 - val_accuracy: 0.9698 - 3s/epoch - 18ms/step
# Epoch 53/100
#
# Epoch 53: val_loss did not improve from 0.08734
# 177/177 - 3s - loss: 0.0204 - accuracy: 0.9924 - val_loss: 0.1297 - val_accuracy: 0.9618 - 3s/epoch - 16ms/step
# Epoch 54/100
#
# Epoch 54: val_loss did not improve from 0.08734
# 177/177 - 3s - loss: 0.0199 - accuracy: 0.9940 - val_loss: 0.1150 - val_accuracy: 0.9634 - 3s/epoch - 16ms/step
# Epoch 55/100
#
# Epoch 55: val_loss did not improve from 0.08734
# 177/177 - 2s - loss: 0.0197 - accuracy: 0.9915 - val_loss: 0.0957 - val_accuracy: 0.9714 - 2s/epoch - 14ms/step
# Epoch 56/100
#
# Epoch 56: val_loss did not improve from 0.08734
# 177/177 - 2s - loss: 0.0221 - accuracy: 0.9931 - val_loss: 0.0970 - val_accuracy: 0.9746 - 2s/epoch - 13ms/step
# Epoch 57/100
#
# Epoch 57: val_loss did not improve from 0.08734
# 177/177 - 3s - loss: 0.0237 - accuracy: 0.9926 - val_loss: 0.1186 - val_accuracy: 0.9634 - 3s/epoch - 14ms/step
# Epoch 58/100
#
# Epoch 58: val_loss did not improve from 0.08734
# 177/177 - 2s - loss: 0.0284 - accuracy: 0.9904 - val_loss: 0.2109 - val_accuracy: 0.9396 - 2s/epoch - 14ms/step
# Epoch 59/100
#
# Epoch 59: val_loss did not improve from 0.08734
# 177/177 - 2s - loss: 0.0245 - accuracy: 0.9917 - val_loss: 0.1198 - val_accuracy: 0.9650 - 2s/epoch - 13ms/step
# Epoch 60/100
#
# Epoch 60: val_loss did not improve from 0.08734
# 177/177 - 3s - loss: 0.0232 - accuracy: 0.9926 - val_loss: 0.1209 - val_accuracy: 0.9634 - 3s/epoch - 17ms/step
# Epoch 61/100
#
# Epoch 61: val_loss did not improve from 0.08734
# 177/177 - 3s - loss: 0.0252 - accuracy: 0.9922 - val_loss: 0.1747 - val_accuracy: 0.9507 - 3s/epoch - 15ms/step
# Epoch 62/100
#
# Epoch 62: val_loss did not improve from 0.08734
# 177/177 - 3s - loss: 0.0188 - accuracy: 0.9933 - val_loss: 0.0971 - val_accuracy: 0.9698 - 3s/epoch - 16ms/step
# Epoch 63/100
#
# Epoch 63: val_loss did not improve from 0.08734
# 177/177 - 3s - loss: 0.0203 - accuracy: 0.9933 - val_loss: 0.1468 - val_accuracy: 0.9555 - 3s/epoch - 14ms/step
# Epoch 64/100
#
# Epoch 64: val_loss did not improve from 0.08734
# ...
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 0.11292
# 177/177 - 2s - loss: 0.0486 - accuracy: 0.9835 - val_loss: 0.2003 - val_accuracy: 0.9412 - 2s/epoch - 14ms/step
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 0.11292
# 177/177 - 3s - loss: 0.0448 - accuracy: 0.9837 - val_loss: 0.2009 - val_accuracy: 0.9332 - 3s/epoch - 15ms/step
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 0.11292
# 177/177 - 2s - loss: 0.0393 - accuracy: 0.9860 - val_loss: 0.2071 - val_accuracy: 0.9300 - 2s/epoch - 12ms/step
# Epoch 15/100
#
# Epoch 15: val_loss improved from 0.11292 to 0.07672, saving model to sdp-tree-9.weights.best.keras
# 177/177 - 3s - loss: 0.0429 - accuracy: 0.9844 - val_loss: 0.0767 - val_accuracy: 0.9746 - 3s/epoch - 15ms/step
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0423 - accuracy: 0.9832 - val_loss: 0.1644 - val_accuracy: 0.9412 - 2s/epoch - 12ms/step
# Epoch 17/100
#
# Epoch 17: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0393 - accuracy: 0.9855 - val_loss: 0.1485 - val_accuracy: 0.9459 - 2s/epoch - 11ms/step
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0368 - accuracy: 0.9883 - val_loss: 0.1078 - val_accuracy: 0.9571 - 2s/epoch - 12ms/step
# Epoch 19/100
#
# Epoch 19: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0396 - accuracy: 0.9871 - val_loss: 0.1508 - val_accuracy: 0.9444 - 2s/epoch - 11ms/step
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0346 - accuracy: 0.9880 - val_loss: 0.2200 - val_accuracy: 0.9237 - 2s/epoch - 11ms/step
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0336 - accuracy: 0.9883 - val_loss: 0.1348 - val_accuracy: 0.9539 - 2s/epoch - 11ms/step
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0257 - accuracy: 0.9912 - val_loss: 0.1608 - val_accuracy: 0.9396 - 2s/epoch - 11ms/step
# Epoch 23/100
#
# Epoch 23: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0329 - accuracy: 0.9903 - val_loss: 0.1457 - val_accuracy: 0.9571 - 2s/epoch - 11ms/step
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0358 - accuracy: 0.9881 - val_loss: 0.1746 - val_accuracy: 0.9459 - 2s/epoch - 12ms/step
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0267 - accuracy: 0.9903 - val_loss: 0.1821 - val_accuracy: 0.9428 - 2s/epoch - 11ms/step
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0303 - accuracy: 0.9899 - val_loss: 0.2000 - val_accuracy: 0.9380 - 2s/epoch - 13ms/step
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0254 - accuracy: 0.9920 - val_loss: 0.1314 - val_accuracy: 0.9571 - 2s/epoch - 13ms/step
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0299 - accuracy: 0.9896 - val_loss: 0.2534 - val_accuracy: 0.9205 - 2s/epoch - 12ms/step
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0290 - accuracy: 0.9919 - val_loss: 0.1239 - val_accuracy: 0.9587 - 2s/epoch - 12ms/step
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0304 - accuracy: 0.9906 - val_loss: 0.1314 - val_accuracy: 0.9603 - 2s/epoch - 12ms/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0303 - accuracy: 0.9887 - val_loss: 0.1056 - val_accuracy: 0.9666 - 2s/epoch - 13ms/step
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0227 - accuracy: 0.9924 - val_loss: 0.2183 - val_accuracy: 0.9475 - 2s/epoch - 13ms/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0192 - accuracy: 0.9943 - val_loss: 0.1132 - val_accuracy: 0.9682 - 2s/epoch - 13ms/step
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0262 - accuracy: 0.9912 - val_loss: 0.1548 - val_accuracy: 0.9507 - 2s/epoch - 11ms/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0253 - accuracy: 0.9920 - val_loss: 0.1914 - val_accuracy: 0.9396 - 2s/epoch - 12ms/step
# Epoch 36/100
#
# Epoch 36: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0237 - accuracy: 0.9922 - val_loss: 0.1710 - val_accuracy: 0.9475 - 2s/epoch - 12ms/step
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0231 - accuracy: 0.9924 - val_loss: 0.1790 - val_accuracy: 0.9475 - 2s/epoch - 11ms/step
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0249 - accuracy: 0.9929 - val_loss: 0.1711 - val_accuracy: 0.9523 - 2s/epoch - 11ms/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0191 - accuracy: 0.9938 - val_loss: 0.1358 - val_accuracy: 0.9603 - 2s/epoch - 11ms/step
# Epoch 40/100
#
# Epoch 40: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0281 - accuracy: 0.9890 - val_loss: 0.1772 - val_accuracy: 0.9475 - 2s/epoch - 11ms/step
# Epoch 41/100
#
# Epoch 41: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0265 - accuracy: 0.9906 - val_loss: 0.1111 - val_accuracy: 0.9698 - 2s/epoch - 10ms/step
# Epoch 42/100
#
# Epoch 42: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0215 - accuracy: 0.9915 - val_loss: 0.1737 - val_accuracy: 0.9459 - 2s/epoch - 13ms/step
# Epoch 43/100
#
# Epoch 43: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0198 - accuracy: 0.9933 - val_loss: 0.1313 - val_accuracy: 0.9618 - 2s/epoch - 12ms/step
# Epoch 44/100
#
# Epoch 44: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0179 - accuracy: 0.9945 - val_loss: 0.2047 - val_accuracy: 0.9348 - 2s/epoch - 10ms/step
# Epoch 45/100
#
# Epoch 45: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0188 - accuracy: 0.9943 - val_loss: 0.2314 - val_accuracy: 0.9380 - 2s/epoch - 11ms/step
# Epoch 46/100
#
# Epoch 46: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0159 - accuracy: 0.9952 - val_loss: 0.1674 - val_accuracy: 0.9491 - 2s/epoch - 11ms/step
# Epoch 47/100
#
# Epoch 47: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0140 - accuracy: 0.9952 - val_loss: 0.2038 - val_accuracy: 0.9412 - 2s/epoch - 12ms/step
# Epoch 48/100
#
# Epoch 48: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0179 - accuracy: 0.9943 - val_loss: 0.1305 - val_accuracy: 0.9666 - 2s/epoch - 11ms/step
# Epoch 49/100
#
# Epoch 49: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0242 - accuracy: 0.9917 - val_loss: 0.1542 - val_accuracy: 0.9571 - 2s/epoch - 12ms/step
# Epoch 50/100
#
# Epoch 50: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0231 - accuracy: 0.9922 - val_loss: 0.1468 - val_accuracy: 0.9603 - 2s/epoch - 12ms/step
# Epoch 51/100
#
# Epoch 51: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0205 - accuracy: 0.9942 - val_loss: 0.1325 - val_accuracy: 0.9587 - 2s/epoch - 13ms/step
# Epoch 52/100
#
# Epoch 52: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0247 - accuracy: 0.9922 - val_loss: 0.1374 - val_accuracy: 0.9618 - 2s/epoch - 12ms/step
# Epoch 53/100
#
# Epoch 53: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0241 - accuracy: 0.9926 - val_loss: 0.1073 - val_accuracy: 0.9746 - 2s/epoch - 12ms/step
# Epoch 54/100
#
# Epoch 54: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0222 - accuracy: 0.9922 - val_loss: 0.1856 - val_accuracy: 0.9555 - 2s/epoch - 14ms/step
# Epoch 55/100
#
# Epoch 55: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0183 - accuracy: 0.9938 - val_loss: 0.1485 - val_accuracy: 0.9618 - 2s/epoch - 14ms/step
# Epoch 56/100
#
# Epoch 56: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0238 - accuracy: 0.9927 - val_loss: 0.1960 - val_accuracy: 0.9428 - 2s/epoch - 13ms/step
# Epoch 57/100
#
# Epoch 57: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0202 - accuracy: 0.9931 - val_loss: 0.1409 - val_accuracy: 0.9587 - 2s/epoch - 13ms/step
# Epoch 58/100
#
# Epoch 58: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0174 - accuracy: 0.9943 - val_loss: 0.1275 - val_accuracy: 0.9634 - 2s/epoch - 12ms/step
# Epoch 59/100
#
# Epoch 59: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0164 - accuracy: 0.9938 - val_loss: 0.1173 - val_accuracy: 0.9682 - 2s/epoch - 12ms/step
# Epoch 60/100
#
# Epoch 60: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0192 - accuracy: 0.9935 - val_loss: 0.1196 - val_accuracy: 0.9603 - 2s/epoch - 10ms/step
# Epoch 61/100
#
# Epoch 61: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0144 - accuracy: 0.9959 - val_loss: 0.0989 - val_accuracy: 0.9682 - 2s/epoch - 11ms/step
# Epoch 62/100
#
# Epoch 62: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0161 - accuracy: 0.9945 - val_loss: 0.1137 - val_accuracy: 0.9666 - 2s/epoch - 11ms/step
# Epoch 63/100
#
# Epoch 63: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0163 - accuracy: 0.9942 - val_loss: 0.1630 - val_accuracy: 0.9523 - 2s/epoch - 11ms/step
# Epoch 64/100
#
# Epoch 64: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0162 - accuracy: 0.9949 - val_loss: 0.1472 - val_accuracy: 0.9507 - 2s/epoch - 11ms/step
# Epoch 65/100
#
# Epoch 65: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0170 - accuracy: 0.9943 - val_loss: 0.1912 - val_accuracy: 0.9475 - 2s/epoch - 11ms/step
# Epoch 66/100
#
# Epoch 66: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0196 - accuracy: 0.9935 - val_loss: 0.1498 - val_accuracy: 0.9571 - 2s/epoch - 11ms/step
# Epoch 67/100
#
# Epoch 67: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0165 - accuracy: 0.9947 - val_loss: 0.1740 - val_accuracy: 0.9348 - 2s/epoch - 11ms/step
# Epoch 68/100
#
# Epoch 68: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0180 - accuracy: 0.9922 - val_loss: 0.1110 - val_accuracy: 0.9666 - 2s/epoch - 11ms/step
# Epoch 69/100
#
# Epoch 69: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0188 - accuracy: 0.9943 - val_loss: 0.1620 - val_accuracy: 0.9507 - 2s/epoch - 14ms/step
# Epoch 70/100
#
# Epoch 70: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0181 - accuracy: 0.9931 - val_loss: 0.1560 - val_accuracy: 0.9475 - 2s/epoch - 14ms/step
# Epoch 71/100
#
# Epoch 71: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0172 - accuracy: 0.9935 - val_loss: 0.1763 - val_accuracy: 0.9539 - 2s/epoch - 12ms/step
# Epoch 72/100
#
# Epoch 72: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0139 - accuracy: 0.9954 - val_loss: 0.0901 - val_accuracy: 0.9682 - 2s/epoch - 13ms/step
# Epoch 73/100
#
# Epoch 73: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0152 - accuracy: 0.9945 - val_loss: 0.0854 - val_accuracy: 0.9650 - 2s/epoch - 12ms/step
# Epoch 74/100
#
# Epoch 74: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0130 - accuracy: 0.9947 - val_loss: 0.1804 - val_accuracy: 0.9491 - 2s/epoch - 11ms/step
# Epoch 75/100
#
# Epoch 75: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0165 - accuracy: 0.9958 - val_loss: 0.1713 - val_accuracy: 0.9475 - 2s/epoch - 14ms/step
# Epoch 76/100
#
# Epoch 76: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0154 - accuracy: 0.9942 - val_loss: 0.1663 - val_accuracy: 0.9603 - 2s/epoch - 13ms/step
# Epoch 77/100
#
# Epoch 77: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0136 - accuracy: 0.9965 - val_loss: 0.1270 - val_accuracy: 0.9650 - 2s/epoch - 13ms/step
# Epoch 78/100
#
# Epoch 78: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0115 - accuracy: 0.9965 - val_loss: 0.1248 - val_accuracy: 0.9714 - 2s/epoch - 12ms/step
# Epoch 79/100
#
# Epoch 79: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0172 - accuracy: 0.9943 - val_loss: 0.1156 - val_accuracy: 0.9698 - 2s/epoch - 12ms/step
# Epoch 80/100
#
# Epoch 80: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0200 - accuracy: 0.9949 - val_loss: 0.1333 - val_accuracy: 0.9634 - 2s/epoch - 12ms/step
# Epoch 81/100
#
# Epoch 81: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0140 - accuracy: 0.9952 - val_loss: 0.1054 - val_accuracy: 0.9603 - 2s/epoch - 12ms/step
# Epoch 82/100
#
# Epoch 82: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0111 - accuracy: 0.9959 - val_loss: 0.1012 - val_accuracy: 0.9746 - 2s/epoch - 12ms/step
# Epoch 83/100
#
# Epoch 83: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0115 - accuracy: 0.9965 - val_loss: 0.1596 - val_accuracy: 0.9555 - 2s/epoch - 11ms/step
# Epoch 84/100
#
# Epoch 84: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0148 - accuracy: 0.9954 - val_loss: 0.1605 - val_accuracy: 0.9475 - 2s/epoch - 11ms/step
# Epoch 85/100
#
# Epoch 85: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0100 - accuracy: 0.9959 - val_loss: 0.1392 - val_accuracy: 0.9539 - 2s/epoch - 12ms/step
# Epoch 86/100
#
# Epoch 86: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0167 - accuracy: 0.9945 - val_loss: 0.1666 - val_accuracy: 0.9475 - 2s/epoch - 11ms/step
# Epoch 87/100
#
# Epoch 87: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0169 - accuracy: 0.9947 - val_loss: 0.1724 - val_accuracy: 0.9475 - 2s/epoch - 11ms/step
# Epoch 88/100
#
# Epoch 88: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0105 - accuracy: 0.9966 - val_loss: 0.0880 - val_accuracy: 0.9762 - 2s/epoch - 10ms/step
# Epoch 89/100
#
# Epoch 89: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0143 - accuracy: 0.9968 - val_loss: 0.0934 - val_accuracy: 0.9650 - 2s/epoch - 11ms/step
# Epoch 90/100
#
# Epoch 90: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0126 - accuracy: 0.9963 - val_loss: 0.1133 - val_accuracy: 0.9571 - 2s/epoch - 11ms/step
# Epoch 91/100
#
# Epoch 91: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0142 - accuracy: 0.9959 - val_loss: 0.1154 - val_accuracy: 0.9618 - 2s/epoch - 11ms/step
# Epoch 92/100
#
# Epoch 92: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0124 - accuracy: 0.9963 - val_loss: 0.1568 - val_accuracy: 0.9491 - 2s/epoch - 11ms/step
# Epoch 93/100
#
# Epoch 93: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0143 - accuracy: 0.9952 - val_loss: 0.1557 - val_accuracy: 0.9475 - 2s/epoch - 11ms/step
# Epoch 94/100
#
# Epoch 94: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0145 - accuracy: 0.9956 - val_loss: 0.1904 - val_accuracy: 0.9523 - 2s/epoch - 11ms/step
# Epoch 95/100
#
# Epoch 95: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0166 - accuracy: 0.9942 - val_loss: 0.1422 - val_accuracy: 0.9491 - 2s/epoch - 11ms/step
# Epoch 96/100
#
# Epoch 96: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0171 - accuracy: 0.9949 - val_loss: 0.1333 - val_accuracy: 0.9571 - 2s/epoch - 11ms/step
# Epoch 97/100
#
# Epoch 97: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0115 - accuracy: 0.9966 - val_loss: 0.1458 - val_accuracy: 0.9634 - 2s/epoch - 11ms/step
# Epoch 98/100
#
# Epoch 98: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0156 - accuracy: 0.9950 - val_loss: 0.1811 - val_accuracy: 0.9444 - 2s/epoch - 11ms/step
# Epoch 99/100
#
# Epoch 99: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0163 - accuracy: 0.9938 - val_loss: 0.1067 - val_accuracy: 0.9682 - 2s/epoch - 11ms/step
# Epoch 100/100
#
# Epoch 100: val_loss did not improve from 0.07672
# 177/177 - 2s - loss: 0.0210 - accuracy: 0.9936 - val_loss: 0.1385 - val_accuracy: 0.9587 - 2s/epoch - 12ms/step
# 197/197 [==============================] - 2s 6ms/step
# 22/22 [==============================] - 0s 5ms/step
# Evaluate on training data
# 197/197 [==============================] - 1s 6ms/step - loss: 0.0320 - accuracy: 0.9897
# test loss, test acc: [0.03196803107857704, 0.9896529912948608]
# Evaluate on test data
# 22/22 [==============================] - 0s 6ms/step - loss: 0.2754 - accuracy: 0.9140
# test loss, test acc: [0.275374174118042, 0.9140400886535645]

# %%
dict_test_result
# Out:
#    train_accu  train_precision  train_recall  train_f1  test_accu  \
# 0    0.994429         0.994447      0.994429  0.994428   0.909742
# 1    0.992359         0.992405      0.992359  0.992359   0.915473
# 2    0.994269         0.994273      0.994269  0.994269   0.938395
# 3    0.992837         0.992839      0.992837  0.992837   0.928367
# 4    0.979147         0.979348      0.979147  0.979145   0.931232
# 5    0.986310         0.986383      0.986310  0.986310   0.928367
# 6    0.986628         0.986636      0.986628  0.986628   0.938395
# 7    0.993473         0.993485      0.993473  0.993473   0.931232
# 8    0.994747         0.994747      0.994747  0.994747   0.929799
# 9    0.989653         0.989671      0.989653  0.989653   0.914040
#
#    test_precision  test_recall   test_f1  Input   RTE
# 0        0.915362     0.909742  0.909996     39  7461
# 1        0.923786     0.915473  0.915826     39  7461
# 2        0.940206     0.938395  0.938451     39  7461
# 3        0.932570     0.928367  0.928518     39  7461
# 4        0.935978     0.931232  0.931396     39  7461
# 5        0.930731     0.928367  0.928452     39  7461
# 6        0.940206     0.938395  0.938451     39  7461
# 7        0.935978     0.931232  0.931396     39  7461
# 8        0.934828     0.929799  0.929976     39  7461
# 9        0.917735     0.914040  0.914199     39  7461

# %%
best = 8

dbfile = open('rte-tree-{0}.pickle'.format(best), 'rb')    
rte = pickle.load(dbfile)
dbfile.close()

dbfile = open('sdp-classifier-tree-{0}.pickle'.format(best), 'rb')    
sdp_classifier = pickle.load(dbfile)
dbfile.close()
sdp_classifier.load_weights('sdp-tree-{0}.weights.best.keras'.format(best))

# %%
X_sparse_embedding = rte.transform(X_norm_scale_smote)
#X_norm_scale_pca = pca.transform(X_sparse_embedding.toarray())
#X_norm_scale_pca = scaler_pca.fit_transform(X_norm_scale_pca)

# %% [raw]
# X_norm_scale.shape, X_norm_scale_smote.shape, X_sparse_embedding.toarray().shape

# %%
print("Evaluate on training data")
results = sdp_classifier.evaluate([X_sparse_embedding.toarray(), X_norm_scale_smote], y_smote, batch_size=128)
print("test loss, test acc:", results)
# Out:
# Evaluate on training data
# 55/55 [==============================] - 2s 4ms/step - loss: 0.0505 - accuracy: 0.9883
# test loss, test acc: [0.05054587870836258, 0.9882521629333496]

# %%
from sklearn.metrics import classification_report

results = sdp_classifier.predict([X_sparse_embedding.toarray(),X_norm_scale_smote])
results=np.round(results)
print(classification_report(y_smote,results))
# Out:
# 219/219 [==============================] - 1s 3ms/step
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.98      0.99      3490
#          1.0       0.98      0.99      0.99      3490
#
#     accuracy                           0.99      6980
#    macro avg       0.99      0.99      0.99      6980
# weighted avg       0.99      0.99      0.99      6980

# %%
list_result = []

for label in my_dataset:
    dt = adjustdataset(my_dataset[label], df)
    pt, scaler, imputer, X_norm_scale_dt, y_dt = preprocessing(dt,imputer,pt, scaler, show=False)
    X_sparse_embedding_dt = rte.transform(X_norm_scale_dt)
    results = sdp_classifier.predict([X_sparse_embedding_dt.toarray(),X_norm_scale_dt])
    result  = np.round(results)
    list_result.append({'label':label, 'accuracy' : accuracy_score(y_dt, result),'precision':precision_score(y_dt, result, average='weighted'),
                  'recall': recall_score(y_dt, result, average='weighted'), 'f1-score':f1_score(y_dt, result, average='weighted')})
    heat_map(y_dt,result,label)
# Out:
# 131/131 [==============================] - 1s 3ms/step
# 126/126 [==============================] - 0s 3ms/step
# 124/124 [==============================] - 0s 3ms/step
# 128/128 [==============================] - 0s 3ms/step
# 142/142 [==============================] - 1s 4ms/step
# 153/153 [==============================] - 0s 2ms/step
# 160/160 [==============================] - 0s 2ms/step
# 173/173 [==============================] - 0s 2ms/step
# 143/143 [==============================] - 0s 2ms/step
# 362/362 [==============================] - 1s 3ms/step
# 157/157 [==============================] - 1s 3ms/step
# 181/181 [==============================] - 1s 3ms/step
# 124/124 [==============================] - 1s 4ms/step
# 122/122 [==============================] - 0s 3ms/step
# 124/124 [==============================] - 1s 4ms/step
# 121/121 [==============================] - 0s 3ms/step
# 124/124 [==============================] - 1s 4ms/step

# %%
df_result = pd.DataFrame(list_result)
df_result
# Out:
#    label  accuracy  precision    recall  f1-score
# 0    cm1  0.963488   0.967786  0.963488  0.964931
# 1    kc3  0.967742   0.971050  0.967742  0.968846
# 2    mc2  0.970707   0.971837  0.970707  0.971157
# 3    mw1  0.970387   0.974042  0.970387  0.971537
# 4    pc1  0.953488   0.960970  0.953488  0.956017
# 5    pc3  0.933933   0.941146  0.933933  0.936768
# 6    pc4  0.933020   0.935676  0.933020  0.934213
# 7    pc5  0.879385   0.878582  0.879385  0.878976
# 8    pc2  0.984862   0.986463  0.984862  0.985314
# 9    jm1  0.710453   0.816336  0.710453  0.743094
# 10   kc1  0.912165   0.925354  0.912165  0.916842
# 11   mc1  0.981168   0.984850  0.981168  0.982161
# 12   ar1  0.972959   0.977297  0.972959  0.974190
# 13   ar3  0.979738   0.981892  0.979738  0.980368
# 14   ar4  0.973371   0.976404  0.973371  0.974307
# 15   ar5  0.980114   0.982146  0.980114  0.980709
# 16   ar6  0.975870   0.978659  0.975870  0.976706

# %%
df_result[['accuracy','precision','recall','f1-score']].mean()
# Out:
# accuracy     0.943697
# precision    0.953558
# recall       0.943697
# f1-score     0.946832
# dtype: float64

# %%
sdp_classifier.summary()
# Out:
# Model: "model_48"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  X_train1 (InputLayer)       [(None, 7343)]               0         []
#
#  X_train2 (InputLayer)       [(None, 39)]                 0         []
#
#  X_train1_layer (Dense)      (None, 128)                  940032    ['X_train1[0][0]']
#
#  X_train2_layer (Dense)      (None, 128)                  5120      ['X_train2[0][0]']
#
#  batch_normalization_193 (B  (None, 128)                  512       ['X_train1_layer[0][0]']
#  atchNormalization)
#
#  batch_normalization_195 (B  (None, 128)                  512       ['X_train2_layer[0][0]']
#  atchNormalization)
#
#  dropout_193 (Dropout)       (None, 128)                  0         ['batch_normalization_193[0][0
#                                                                     ]']
#
#  dropout_195 (Dropout)       (None, 128)                  0         ['batch_normalization_195[0][0
#                                                                     ]']
#
#  concatenate_48 (Concatenat  (None, 256)                  0         ['dropout_193[0][0]',
#  e)                                                                  'dropout_195[0][0]']
#
#  classifier (Dense)          (None, 1)                    257       ['concatenate_48[0][0]']
#
# ==================================================================================================
# Total params: 946433 (3.61 MB)
# Trainable params: 945921 (3.61 MB)
# Non-trainable params: 512 (2.00 KB)
# __________________________________________________________________________________________________
