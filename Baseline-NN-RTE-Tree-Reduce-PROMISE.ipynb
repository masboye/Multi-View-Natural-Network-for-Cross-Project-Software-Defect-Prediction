# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.io import arff
from sklearn.model_selection import StratifiedKFold
import numpy as np
import pickle
from sklearn.metrics import accuracy_score, precision_score, recall_score
from tensorflow.keras import layers, losses
from tensorflow.keras.models import Model
from keras.callbacks import ModelCheckpoint
from sklearn.impute import KNNImputer
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import StandardScaler
from scipy.stats import norm
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score,f1_score,precision_score,recall_score, auc, roc_curve
from sklearn.metrics import make_scorer
from imblearn.over_sampling import SMOTE, RandomOverSampler
from sklearn.ensemble import RandomTreesEmbedding
from sklearn.decomposition import PCA
import os

# %% [raw]
# path_to_directory="PROMISE/"
# files = [arff for arff in os.listdir(path_to_directory) if arff.endswith(".arff")]
#
# def toCsv(content):
#     data = False
#     header = ""
#     newContent = []
#     for line in content:
#         if not data:
#             if "@attribute" in line:
#                 attri = line.split()
#                 columnName = attri[attri.index("@attribute")+1]
#                 header = header + columnName + ","
#             elif "@data" in line:
#                 data = True
#                 header = header[:-1]
#                 header += '\n'
#                 newContent.append(header)
#         else:
#             newContent.append(line)
#     return newContent

# %% [raw]
# # Main loop for reading and writing files
# for zzzz,file in enumerate(files):
#     with open(path_to_directory+file , "r") as inFile:
#         content = inFile.readlines()
#         name,ext = os.path.splitext(inFile.name)
#         new = toCsv(content)
#         with open(name+".csv", "w") as outFile:
#             outFile.writelines(new)

# %%
ant = pd.read_csv('PROMISE/ant-1.7.csv')
ant_1_3 = pd.read_csv('PROMISE/ant-1.3.csv')
ant_1_4 = pd.read_csv('PROMISE/ant-1.4.csv')
ant_1_5 = pd.read_csv('PROMISE/ant-1.5.csv')
ant_1_6 = pd.read_csv('PROMISE/ant-1.6.csv')

camel = pd.read_csv('PROMISE/camel-1.6.csv')
camel_1_0 = pd.read_csv('PROMISE/camel-1.0.csv')
camel_1_2 = pd.read_csv('PROMISE/camel-1.2.csv')
camel_1_4 = pd.read_csv('PROMISE/camel-1.4.csv')

ivy = pd.read_csv('PROMISE/ivy-1.2.csv')
ivy_1_0 = pd.read_csv('PROMISE/ivy-1.0.csv')
ivy_1_1 = pd.read_csv('PROMISE/ivy-1.1.csv')
ivy_2_0 = pd.read_csv('PROMISE/ivy-2.0.csv')

jedit = pd.read_csv('PROMISE/jedit-4.3.csv')
jedit_3_2 = pd.read_csv('PROMISE/jedit-3.2.csv')
jedit_4_0 = pd.read_csv('PROMISE/jedit-4.0.csv')
jedit_4_1 = pd.read_csv('PROMISE/jedit-4.1.csv')
jedit_4_2 = pd.read_csv('PROMISE/jedit-4.2.csv')

log4j = pd.read_csv('PROMISE/log4j-1.2.csv')
log4j_1_0 = pd.read_csv('PROMISE/log4j-1.0.csv')
log4j_1_1 = pd.read_csv('PROMISE/log4j-1.1.csv')

lucene = pd.read_csv('PROMISE/lucene-2.4.csv')
lucene_2_0 = pd.read_csv('PROMISE/lucene-2.0.csv')
lucene_2_2 = pd.read_csv('PROMISE/lucene-2.2.csv')

poi = pd.read_csv('PROMISE/poi-3.0.csv')
poi_1_5 = pd.read_csv('PROMISE/poi-1.5.csv')
poi_2_0 = pd.read_csv('PROMISE/poi-2.0.csv')
poi_2_5 = pd.read_csv('PROMISE/poi-2.5.csv')

synapse = pd.read_csv('PROMISE/synapse-1.2.csv')
synapse_1_0 = pd.read_csv('PROMISE/synapse-1.0.csv')
synapse_1_1 = pd.read_csv('PROMISE/synapse-1.1.csv')

velocity = pd.read_csv('PROMISE/velocity-1.6.csv')
velocity_1_4 = pd.read_csv('PROMISE/velocity-1.4.csv')
velocity_1_5 = pd.read_csv('PROMISE/velocity-1.5.csv')

xalan = pd.read_csv('PROMISE/xalan-2.7.csv')
xalan_2_4 = pd.read_csv('PROMISE/xalan-2.4.csv')
xalan_2_5 = pd.read_csv('PROMISE/xalan-2.5.csv')
xalan_2_6 = pd.read_csv('PROMISE/xalan-2.6.csv')

xerces = pd.read_csv('PROMISE/xerces-1.4.4.csv')
xerces_1_1 = pd.read_csv('PROMISE/xerces-1.1.csv')
xerces_1_2 = pd.read_csv('PROMISE/xerces-1.2.csv')
xerces_1_3 = pd.read_csv('PROMISE/xerces-1.3.csv')

# %%
list_ant = ['ant','ant_1_3','ant_1_4','ant_1_5','ant_1_6']
list_data_ant = [ant,ant_1_3,ant_1_4,ant_1_5,ant_1_6]

list_camel = ['camel','camel_1_0','camel_1_2','camel_1_4']
list_data_camel = [camel,camel_1_0,camel_1_2,camel_1_4]

list_ivy = ['ivy','ivy_1_0','ivy_1_1','ivy_2_0']
list_data_ivy = [ivy,ivy_1_0,ivy_1_1,ivy_2_0]

list_jedit = ['jedit','jedit_3_2','jedit_4_0','jedit_4_1','jedit_4_2']
list_data_jedit = [jedit,jedit_3_2,jedit_4_0,jedit_4_1,jedit_4_2]

list_log4j = ['log4j','log4j_1_0','log4j_1_1']
list_data_log4j = [log4j,log4j_1_0,log4j_1_1]

list_lucene = ['lucene','lucene_2_0','lucene_2_2']
list_data_lucene = [lucene,lucene_2_0,lucene_2_2]

list_poi = ['poi','poi_1_5','poi_2_0','poi_2_5']
list_data_poi = [poi,poi_1_5,poi_2_0,poi_2_5]

list_synapse = ['synapse','synapse_1_0','synapse_1_1']
list_data_synapse = [synapse,synapse_1_0,synapse_1_1]

list_velocity = ['velocity','velocity_1_4','velocity_1_5']
list_data_velocity = [velocity,velocity_1_4,velocity_1_5]

list_xalan = ['xalan','xalan_2_4','xalan_2_5','xalan_2_6']
list_data_xalan = [xalan,xalan_2_4,xalan_2_5,xalan_2_6]

list_xerces = ['xerces','xerces_1_1','xerces_1_2','xerces_1_3']
list_data_xerces = [xerces,xerces_1_1,xerces_1_2,xerces_1_3]

list_promise = list_ant + list_camel + list_ivy + list_jedit + list_log4j + list_lucene + list_poi + list_synapse + list_velocity + list_xalan +list_xerces
list_data_promise = list_data_ant + list_data_camel + list_data_ivy + list_data_jedit + list_data_log4j + list_data_lucene + list_data_poi + list_data_synapse + list_data_velocity + list_data_xalan +list_data_xerces

# %%
ant[ant['bug'] > 0]
# Out:
#                                                   name  wmc  dit  noc  cbo  \
# 4                org.apache.tools.ant.taskdefs.WaitFor    9    3    0    5
# 6                   org.apache.tools.zip.AsiExtraField   20    1    0    4
# 19   org.apache.tools.ant.types.resources.comparato...    3    4    0    5
# 25          org.apache.tools.ant.taskdefs.optional.Rpm   16    3    0   15
# 32                org.apache.tools.zip.ZipOutputStream   27    3    0    8
# ..                                                 ...  ...  ...  ...  ...
# 733                 org.apache.tools.ant.ProjectHelper   18    1    2   24
# 734        org.apache.tools.ant.listener.Log4jListener    8    1    0    7
# 738    org.apache.tools.ant.taskdefs.ManifestClassPath    6    3    0    6
# 740              org.apache.tools.ant.taskdefs.Javadoc   92    3    0   34
# 743        org.apache.tools.ant.taskdefs.compilers.Gcj    5    2    0    8
#
#      rfc  lcom  ca  ce  npm  ...       dam  moa       mfa       cam  ic  cbm  \
# 4     26    16   0   5    7  ...  1.000000    0  0.800000  0.388889   0    0
# 6     40   130   0   4   18  ...  1.000000    1  0.000000  0.284211   0    0
# 19    11     1   1   4    1  ...  1.000000    1  0.971429  0.750000   1    2
# 25    65    76   0  15   13  ...  1.000000    0  0.725490  0.311111   0    0
# 32   101   157   5   3   15  ...  0.888889    1  0.294118  0.183761   1    7
# ..   ...   ...  ..  ..  ...  ...       ...  ...       ...       ...  ..  ...
# 733   68   151  18   8   17  ...  0.125000    0  0.000000  0.152778   0    0
# 734   33     0   0   7    8  ...  0.250000    0  0.000000  0.937500   0    0
# 738   33     3   0   6    6  ...  1.000000    1  0.880952  0.333333   0    0
# 740  261  3726   8  34   81  ...  0.970588   11  0.291339  0.112476   2    2
# 743   34     8   1   7    3  ...  1.000000    0  0.884615  1.000000   0    0
#
#            amc  max_cc  avg_cc  bug
# 4    19.000000       2  1.0000    1
# 6    15.900000       3  1.1500    1
# 19   12.333333       3  1.0000    1
# 25   28.250000       9  1.5625    1
# 32   45.629630       4  1.1111    1
# ..         ...     ...     ...  ...
# 733  20.000000       4  1.5000    1
# 734  36.625000       5  3.0000    1
# 738  47.000000      14  3.1667    2
# 740  28.021739      15  1.5543    4
# 743  42.000000      11  3.4000    1
#
# [166 rows x 22 columns]

# %%
for dt in list_data_promise:
    dt.drop(index=dt.index[0], axis=0, inplace=True)
    dt['Defective'] = dt['bug']
    dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
    dt.loc[dt['Defective'] == 0, 'Defective'] = 'N'
    dt.drop('name',axis=1,inplace=True)
    dt.drop('bug',axis=1,inplace=True)
# Out:
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'
# /var/folders/pw/v332jpv14_v0w0p5xsgfb3v80000gn/T/ipykernel_24509/528308183.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Y' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   dt.loc[dt['Defective'] > 0 , 'Defective'] = 'Y'

# %%
list_dataset = [xerces_1_3]
label_dataset = ['ant']

list_test = list_data_promise
label_test = list_promise

my_index = range(0,len(list_test))
my_dataset = dict(zip(label_test,list_test))

df = list_dataset
df = pd.concat(df)
df
# Out:
#      wmc  dit  noc  cbo  rfc  lcom  ca  ce  npm     lcom3  ...  dam  moa  \
# 1     46    1    0   13   61   833  11   2   46  0.903704  ...  1.0    1
# 2      4    1    0    0    4     6   0   0    4  2.000000  ...  0.0    0
# 3      4    1    0    0    4     6   0   0    4  2.000000  ...  0.0    0
# 4     41    2    0   11   75   280   2   9   35  0.903947  ...  1.0   10
# 5     17    1    1    0   37   136   0   0   16  2.000000  ...  0.0    0
# ..   ...  ...  ...  ...  ...   ...  ..  ..  ...       ...  ...  ...  ...
# 448    3    1    0    0    3     3   0   0    3  2.000000  ...  0.0    0
# 449   11    1    1    1   18    15   1   0   11  0.500000  ...  1.0    0
# 450    8    1    0    2   14     0   2   0    7  0.357143  ...  1.0    0
# 451    3    3    0    0    4     1   0   0    2  0.500000  ...  0.0    0
# 452    2    3    0    0    4     1   0   0    2  2.000000  ...  0.0    0
#
#           mfa       cam  ic  cbm         amc  max_cc  avg_cc  Defective
# 1    0.000000  0.220497   0    0   11.195652      12  1.6522          N
# 2    0.000000  0.750000   0    0    0.000000       1  1.0000          N
# 3    0.000000  0.500000   0    0    0.000000       1  1.0000          N
# 4    0.487179  0.306620   1    7   28.414634       3  1.1951          N
# 5    0.000000  0.308824   0    0   13.941176       1  0.9412          N
# ..        ...       ...  ..  ...         ...     ...     ...        ...
# 448  0.000000  1.000000   0    0    0.000000       1  1.0000          N
# 449  0.000000  0.431818   0    0    8.090909       1  0.9091          N
# 450  0.000000  0.625000   0    0   16.750000       4  1.3750          N
# 451  0.974359  1.000000   0    0  159.000000       1  0.3333          Y
# 452  1.000000  0.750000   0    0    3.500000       0  0.0000          N
#
# [452 rows x 21 columns]

# %%
def adjustdataset(dt,dataframe):
    dt_copy = dt.copy()
    counter = 0
    
    for col in dataframe.columns:
        if not col in dt.columns:
            #print("Not Exist ",col)
            dt_copy.insert(counter,col,-1)
        counter += 1

    return pd.concat([dt_copy[dataframe.columns], dataframe])

# %%
def adjustdataset_list(list_df):
    dt_result = list_df.pop()
    
    for dt in list_df:
        if len(dt.columns) > len(dt_result.columns):
            dt_result = adjustdataset(dt,dt_result)
        else:
            dt_result = adjustdataset(dt_result,dt)    
    return dt_result

# %%
def show_distribution(df, columns):
    
    counter = 0
    # Create a figure and a grid of subplots with 4 rows and 10 columns
    fig, axes = plt.subplots(5, 8, figsize=(20, 8))
    
    # Loop through each subplot and add content (optional)
    for i in range(5):
        for j in range(8):
            try:
                ax = axes[i, j]
                ax.set_title(columns[counter])
                ax.plot(df[columns[counter]].sort_values(), norm.pdf(df[columns[counter]].sort_values(), df[columns[counter]].mean(), df[columns[counter]].std())) 
                ax.set_xticks([])
                ax.set_yticks([])
                counter += 1
            except:
                pass

# Adjust layout to prevent overlapping titles/labels
plt.tight_layout()

# Display the plot
plt.show()

# %%
def preprocessing(dataframe, imputer = None, pt = None, scaler = None, show = True):
    
    df = dataframe.copy()
    
    df.loc[(df['Defective'] == 'N'),'Defective']=0
    df.loc[(df['Defective'] == 'Y'),'Defective']=1
    
    change_dtypes = ['Defective']
    dict_dtypes = {d:'int64' for d in change_dtypes }
    df = df.astype(dict_dtypes)
    
    columns = df.columns
    
    if show:
        show_distribution(df,df.columns)
    
    if imputer :
        df = imputer.transform(df)
    else:
        imputer = KNNImputer(n_neighbors=2)
        df = imputer.fit_transform(df)
    
    df = pd.DataFrame(df)
    df.columns = columns
    
    if show:
        show_distribution(df,df.columns)
    
    y = df['Defective']
    X = df.drop('Defective',axis=1)
    
    if pt:
        X_norm = pt.transform(X)
    else:
        pt = PowerTransformer()
        X_norm = pt.fit_transform(X)
    
    X_norm = pd.DataFrame(X)
    X_norm.columns = X.columns
    
    if show:
        show_distribution(X_norm,X_norm.columns)

    if scaler:
        X_norm_scale = scaler.transform(X_norm)
    else:
        scaler = StandardScaler()
        X_norm_scale = scaler.fit_transform(X_norm)
        
    return pt, scaler, imputer, X_norm_scale, y

# %%
def heat_map(y,result,title):
    import seaborn as sns
    from sklearn.metrics import confusion_matrix
    sns.set
    _, ax = plt.subplots(figsize=(10,10))
    ax = sns.heatmap(confusion_matrix(y, result), annot=True, fmt='d', cmap= ['#09acec','#089dd9','#078fc5','#0681b1','#05668d','#05368d'], annot_kws={"size": 40, "weight": "bold"})  
    labels = ['No Defect','Defect']
    ax.set_xticklabels(labels, fontsize=30);
    ax.set_yticklabels(labels, fontsize=30,rotation=0);
    ax.set_ylabel('Prediction', fontsize=30,rotation=0);
    ax.set_xlabel('Ground Truth', fontsize=30) #0,1
    ax.set_title(title)

# %%
def score(y,result):
    accuracy = accuracy_score(y, result)
    f1 = f1_score(y, result, average='weighted')
    precision = precision_score(y, result, average='weighted')
    recall = recall_score(y, result, average='weighted')
    print("Accuracy = " , accuracy, " Precision = ",precision, " Recall = ",recall, " F1-Score = ",f1 )

# %%
from sklearn.metrics import make_scorer

scorers = {
            'f1_score': make_scorer(f1_score, average='micro'),
            'precision_score': make_scorer(precision_score, average='micro'),
            'recall_score': make_scorer(recall_score, average='micro'),
            'accuracy_score': make_scorer(accuracy_score)
          }
search_space={}

# %%
pt, scaler, imputer, X_norm_scale, y = preprocessing(df, show=False)
#X_norm_scale_smote, y_smote = X_norm_scale, y
smote = SMOTE(random_state=42)
X_norm_scale_smote, y_smote = smote.fit_resample(X_norm_scale, y)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/base.py:474: FutureWarning: `BaseEstimator._validate_data` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation.validate_data` instead. This function becomes public and is part of the scikit-learn developer API.
#   warnings.warn(

# %% [raw]
# smote = SMOTE(random_state=42)
# X_norm_scale_smote, y_smote = smote.fit_resample(X_norm_scale, y)
# X_norm_scale_smote, y_smote = X_norm_scale, y

# %%
counter = 0
histories = []

lst_accu_stratified = []
lst_f1_stratified = []
lst_precision_stratified = []
lst_recall_stratified = []
lst_auc_stratified = []

lst_accu_stratified_val = []
lst_f1_stratified_val = []
lst_precision_stratified_val = []
lst_recall_stratified_val = []
lst_auc_stratified_val = []

skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=19)

for train_index, test_index in skf.split(X_norm_scale_smote, y_smote):

    x_train_fold, x_test_fold = X_norm_scale_smote[train_index], X_norm_scale_smote[test_index]
    y_train_fold, y_test_fold = y_smote[train_index], y_smote[test_index]
 
    rte = RandomTreesEmbedding(n_estimators=1000, random_state=0, max_depth=10).fit(x_train_fold)
    x_sparse_embedding_train = rte.transform(x_train_fold)
    x_sparse_embedding_test = rte.transform(x_test_fold)
    
    with open('rte-tree-promise-{0}.pickle'.format(counter), 'wb') as handle:
        pickle.dump(rte, handle, protocol=pickle.HIGHEST_PROTOCOL)
        
    from sklearn.manifold import Isomap
    manifold = Isomap(n_components=100)
    x_sparse_manifold_train = manifold.fit_transform(x_sparse_embedding_train)
    x_sparse_manifold_test = manifold.transform(x_sparse_embedding_test)
    
    with open('manifold-tree-promise-{0}.pickle'.format(counter), 'wb') as handle:
        pickle.dump(manifold, handle, protocol=pickle.HIGHEST_PROTOCOL)

    scaler2 = StandardScaler()
    x_sparse_manifold_train = scaler2.fit_transform(x_sparse_manifold_train)
    x_sparse_manifold_test = scaler2.transform(x_sparse_manifold_test)
    
    with open('scaler-tree-promise-{0}.pickle'.format(counter), 'wb') as handle:
        pickle.dump(scaler2, handle, protocol=pickle.HIGHEST_PROTOCOL)
    
    input_X_train1 = layers.Input(
    shape=(x_sparse_manifold_train.shape[1],), name="X_train1")  
    
    input_X_train2 = layers.Input(shape=(x_train_fold.shape[1],), name="X_train2")

    layer_X_train1 = layers.Dense(64,activation='relu',name="X_train1_layer")(input_X_train1)
    layer_X_train1 = layers.BatchNormalization()(layer_X_train1)
    layer_X_train1 = layers.Dropout(0.3)(layer_X_train1)
    
    layer_X_train2 = layers.Dense(64,activation='relu',name="X_train2_layer")(input_X_train2)
    layer_X_train2 = layers.BatchNormalization()(layer_X_train2)
    layer_X_train2 = layers.Dropout(0.1)(layer_X_train2)
    
    # Merge all available features into a single large vector via concatenation
    concat = layers.concatenate([layer_X_train1, layer_X_train2])

    layer_final = layers.Dense(1, activation='sigmoid', name="classifier")(concat)
    sdp_classifier = Model(inputs=[input_X_train1, input_X_train2], outputs=layer_final)

    checkpointer=ModelCheckpoint(filepath='sdp-tree-promise-{0}.weights.best.keras'.format(counter),verbose=1,save_best_only=True)

    sdp_classifier.compile(optimizer="adam", loss='binary_crossentropy', metrics=['accuracy'] )
    
    hist = sdp_classifier.fit([x_sparse_manifold_train,x_train_fold], y_train_fold, 
                    batch_size=32, epochs=100, validation_split= 0.1, callbacks=[checkpointer], 
                    verbose=2, shuffle=True)
    
    with open('sdp-classifier-tree-promise-{0}.pickle'.format(counter), 'wb') as handle:
        pickle.dump(sdp_classifier, handle, protocol=pickle.HIGHEST_PROTOCOL)
    

    sdp_classifier.load_weights('sdp-tree-promise-{0}.weights.best.keras'.format(counter))

    histories.append(hist)

    results = sdp_classifier.predict([x_sparse_manifold_train,x_train_fold])
    results = np.round(results)
    
    lst_accu_stratified.append(accuracy_score(y_train_fold, results))
    lst_f1_stratified.append(f1_score(y_train_fold, results, average='weighted') )
    lst_precision_stratified.append(precision_score(results, y_train_fold, average='weighted') )
    lst_recall_stratified.append(recall_score(results, y_train_fold, average='weighted') )
    fpr, tpr, thresholds = roc_curve(y_train_fold, results)
    lst_auc_stratified.append(auc(fpr, tpr))
    
    results = sdp_classifier.predict([x_sparse_manifold_test,x_test_fold])
    results = np.round(results)
    
    lst_accu_stratified_val.append(accuracy_score(y_test_fold, results))
    lst_f1_stratified_val.append(f1_score(results, y_test_fold, average='weighted') )
    lst_precision_stratified_val.append(precision_score(results, y_test_fold, average='weighted') )
    lst_recall_stratified_val.append(recall_score(results, y_test_fold, average='weighted') )
    fpr, tpr, thresholds = roc_curve(y_test_fold, results)
    lst_auc_stratified_val.append(auc(fpr, tpr))

    print("Evaluate on training data")
    results = sdp_classifier.evaluate([x_sparse_manifold_train, x_train_fold], y_train_fold)
    print("test loss, test acc:", results)

    print("Evaluate on test data")
    results = sdp_classifier.evaluate([x_sparse_manifold_test , x_test_fold], y_test_fold)
    print("test loss, test acc:", results)
    counter += 1
    

dict_test = {  "train_accu":lst_accu_stratified, 
               "train_precision":lst_precision_stratified, "train_recall":lst_recall_stratified,
               "train_auc":lst_auc_stratified, "train_f1":lst_f1_stratified,
             
               "test_accu":lst_accu_stratified_val, 
               "test_precision":lst_precision_stratified_val, "test_recall":lst_recall_stratified_val, 
               "test_auc":lst_auc_stratified_val, "test_f1":lst_f1_stratified_val,
               "Input": x_train_fold.shape[1], "RTE": x_sparse_manifold_train.shape[1]}

dict_test_result = pd.DataFrame.from_dict(dict_test)
dict_test_result.to_csv("hasil.csv")

with open('histories-tree-manifold-promise.pickle'.format(counter), 'wb') as handle:
        pickle.dump(histories, handle, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/manifold/_isomap.py:384: UserWarning: The number of connected components of the neighbors graph is 4 > 1. Completing the graph to fit Isomap might be slow. Increase the number of neighbors to avoid this issue.
#   self._fit_transform(X)
# /opt/anaconda3/lib/python3.11/site-packages/scipy/sparse/_index.py:100: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.59668, saving model to sdp-tree-promise-0.weights.best.keras
# 20/20 - 1s - loss: 0.7451 - accuracy: 0.6468 - val_loss: 0.5967 - val_accuracy: 0.6522 - 1s/epoch - 66ms/step
# Epoch 2/100
#
# Epoch 2: val_loss improved from 0.59668 to 0.52242, saving model to sdp-tree-promise-0.weights.best.keras
# 20/20 - 0s - loss: 0.5372 - accuracy: 0.7403 - val_loss: 0.5224 - val_accuracy: 0.7101 - 109ms/epoch - 5ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 0.52242 to 0.50914, saving model to sdp-tree-promise-0.weights.best.keras
# 20/20 - 0s - loss: 0.4204 - accuracy: 0.8145 - val_loss: 0.5091 - val_accuracy: 0.7101 - 112ms/epoch - 6ms/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 0.50914 to 0.46435, saving model to sdp-tree-promise-0.weights.best.keras
# 20/20 - 0s - loss: 0.3693 - accuracy: 0.8355 - val_loss: 0.4644 - val_accuracy: 0.7536 - 109ms/epoch - 5ms/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 0.46435 to 0.43034, saving model to sdp-tree-promise-0.weights.best.keras
# 20/20 - 0s - loss: 0.3279 - accuracy: 0.8452 - val_loss: 0.4303 - val_accuracy: 0.8116 - 127ms/epoch - 6ms/step
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.43034 to 0.39511, saving model to sdp-tree-promise-0.weights.best.keras
# 20/20 - 0s - loss: 0.2885 - accuracy: 0.8758 - val_loss: 0.3951 - val_accuracy: 0.8406 - 103ms/epoch - 5ms/step
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.39511 to 0.35945, saving model to sdp-tree-promise-0.weights.best.keras
# 20/20 - 0s - loss: 0.2757 - accuracy: 0.8855 - val_loss: 0.3594 - val_accuracy: 0.8406 - 100ms/epoch - 5ms/step
# Epoch 8/100
#
# Epoch 8: val_loss improved from 0.35945 to 0.32963, saving model to sdp-tree-promise-0.weights.best.keras
# 20/20 - 0s - loss: 0.2496 - accuracy: 0.8935 - val_loss: 0.3296 - val_accuracy: 0.8551 - 102ms/epoch - 5ms/step
# Epoch 9/100
#
# Epoch 9: val_loss improved from 0.32963 to 0.30137, saving model to sdp-tree-promise-0.weights.best.keras
# 20/20 - 0s - loss: 0.2149 - accuracy: 0.9194 - val_loss: 0.3014 - val_accuracy: 0.8696 - 102ms/epoch - 5ms/step
# Epoch 10/100
#
# Epoch 10: val_loss improved from 0.30137 to 0.28743, saving model to sdp-tree-promise-0.weights.best.keras
# 20/20 - 0s - loss: 0.2043 - accuracy: 0.9339 - val_loss: 0.2874 - val_accuracy: 0.8986 - 103ms/epoch - 5ms/step
# Epoch 11/100
#
# Epoch 11: val_loss improved from 0.28743 to 0.26497, saving model to sdp-tree-promise-0.weights.best.keras
# 20/20 - 0s - loss: 0.1985 - accuracy: 0.9306 - val_loss: 0.2650 - val_accuracy: 0.8986 - 102ms/epoch - 5ms/step
# Epoch 12/100
#
# Epoch 12: val_loss improved from 0.26497 to 0.25504, saving model to sdp-tree-promise-0.weights.best.keras
# 20/20 - 0s - loss: 0.1701 - accuracy: 0.9516 - val_loss: 0.2550 - val_accuracy: 0.8986 - 106ms/epoch - 5ms/step
# Epoch 13/100
#
# Epoch 13: val_loss improved from 0.25504 to 0.23458, saving model to sdp-tree-promise-0.weights.best.keras
# 20/20 - 0s - loss: 0.1657 - accuracy: 0.9484 - val_loss: 0.2346 - val_accuracy: 0.9130 - 102ms/epoch - 5ms/step
# Epoch 14/100
#
# Epoch 14: val_loss improved from 0.23458 to 0.22579, saving model to sdp-tree-promise-0.weights.best.keras
# 20/20 - 0s - loss: 0.1684 - accuracy: 0.9403 - val_loss: 0.2258 - val_accuracy: 0.9130 - 101ms/epoch - 5ms/step
# Epoch 15/100
#
# Epoch 15: val_loss improved from 0.22579 to 0.21691, saving model to sdp-tree-promise-0.weights.best.keras
# 20/20 - 0s - loss: 0.1644 - accuracy: 0.9387 - val_loss: 0.2169 - val_accuracy: 0.9275 - 106ms/epoch - 5ms/step
# Epoch 16/100
#
# Epoch 16: val_loss improved from 0.21691 to 0.21372, saving model to sdp-tree-promise-0.weights.best.keras
# 20/20 - 0s - loss: 0.1513 - accuracy: 0.9500 - val_loss: 0.2137 - val_accuracy: 0.9130 - 117ms/epoch - 6ms/step
# Epoch 17/100
#
# Epoch 17: val_loss improved from 0.21372 to 0.20469, saving model to sdp-tree-promise-0.weights.best.keras
# 20/20 - 0s - loss: 0.1376 - accuracy: 0.9532 - val_loss: 0.2047 - val_accuracy: 0.9130 - 110ms/epoch - 5ms/step
# Epoch 18/100
#
# Epoch 18: val_loss improved from 0.20469 to 0.19389, saving model to sdp-tree-promise-0.weights.best.keras
# 20/20 - 0s - loss: 0.1223 - accuracy: 0.9565 - val_loss: 0.1939 - val_accuracy: 0.9130 - 108ms/epoch - 5ms/step
# Epoch 19/100
#
# Epoch 19: val_loss improved from 0.19389 to 0.19144, saving model to sdp-tree-promise-0.weights.best.keras
# 20/20 - 0s - loss: 0.1220 - accuracy: 0.9597 - val_loss: 0.1914 - val_accuracy: 0.9275 - 145ms/epoch - 7ms/step
# Epoch 20/100
#
# Epoch 20: val_loss improved from 0.19144 to 0.17584, saving model to sdp-tree-promise-0.weights.best.keras
# 20/20 - 0s - loss: 0.1184 - accuracy: 0.9565 - val_loss: 0.1758 - val_accuracy: 0.9275 - 105ms/epoch - 5ms/step
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 0.17584
# 20/20 - 0s - loss: 0.1083 - accuracy: 0.9677 - val_loss: 0.1758 - val_accuracy: 0.9275 - 65ms/epoch - 3ms/step
# Epoch 22/100
#
# Epoch 22: val_loss improved from 0.17584 to 0.17465, saving model to sdp-tree-promise-0.weights.best.keras
# 20/20 - 0s - loss: 0.1107 - accuracy: 0.9677 - val_loss: 0.1746 - val_accuracy: 0.9275 - 108ms/epoch - 5ms/step
# Epoch 23/100
#
# Epoch 23: val_loss improved from 0.17465 to 0.17017, saving model to sdp-tree-promise-0.weights.best.keras
# 20/20 - 0s - loss: 0.1030 - accuracy: 0.9726 - val_loss: 0.1702 - val_accuracy: 0.9420 - 102ms/epoch - 5ms/step
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 0.17017
# 20/20 - 0s - loss: 0.0906 - accuracy: 0.9677 - val_loss: 0.1760 - val_accuracy: 0.9420 - 62ms/epoch - 3ms/step
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 0.17017
# 20/20 - 0s - loss: 0.0904 - accuracy: 0.9694 - val_loss: 0.1731 - val_accuracy: 0.9420 - 59ms/epoch - 3ms/step
# Epoch 26/100
#
# Epoch 26: val_loss improved from 0.17017 to 0.16445, saving model to sdp-tree-promise-0.weights.best.keras
# 20/20 - 0s - loss: 0.0977 - accuracy: 0.9661 - val_loss: 0.1645 - val_accuracy: 0.9420 - 99ms/epoch - 5ms/step
# Epoch 27/100
#
# Epoch 27: val_loss improved from 0.16445 to 0.15694, saving model to sdp-tree-promise-0.weights.best.keras
# 20/20 - 0s - loss: 0.0910 - accuracy: 0.9694 - val_loss: 0.1569 - val_accuracy: 0.9420 - 101ms/epoch - 5ms/step
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 0.15694
# 20/20 - 0s - loss: 0.0781 - accuracy: 0.9790 - val_loss: 0.1575 - val_accuracy: 0.9420 - 61ms/epoch - 3ms/step
# Epoch 29/100
#
# Epoch 29: val_loss improved from 0.15694 to 0.15396, saving model to sdp-tree-promise-0.weights.best.keras
# 20/20 - 0s - loss: 0.0841 - accuracy: 0.9710 - val_loss: 0.1540 - val_accuracy: 0.9420 - 109ms/epoch - 5ms/step
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 0.15396
# 20/20 - 0s - loss: 0.0795 - accuracy: 0.9726 - val_loss: 0.1546 - val_accuracy: 0.9420 - 63ms/epoch - 3ms/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 0.15396
# 20/20 - 0s - loss: 0.0777 - accuracy: 0.9710 - val_loss: 0.1787 - val_accuracy: 0.9420 - 72ms/epoch - 4ms/step
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 0.15396
# 20/20 - 0s - loss: 0.0689 - accuracy: 0.9823 - val_loss: 0.1752 - val_accuracy: 0.9420 - 64ms/epoch - 3ms/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 0.15396
# 20/20 - 0s - loss: 0.0744 - accuracy: 0.9726 - val_loss: 0.1737 - val_accuracy: 0.9275 - 56ms/epoch - 3ms/step
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 0.15396
# 20/20 - 0s - loss: 0.0592 - accuracy: 0.9823 - val_loss: 0.1694 - val_accuracy: 0.9275 - 60ms/epoch - 3ms/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 0.15396
# 20/20 - 0s - loss: 0.0713 - accuracy: 0.9790 - val_loss: 0.1544 - val_accuracy: 0.9420 - 59ms/epoch - 3ms/step
# Epoch 36/100
#
# Epoch 36: val_loss did not improve from 0.15396
# 20/20 - 0s - loss: 0.0628 - accuracy: 0.9790 - val_loss: 0.1597 - val_accuracy: 0.9420 - 59ms/epoch - 3ms/step
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 0.15396
# 20/20 - 0s - loss: 0.0643 - accuracy: 0.9806 - val_loss: 0.1656 - val_accuracy: 0.9420 - 58ms/epoch - 3ms/step
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 0.15396
# 20/20 - 0s - loss: 0.0512 - accuracy: 0.9887 - val_loss: 0.1636 - val_accuracy: 0.9420 - 59ms/epoch - 3ms/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 0.15396
# 20/20 - 0s - loss: 0.0573 - accuracy: 0.9855 - val_loss: 0.1617 - val_accuracy: 0.9420 - 59ms/epoch - 3ms/step
# Epoch 40/100
#
# Epoch 40: val_loss did not improve from 0.15396
# 20/20 - 0s - loss: 0.0555 - accuracy: 0.9855 - val_loss: 0.1679 - val_accuracy: 0.9420 - 59ms/epoch - 3ms/step
# Epoch 41/100
#
# Epoch 41: val_loss did not improve from 0.15396
# 20/20 - 0s - loss: 0.0657 - accuracy: 0.9742 - val_loss: 0.1803 - val_accuracy: 0.9275 - 63ms/epoch - 3ms/step
# Epoch 42/100
#
# Epoch 42: val_loss did not improve from 0.15396
# 20/20 - 0s - loss: 0.0509 - accuracy: 0.9871 - val_loss: 0.1816 - val_accuracy: 0.9130 - 65ms/epoch - 3ms/step
# Epoch 43/100
#
# Epoch 43: val_loss did not improve from 0.15396
# 20/20 - 0s - loss: 0.0483 - accuracy: 0.9855 - val_loss: 0.1743 - val_accuracy: 0.9275 - 64ms/epoch - 3ms/step
# Epoch 44/100
#
# Epoch 44: val_loss did not improve from 0.15396
# 20/20 - 0s - loss: 0.0468 - accuracy: 0.9839 - val_loss: 0.1638 - val_accuracy: 0.9275 - 58ms/epoch - 3ms/step
# Epoch 45/100
#
# Epoch 45: val_loss improved from 0.15396 to 0.15094, saving model to sdp-tree-promise-0.weights.best.keras
# 20/20 - 0s - loss: 0.0622 - accuracy: 0.9758 - val_loss: 0.1509 - val_accuracy: 0.9420 - 97ms/epoch - 5ms/step
# Epoch 46/100
#
# Epoch 46: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0375 - accuracy: 0.9887 - val_loss: 0.1583 - val_accuracy: 0.9420 - 66ms/epoch - 3ms/step
# Epoch 47/100
#
# Epoch 47: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0395 - accuracy: 0.9919 - val_loss: 0.1632 - val_accuracy: 0.9275 - 58ms/epoch - 3ms/step
# Epoch 48/100
#
# Epoch 48: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0483 - accuracy: 0.9839 - val_loss: 0.1676 - val_accuracy: 0.9275 - 58ms/epoch - 3ms/step
# Epoch 49/100
#
# Epoch 49: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0484 - accuracy: 0.9839 - val_loss: 0.1931 - val_accuracy: 0.9275 - 139ms/epoch - 7ms/step
# Epoch 50/100
#
# Epoch 50: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0467 - accuracy: 0.9839 - val_loss: 0.1834 - val_accuracy: 0.9275 - 58ms/epoch - 3ms/step
# Epoch 51/100
#
# Epoch 51: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0583 - accuracy: 0.9839 - val_loss: 0.2008 - val_accuracy: 0.9275 - 58ms/epoch - 3ms/step
# Epoch 52/100
#
# Epoch 52: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0449 - accuracy: 0.9839 - val_loss: 0.1870 - val_accuracy: 0.9275 - 64ms/epoch - 3ms/step
# Epoch 53/100
#
# Epoch 53: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0497 - accuracy: 0.9806 - val_loss: 0.1896 - val_accuracy: 0.9275 - 64ms/epoch - 3ms/step
# Epoch 54/100
#
# Epoch 54: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0332 - accuracy: 0.9919 - val_loss: 0.1768 - val_accuracy: 0.9275 - 59ms/epoch - 3ms/step
# Epoch 55/100
#
# Epoch 55: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0367 - accuracy: 0.9887 - val_loss: 0.1713 - val_accuracy: 0.9275 - 59ms/epoch - 3ms/step
# Epoch 56/100
#
# Epoch 56: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0314 - accuracy: 0.9952 - val_loss: 0.1709 - val_accuracy: 0.9275 - 57ms/epoch - 3ms/step
# Epoch 57/100
#
# Epoch 57: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0505 - accuracy: 0.9790 - val_loss: 0.1788 - val_accuracy: 0.9275 - 59ms/epoch - 3ms/step
# Epoch 58/100
#
# Epoch 58: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0444 - accuracy: 0.9871 - val_loss: 0.1860 - val_accuracy: 0.9130 - 56ms/epoch - 3ms/step
# Epoch 59/100
#
# Epoch 59: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0332 - accuracy: 0.9903 - val_loss: 0.1628 - val_accuracy: 0.9275 - 57ms/epoch - 3ms/step
# Epoch 60/100
#
# Epoch 60: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0353 - accuracy: 0.9887 - val_loss: 0.1882 - val_accuracy: 0.9275 - 59ms/epoch - 3ms/step
# Epoch 61/100
#
# Epoch 61: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0535 - accuracy: 0.9806 - val_loss: 0.1901 - val_accuracy: 0.9130 - 59ms/epoch - 3ms/step
# Epoch 62/100
#
# Epoch 62: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0368 - accuracy: 0.9903 - val_loss: 0.1725 - val_accuracy: 0.9420 - 60ms/epoch - 3ms/step
# Epoch 63/100
#
# Epoch 63: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0235 - accuracy: 0.9935 - val_loss: 0.1756 - val_accuracy: 0.9420 - 58ms/epoch - 3ms/step
# Epoch 64/100
#
# Epoch 64: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0343 - accuracy: 0.9855 - val_loss: 0.1729 - val_accuracy: 0.9420 - 71ms/epoch - 4ms/step
# Epoch 65/100
#
# Epoch 65: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0307 - accuracy: 0.9919 - val_loss: 0.1787 - val_accuracy: 0.9420 - 65ms/epoch - 3ms/step
# Epoch 66/100
#
# Epoch 66: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0334 - accuracy: 0.9919 - val_loss: 0.1762 - val_accuracy: 0.9420 - 58ms/epoch - 3ms/step
# Epoch 67/100
#
# Epoch 67: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0330 - accuracy: 0.9903 - val_loss: 0.1802 - val_accuracy: 0.9275 - 61ms/epoch - 3ms/step
# Epoch 68/100
#
# Epoch 68: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0336 - accuracy: 0.9855 - val_loss: 0.1752 - val_accuracy: 0.9275 - 56ms/epoch - 3ms/step
# Epoch 69/100
#
# Epoch 69: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0329 - accuracy: 0.9919 - val_loss: 0.1828 - val_accuracy: 0.9420 - 60ms/epoch - 3ms/step
# Epoch 70/100
#
# Epoch 70: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0362 - accuracy: 0.9871 - val_loss: 0.2140 - val_accuracy: 0.9275 - 59ms/epoch - 3ms/step
# Epoch 71/100
#
# Epoch 71: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0473 - accuracy: 0.9871 - val_loss: 0.2013 - val_accuracy: 0.9420 - 56ms/epoch - 3ms/step
# Epoch 72/100
#
# Epoch 72: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0315 - accuracy: 0.9903 - val_loss: 0.1902 - val_accuracy: 0.9420 - 60ms/epoch - 3ms/step
# Epoch 73/100
#
# Epoch 73: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0357 - accuracy: 0.9887 - val_loss: 0.2108 - val_accuracy: 0.9420 - 57ms/epoch - 3ms/step
# Epoch 74/100
#
# Epoch 74: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0384 - accuracy: 0.9903 - val_loss: 0.1936 - val_accuracy: 0.9420 - 60ms/epoch - 3ms/step
# Epoch 75/100
#
# Epoch 75: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0239 - accuracy: 0.9968 - val_loss: 0.2010 - val_accuracy: 0.9420 - 63ms/epoch - 3ms/step
# Epoch 76/100
#
# Epoch 76: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0299 - accuracy: 0.9871 - val_loss: 0.2064 - val_accuracy: 0.9420 - 63ms/epoch - 3ms/step
# Epoch 77/100
#
# Epoch 77: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0253 - accuracy: 0.9952 - val_loss: 0.1996 - val_accuracy: 0.9275 - 59ms/epoch - 3ms/step
# Epoch 78/100
#
# Epoch 78: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0339 - accuracy: 0.9871 - val_loss: 0.1889 - val_accuracy: 0.9275 - 58ms/epoch - 3ms/step
# Epoch 79/100
#
# Epoch 79: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0259 - accuracy: 0.9935 - val_loss: 0.1905 - val_accuracy: 0.9275 - 58ms/epoch - 3ms/step
# Epoch 80/100
#
# Epoch 80: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0161 - accuracy: 0.9952 - val_loss: 0.1830 - val_accuracy: 0.9275 - 58ms/epoch - 3ms/step
# Epoch 81/100
#
# Epoch 81: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0337 - accuracy: 0.9887 - val_loss: 0.1742 - val_accuracy: 0.9275 - 62ms/epoch - 3ms/step
# Epoch 82/100
#
# Epoch 82: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0255 - accuracy: 0.9919 - val_loss: 0.1653 - val_accuracy: 0.9275 - 65ms/epoch - 3ms/step
# Epoch 83/100
#
# Epoch 83: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0305 - accuracy: 0.9903 - val_loss: 0.1823 - val_accuracy: 0.9275 - 110ms/epoch - 5ms/step
# Epoch 84/100
#
# Epoch 84: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0222 - accuracy: 0.9919 - val_loss: 0.1855 - val_accuracy: 0.9275 - 60ms/epoch - 3ms/step
# Epoch 85/100
#
# Epoch 85: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0310 - accuracy: 0.9887 - val_loss: 0.1738 - val_accuracy: 0.9275 - 59ms/epoch - 3ms/step
# Epoch 86/100
#
# Epoch 86: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0237 - accuracy: 0.9887 - val_loss: 0.2002 - val_accuracy: 0.9275 - 61ms/epoch - 3ms/step
# Epoch 87/100
#
# Epoch 87: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0285 - accuracy: 0.9903 - val_loss: 0.2139 - val_accuracy: 0.9275 - 59ms/epoch - 3ms/step
# Epoch 88/100
#
# Epoch 88: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0259 - accuracy: 0.9903 - val_loss: 0.2269 - val_accuracy: 0.9275 - 60ms/epoch - 3ms/step
# Epoch 89/100
#
# Epoch 89: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0182 - accuracy: 0.9968 - val_loss: 0.2076 - val_accuracy: 0.9275 - 58ms/epoch - 3ms/step
# Epoch 90/100
#
# Epoch 90: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0251 - accuracy: 0.9871 - val_loss: 0.2160 - val_accuracy: 0.9275 - 57ms/epoch - 3ms/step
# Epoch 91/100
#
# Epoch 91: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0257 - accuracy: 0.9903 - val_loss: 0.2234 - val_accuracy: 0.9275 - 62ms/epoch - 3ms/step
# Epoch 92/100
#
# Epoch 92: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0196 - accuracy: 0.9968 - val_loss: 0.2050 - val_accuracy: 0.9275 - 59ms/epoch - 3ms/step
# Epoch 93/100
#
# Epoch 93: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0249 - accuracy: 0.9903 - val_loss: 0.1868 - val_accuracy: 0.9275 - 58ms/epoch - 3ms/step
# Epoch 94/100
#
# Epoch 94: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0208 - accuracy: 0.9952 - val_loss: 0.2009 - val_accuracy: 0.9275 - 59ms/epoch - 3ms/step
# Epoch 95/100
#
# Epoch 95: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0175 - accuracy: 0.9984 - val_loss: 0.1939 - val_accuracy: 0.9275 - 58ms/epoch - 3ms/step
# Epoch 96/100
#
# Epoch 96: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0153 - accuracy: 0.9952 - val_loss: 0.2039 - val_accuracy: 0.9275 - 58ms/epoch - 3ms/step
# Epoch 97/100
#
# Epoch 97: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0263 - accuracy: 0.9952 - val_loss: 0.2059 - val_accuracy: 0.9275 - 59ms/epoch - 3ms/step
# Epoch 98/100
#
# Epoch 98: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0238 - accuracy: 0.9919 - val_loss: 0.2325 - val_accuracy: 0.9275 - 57ms/epoch - 3ms/step
# Epoch 99/100
#
# Epoch 99: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0230 - accuracy: 0.9935 - val_loss: 0.2151 - val_accuracy: 0.9275 - 62ms/epoch - 3ms/step
# Epoch 100/100
#
# Epoch 100: val_loss did not improve from 0.15094
# 20/20 - 0s - loss: 0.0267 - accuracy: 0.9935 - val_loss: 0.2065 - val_accuracy: 0.9275 - 57ms/epoch - 3ms/step
# 22/22 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# Evaluate on training data
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0388 - accuracy: 0.9898
# test loss, test acc: [0.03882809728384018, 0.9898403286933899]
# Evaluate on test data
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5821 - accuracy: 0.8442
# test loss, test acc: [0.5821475386619568, 0.8441558480262756]
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/manifold/_isomap.py:384: UserWarning: The number of connected components of the neighbors graph is 4 > 1. Completing the graph to fit Isomap might be slow. Increase the number of neighbors to avoid this issue.
#   self._fit_transform(X)
# /opt/anaconda3/lib/python3.11/site-packages/scipy/sparse/_index.py:100: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.82198, saving model to sdp-tree-promise-1.weights.best.keras
# 20/20 - 1s - loss: 0.8060 - accuracy: 0.5919 - val_loss: 0.8220 - val_accuracy: 0.4493 - 1s/epoch - 68ms/step
# Epoch 2/100
#
# Epoch 2: val_loss improved from 0.82198 to 0.72767, saving model to sdp-tree-promise-1.weights.best.keras
# 20/20 - 0s - loss: 0.5492 - accuracy: 0.7484 - val_loss: 0.7277 - val_accuracy: 0.4783 - 101ms/epoch - 5ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 0.72767 to 0.70619, saving model to sdp-tree-promise-1.weights.best.keras
# 20/20 - 0s - loss: 0.4323 - accuracy: 0.8226 - val_loss: 0.7062 - val_accuracy: 0.5652 - 103ms/epoch - 5ms/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 0.70619 to 0.68699, saving model to sdp-tree-promise-1.weights.best.keras
# 20/20 - 0s - loss: 0.3798 - accuracy: 0.8194 - val_loss: 0.6870 - val_accuracy: 0.5942 - 108ms/epoch - 5ms/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 0.68699 to 0.64556, saving model to sdp-tree-promise-1.weights.best.keras
# 20/20 - 0s - loss: 0.3497 - accuracy: 0.8435 - val_loss: 0.6456 - val_accuracy: 0.6522 - 109ms/epoch - 5ms/step
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.64556 to 0.57764, saving model to sdp-tree-promise-1.weights.best.keras
# 20/20 - 0s - loss: 0.2979 - accuracy: 0.8726 - val_loss: 0.5776 - val_accuracy: 0.7101 - 105ms/epoch - 5ms/step
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.57764 to 0.53709, saving model to sdp-tree-promise-1.weights.best.keras
# 20/20 - 0s - loss: 0.2783 - accuracy: 0.8903 - val_loss: 0.5371 - val_accuracy: 0.7391 - 112ms/epoch - 6ms/step
# Epoch 8/100
#
# Epoch 8: val_loss improved from 0.53709 to 0.51327, saving model to sdp-tree-promise-1.weights.best.keras
# 20/20 - 0s - loss: 0.2714 - accuracy: 0.8935 - val_loss: 0.5133 - val_accuracy: 0.7681 - 177ms/epoch - 9ms/step
# Epoch 9/100
#
# Epoch 9: val_loss improved from 0.51327 to 0.47940, saving model to sdp-tree-promise-1.weights.best.keras
# 20/20 - 0s - loss: 0.2459 - accuracy: 0.9113 - val_loss: 0.4794 - val_accuracy: 0.7826 - 99ms/epoch - 5ms/step
# Epoch 10/100
#
# Epoch 10: val_loss improved from 0.47940 to 0.42509, saving model to sdp-tree-promise-1.weights.best.keras
# 20/20 - 0s - loss: 0.2057 - accuracy: 0.9323 - val_loss: 0.4251 - val_accuracy: 0.7971 - 100ms/epoch - 5ms/step
# Epoch 11/100
#
# Epoch 11: val_loss improved from 0.42509 to 0.39742, saving model to sdp-tree-promise-1.weights.best.keras
# 20/20 - 0s - loss: 0.1912 - accuracy: 0.9435 - val_loss: 0.3974 - val_accuracy: 0.8261 - 108ms/epoch - 5ms/step
# Epoch 12/100
#
# Epoch 12: val_loss improved from 0.39742 to 0.38639, saving model to sdp-tree-promise-1.weights.best.keras
# 20/20 - 0s - loss: 0.1888 - accuracy: 0.9403 - val_loss: 0.3864 - val_accuracy: 0.8406 - 108ms/epoch - 5ms/step
# Epoch 13/100
#
# Epoch 13: val_loss improved from 0.38639 to 0.37639, saving model to sdp-tree-promise-1.weights.best.keras
# 20/20 - 0s - loss: 0.1773 - accuracy: 0.9484 - val_loss: 0.3764 - val_accuracy: 0.8406 - 102ms/epoch - 5ms/step
# Epoch 14/100
#
# Epoch 14: val_loss improved from 0.37639 to 0.36545, saving model to sdp-tree-promise-1.weights.best.keras
# 20/20 - 0s - loss: 0.1692 - accuracy: 0.9371 - val_loss: 0.3654 - val_accuracy: 0.8261 - 101ms/epoch - 5ms/step
# Epoch 15/100
#
# Epoch 15: val_loss improved from 0.36545 to 0.33334, saving model to sdp-tree-promise-1.weights.best.keras
# 20/20 - 0s - loss: 0.1468 - accuracy: 0.9532 - val_loss: 0.3333 - val_accuracy: 0.8406 - 105ms/epoch - 5ms/step
# Epoch 16/100
#
# Epoch 16: val_loss improved from 0.33334 to 0.30933, saving model to sdp-tree-promise-1.weights.best.keras
# 20/20 - 0s - loss: 0.1523 - accuracy: 0.9484 - val_loss: 0.3093 - val_accuracy: 0.8551 - 111ms/epoch - 6ms/step
# Epoch 17/100
#
# Epoch 17: val_loss did not improve from 0.30933
# 20/20 - 0s - loss: 0.1317 - accuracy: 0.9597 - val_loss: 0.3187 - val_accuracy: 0.8551 - 59ms/epoch - 3ms/step
# Epoch 18/100
#
# Epoch 18: val_loss improved from 0.30933 to 0.30094, saving model to sdp-tree-promise-1.weights.best.keras
# 20/20 - 0s - loss: 0.1167 - accuracy: 0.9661 - val_loss: 0.3009 - val_accuracy: 0.8406 - 100ms/epoch - 5ms/step
# Epoch 19/100
#
# Epoch 19: val_loss improved from 0.30094 to 0.29465, saving model to sdp-tree-promise-1.weights.best.keras
# 20/20 - 0s - loss: 0.1230 - accuracy: 0.9645 - val_loss: 0.2947 - val_accuracy: 0.8406 - 103ms/epoch - 5ms/step
# Epoch 20/100
#
# Epoch 20: val_loss improved from 0.29465 to 0.28738, saving model to sdp-tree-promise-1.weights.best.keras
# 20/20 - 0s - loss: 0.1027 - accuracy: 0.9726 - val_loss: 0.2874 - val_accuracy: 0.8406 - 100ms/epoch - 5ms/step
# Epoch 21/100
#
# Epoch 21: val_loss improved from 0.28738 to 0.27454, saving model to sdp-tree-promise-1.weights.best.keras
# 20/20 - 0s - loss: 0.1022 - accuracy: 0.9758 - val_loss: 0.2745 - val_accuracy: 0.8406 - 101ms/epoch - 5ms/step
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.27454
# 20/20 - 0s - loss: 0.1009 - accuracy: 0.9629 - val_loss: 0.2783 - val_accuracy: 0.8551 - 61ms/epoch - 3ms/step
# Epoch 23/100
#
# Epoch 23: val_loss improved from 0.27454 to 0.27159, saving model to sdp-tree-promise-1.weights.best.keras
# 20/20 - 0s - loss: 0.0948 - accuracy: 0.9742 - val_loss: 0.2716 - val_accuracy: 0.8551 - 102ms/epoch - 5ms/step
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0809 - accuracy: 0.9742 - val_loss: 0.2727 - val_accuracy: 0.8551 - 67ms/epoch - 3ms/step
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.1006 - accuracy: 0.9661 - val_loss: 0.2787 - val_accuracy: 0.8551 - 59ms/epoch - 3ms/step
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0753 - accuracy: 0.9823 - val_loss: 0.2971 - val_accuracy: 0.8551 - 61ms/epoch - 3ms/step
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0722 - accuracy: 0.9758 - val_loss: 0.3024 - val_accuracy: 0.8551 - 64ms/epoch - 3ms/step
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0669 - accuracy: 0.9823 - val_loss: 0.3044 - val_accuracy: 0.8551 - 62ms/epoch - 3ms/step
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0896 - accuracy: 0.9710 - val_loss: 0.3133 - val_accuracy: 0.8406 - 58ms/epoch - 3ms/step
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0677 - accuracy: 0.9855 - val_loss: 0.3215 - val_accuracy: 0.8406 - 65ms/epoch - 3ms/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0745 - accuracy: 0.9790 - val_loss: 0.3063 - val_accuracy: 0.8261 - 60ms/epoch - 3ms/step
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0592 - accuracy: 0.9790 - val_loss: 0.3073 - val_accuracy: 0.8261 - 62ms/epoch - 3ms/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0598 - accuracy: 0.9839 - val_loss: 0.3161 - val_accuracy: 0.8261 - 79ms/epoch - 4ms/step
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0437 - accuracy: 0.9903 - val_loss: 0.3057 - val_accuracy: 0.8406 - 57ms/epoch - 3ms/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0603 - accuracy: 0.9855 - val_loss: 0.3144 - val_accuracy: 0.8261 - 59ms/epoch - 3ms/step
# Epoch 36/100
#
# Epoch 36: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0659 - accuracy: 0.9806 - val_loss: 0.3087 - val_accuracy: 0.8551 - 56ms/epoch - 3ms/step
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0609 - accuracy: 0.9774 - val_loss: 0.3183 - val_accuracy: 0.8406 - 57ms/epoch - 3ms/step
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0401 - accuracy: 0.9935 - val_loss: 0.3005 - val_accuracy: 0.8551 - 56ms/epoch - 3ms/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0480 - accuracy: 0.9871 - val_loss: 0.3123 - val_accuracy: 0.8551 - 57ms/epoch - 3ms/step
# Epoch 40/100
#
# Epoch 40: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0492 - accuracy: 0.9871 - val_loss: 0.3233 - val_accuracy: 0.8551 - 57ms/epoch - 3ms/step
# Epoch 41/100
#
# Epoch 41: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0674 - accuracy: 0.9758 - val_loss: 0.3016 - val_accuracy: 0.8551 - 56ms/epoch - 3ms/step
# Epoch 42/100
#
# Epoch 42: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0362 - accuracy: 0.9919 - val_loss: 0.3024 - val_accuracy: 0.8551 - 58ms/epoch - 3ms/step
# Epoch 43/100
#
# Epoch 43: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0435 - accuracy: 0.9887 - val_loss: 0.3064 - val_accuracy: 0.8551 - 58ms/epoch - 3ms/step
# Epoch 44/100
#
# Epoch 44: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0411 - accuracy: 0.9919 - val_loss: 0.3201 - val_accuracy: 0.8551 - 57ms/epoch - 3ms/step
# Epoch 45/100
#
# Epoch 45: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0493 - accuracy: 0.9839 - val_loss: 0.3211 - val_accuracy: 0.8406 - 58ms/epoch - 3ms/step
# Epoch 46/100
#
# Epoch 46: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0404 - accuracy: 0.9919 - val_loss: 0.3246 - val_accuracy: 0.8406 - 56ms/epoch - 3ms/step
# Epoch 47/100
#
# Epoch 47: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0429 - accuracy: 0.9871 - val_loss: 0.2937 - val_accuracy: 0.8551 - 57ms/epoch - 3ms/step
# Epoch 48/100
#
# Epoch 48: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0415 - accuracy: 0.9887 - val_loss: 0.3115 - val_accuracy: 0.8406 - 57ms/epoch - 3ms/step
# Epoch 49/100
#
# Epoch 49: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0436 - accuracy: 0.9903 - val_loss: 0.3244 - val_accuracy: 0.8406 - 68ms/epoch - 3ms/step
# Epoch 50/100
#
# Epoch 50: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0325 - accuracy: 0.9919 - val_loss: 0.3154 - val_accuracy: 0.8406 - 67ms/epoch - 3ms/step
# Epoch 51/100
#
# Epoch 51: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0365 - accuracy: 0.9935 - val_loss: 0.3282 - val_accuracy: 0.8406 - 65ms/epoch - 3ms/step
# Epoch 52/100
#
# Epoch 52: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0382 - accuracy: 0.9871 - val_loss: 0.3405 - val_accuracy: 0.8406 - 55ms/epoch - 3ms/step
# Epoch 53/100
#
# Epoch 53: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0402 - accuracy: 0.9887 - val_loss: 0.3353 - val_accuracy: 0.8406 - 60ms/epoch - 3ms/step
# Epoch 54/100
#
# Epoch 54: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0281 - accuracy: 0.9968 - val_loss: 0.3535 - val_accuracy: 0.8406 - 55ms/epoch - 3ms/step
# Epoch 55/100
#
# Epoch 55: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0445 - accuracy: 0.9903 - val_loss: 0.3549 - val_accuracy: 0.8406 - 63ms/epoch - 3ms/step
# Epoch 56/100
#
# Epoch 56: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0256 - accuracy: 0.9968 - val_loss: 0.3548 - val_accuracy: 0.8406 - 58ms/epoch - 3ms/step
# Epoch 57/100
#
# Epoch 57: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0421 - accuracy: 0.9871 - val_loss: 0.3536 - val_accuracy: 0.8551 - 57ms/epoch - 3ms/step
# Epoch 58/100
#
# Epoch 58: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0449 - accuracy: 0.9806 - val_loss: 0.3611 - val_accuracy: 0.8406 - 57ms/epoch - 3ms/step
# Epoch 59/100
#
# Epoch 59: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0336 - accuracy: 0.9887 - val_loss: 0.4059 - val_accuracy: 0.8261 - 56ms/epoch - 3ms/step
# Epoch 60/100
#
# Epoch 60: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0337 - accuracy: 0.9919 - val_loss: 0.4002 - val_accuracy: 0.8406 - 57ms/epoch - 3ms/step
# Epoch 61/100
#
# Epoch 61: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0359 - accuracy: 0.9903 - val_loss: 0.3910 - val_accuracy: 0.8406 - 56ms/epoch - 3ms/step
# Epoch 62/100
#
# Epoch 62: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0186 - accuracy: 0.9984 - val_loss: 0.3940 - val_accuracy: 0.8406 - 57ms/epoch - 3ms/step
# Epoch 63/100
#
# Epoch 63: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0410 - accuracy: 0.9903 - val_loss: 0.3800 - val_accuracy: 0.8551 - 57ms/epoch - 3ms/step
# Epoch 64/100
#
# Epoch 64: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0253 - accuracy: 0.9968 - val_loss: 0.3660 - val_accuracy: 0.8551 - 59ms/epoch - 3ms/step
# Epoch 65/100
#
# Epoch 65: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0328 - accuracy: 0.9919 - val_loss: 0.3806 - val_accuracy: 0.8261 - 57ms/epoch - 3ms/step
# Epoch 66/100
#
# Epoch 66: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0262 - accuracy: 0.9935 - val_loss: 0.3772 - val_accuracy: 0.8406 - 56ms/epoch - 3ms/step
# Epoch 67/100
#
# Epoch 67: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0350 - accuracy: 0.9919 - val_loss: 0.3760 - val_accuracy: 0.8406 - 86ms/epoch - 4ms/step
# Epoch 68/100
#
# Epoch 68: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0301 - accuracy: 0.9935 - val_loss: 0.3799 - val_accuracy: 0.8406 - 56ms/epoch - 3ms/step
# Epoch 69/100
#
# Epoch 69: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0221 - accuracy: 0.9935 - val_loss: 0.3899 - val_accuracy: 0.8406 - 56ms/epoch - 3ms/step
# Epoch 70/100
#
# Epoch 70: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0364 - accuracy: 0.9887 - val_loss: 0.4043 - val_accuracy: 0.8406 - 59ms/epoch - 3ms/step
# Epoch 71/100
#
# Epoch 71: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0212 - accuracy: 0.9935 - val_loss: 0.4062 - val_accuracy: 0.8406 - 56ms/epoch - 3ms/step
# Epoch 72/100
#
# Epoch 72: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0330 - accuracy: 0.9919 - val_loss: 0.4043 - val_accuracy: 0.8261 - 60ms/epoch - 3ms/step
# Epoch 73/100
#
# Epoch 73: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0274 - accuracy: 0.9935 - val_loss: 0.4091 - val_accuracy: 0.8551 - 58ms/epoch - 3ms/step
# Epoch 74/100
#
# Epoch 74: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0200 - accuracy: 0.9968 - val_loss: 0.4070 - val_accuracy: 0.8551 - 60ms/epoch - 3ms/step
# Epoch 75/100
#
# Epoch 75: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0204 - accuracy: 0.9952 - val_loss: 0.4134 - val_accuracy: 0.8406 - 56ms/epoch - 3ms/step
# Epoch 76/100
#
# Epoch 76: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0223 - accuracy: 0.9952 - val_loss: 0.3921 - val_accuracy: 0.8406 - 58ms/epoch - 3ms/step
# Epoch 77/100
#
# Epoch 77: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0174 - accuracy: 0.9968 - val_loss: 0.3901 - val_accuracy: 0.8406 - 58ms/epoch - 3ms/step
# Epoch 78/100
#
# Epoch 78: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0229 - accuracy: 0.9919 - val_loss: 0.3901 - val_accuracy: 0.8261 - 56ms/epoch - 3ms/step
# Epoch 79/100
#
# Epoch 79: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0255 - accuracy: 0.9919 - val_loss: 0.3977 - val_accuracy: 0.8261 - 56ms/epoch - 3ms/step
# Epoch 80/100
#
# Epoch 80: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0202 - accuracy: 0.9935 - val_loss: 0.3995 - val_accuracy: 0.8406 - 57ms/epoch - 3ms/step
# Epoch 81/100
#
# Epoch 81: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0154 - accuracy: 0.9984 - val_loss: 0.4234 - val_accuracy: 0.8406 - 56ms/epoch - 3ms/step
# Epoch 82/100
#
# Epoch 82: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0156 - accuracy: 0.9952 - val_loss: 0.4249 - val_accuracy: 0.8406 - 55ms/epoch - 3ms/step
# Epoch 83/100
#
# Epoch 83: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0111 - accuracy: 1.0000 - val_loss: 0.4207 - val_accuracy: 0.8406 - 60ms/epoch - 3ms/step
# Epoch 84/100
#
# Epoch 84: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0237 - accuracy: 0.9919 - val_loss: 0.4167 - val_accuracy: 0.8551 - 58ms/epoch - 3ms/step
# Epoch 85/100
#
# Epoch 85: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0202 - accuracy: 0.9968 - val_loss: 0.4198 - val_accuracy: 0.8551 - 57ms/epoch - 3ms/step
# Epoch 86/100
#
# Epoch 86: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0200 - accuracy: 0.9952 - val_loss: 0.4182 - val_accuracy: 0.8551 - 58ms/epoch - 3ms/step
# Epoch 87/100
#
# Epoch 87: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0171 - accuracy: 0.9984 - val_loss: 0.4151 - val_accuracy: 0.8551 - 56ms/epoch - 3ms/step
# Epoch 88/100
#
# Epoch 88: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0352 - accuracy: 0.9887 - val_loss: 0.4323 - val_accuracy: 0.8406 - 58ms/epoch - 3ms/step
# Epoch 89/100
#
# Epoch 89: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0253 - accuracy: 0.9952 - val_loss: 0.4340 - val_accuracy: 0.8551 - 58ms/epoch - 3ms/step
# Epoch 90/100
#
# Epoch 90: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0223 - accuracy: 0.9887 - val_loss: 0.4430 - val_accuracy: 0.8551 - 60ms/epoch - 3ms/step
# Epoch 91/100
#
# Epoch 91: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0305 - accuracy: 0.9887 - val_loss: 0.4419 - val_accuracy: 0.8406 - 60ms/epoch - 3ms/step
# Epoch 92/100
#
# Epoch 92: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0178 - accuracy: 0.9952 - val_loss: 0.4393 - val_accuracy: 0.8551 - 58ms/epoch - 3ms/step
# Epoch 93/100
#
# Epoch 93: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0163 - accuracy: 0.9984 - val_loss: 0.4345 - val_accuracy: 0.8551 - 66ms/epoch - 3ms/step
# Epoch 94/100
#
# Epoch 94: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0263 - accuracy: 0.9887 - val_loss: 0.4358 - val_accuracy: 0.8551 - 63ms/epoch - 3ms/step
# Epoch 95/100
#
# Epoch 95: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0138 - accuracy: 0.9968 - val_loss: 0.4724 - val_accuracy: 0.8551 - 57ms/epoch - 3ms/step
# Epoch 96/100
#
# Epoch 96: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0162 - accuracy: 0.9952 - val_loss: 0.4786 - val_accuracy: 0.8406 - 56ms/epoch - 3ms/step
# Epoch 97/100
#
# Epoch 97: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0140 - accuracy: 0.9984 - val_loss: 0.4703 - val_accuracy: 0.8551 - 57ms/epoch - 3ms/step
# Epoch 98/100
#
# Epoch 98: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0163 - accuracy: 0.9952 - val_loss: 0.4597 - val_accuracy: 0.8551 - 58ms/epoch - 3ms/step
# Epoch 99/100
#
# Epoch 99: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0147 - accuracy: 0.9952 - val_loss: 0.4665 - val_accuracy: 0.8261 - 58ms/epoch - 3ms/step
# Epoch 100/100
#
# Epoch 100: val_loss did not improve from 0.27159
# 20/20 - 0s - loss: 0.0122 - accuracy: 0.9968 - val_loss: 0.4481 - val_accuracy: 0.8261 - 60ms/epoch - 3ms/step
# 22/22 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# Evaluate on training data
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0801 - accuracy: 0.9768
# test loss, test acc: [0.08013132214546204, 0.9767779111862183]
# Evaluate on test data
# 3/3 [==============================] - 0s 3ms/step - loss: 0.5602 - accuracy: 0.8182
# test loss, test acc: [0.5601599812507629, 0.8181818127632141]
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/manifold/_isomap.py:384: UserWarning: The number of connected components of the neighbors graph is 5 > 1. Completing the graph to fit Isomap might be slow. Increase the number of neighbors to avoid this issue.
#   self._fit_transform(X)
# /opt/anaconda3/lib/python3.11/site-packages/scipy/sparse/_index.py:100: SparseEfficiencyWarning: Changing the sparsity structure of a csr_matrix is expensive. lil_matrix is more efficient.
#   self._set_intXint(row, col, x.flat[0])
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.72333, saving model to sdp-tree-promise-2.weights.best.keras
# 20/20 - 1s - loss: 0.7583 - accuracy: 0.6065 - val_loss: 0.7233 - val_accuracy: 0.5507 - 1s/epoch - 66ms/step
# Epoch 2/100
#
# Epoch 2: val_loss improved from 0.72333 to 0.63611, saving model to sdp-tree-promise-2.weights.best.keras
# 20/20 - 0s - loss: 0.5601 - accuracy: 0.7403 - val_loss: 0.6361 - val_accuracy: 0.6522 - 107ms/epoch - 5ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 0.63611 to 0.59978, saving model to sdp-tree-promise-2.weights.best.keras
# 20/20 - 0s - loss: 0.4489 - accuracy: 0.8000 - val_loss: 0.5998 - val_accuracy: 0.6957 - 105ms/epoch - 5ms/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 0.59978 to 0.57399, saving model to sdp-tree-promise-2.weights.best.keras
# 20/20 - 0s - loss: 0.3988 - accuracy: 0.8113 - val_loss: 0.5740 - val_accuracy: 0.7101 - 112ms/epoch - 6ms/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 0.57399 to 0.53152, saving model to sdp-tree-promise-2.weights.best.keras
# 20/20 - 0s - loss: 0.3567 - accuracy: 0.8468 - val_loss: 0.5315 - val_accuracy: 0.7246 - 103ms/epoch - 5ms/step
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.53152 to 0.49218, saving model to sdp-tree-promise-2.weights.best.keras
# 20/20 - 0s - loss: 0.3385 - accuracy: 0.8677 - val_loss: 0.4922 - val_accuracy: 0.7971 - 107ms/epoch - 5ms/step
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.49218 to 0.44905, saving model to sdp-tree-promise-2.weights.best.keras
# 20/20 - 0s - loss: 0.3019 - accuracy: 0.8661 - val_loss: 0.4490 - val_accuracy: 0.7971 - 104ms/epoch - 5ms/step
# Epoch 8/100
#
# Epoch 8: val_loss improved from 0.44905 to 0.41653, saving model to sdp-tree-promise-2.weights.best.keras
# 20/20 - 0s - loss: 0.2672 - accuracy: 0.8935 - val_loss: 0.4165 - val_accuracy: 0.8116 - 102ms/epoch - 5ms/step
# Epoch 9/100
#
# Epoch 9: val_loss improved from 0.41653 to 0.38664, saving model to sdp-tree-promise-2.weights.best.keras
# 20/20 - 0s - loss: 0.2610 - accuracy: 0.9016 - val_loss: 0.3866 - val_accuracy: 0.8406 - 107ms/epoch - 5ms/step
# Epoch 10/100
#
# Epoch 10: val_loss improved from 0.38664 to 0.36423, saving model to sdp-tree-promise-2.weights.best.keras
# 20/20 - 0s - loss: 0.2371 - accuracy: 0.9081 - val_loss: 0.3642 - val_accuracy: 0.8406 - 102ms/epoch - 5ms/step
# Epoch 11/100
#
# Epoch 11: val_loss improved from 0.36423 to 0.35955, saving model to sdp-tree-promise-2.weights.best.keras
# 20/20 - 0s - loss: 0.2169 - accuracy: 0.9048 - val_loss: 0.3596 - val_accuracy: 0.8696 - 99ms/epoch - 5ms/step
# Epoch 12/100
#
# Epoch 12: val_loss improved from 0.35955 to 0.33750, saving model to sdp-tree-promise-2.weights.best.keras
# 20/20 - 0s - loss: 0.1973 - accuracy: 0.9371 - val_loss: 0.3375 - val_accuracy: 0.8841 - 100ms/epoch - 5ms/step
# Epoch 13/100
#
# Epoch 13: val_loss improved from 0.33750 to 0.32104, saving model to sdp-tree-promise-2.weights.best.keras
# 20/20 - 0s - loss: 0.2001 - accuracy: 0.9242 - val_loss: 0.3210 - val_accuracy: 0.8841 - 108ms/epoch - 5ms/step
# Epoch 14/100
#
# Epoch 14: val_loss improved from 0.32104 to 0.29926, saving model to sdp-tree-promise-2.weights.best.keras
# 20/20 - 0s - loss: 0.1926 - accuracy: 0.9290 - val_loss: 0.2993 - val_accuracy: 0.8841 - 104ms/epoch - 5ms/step
# Epoch 15/100
#
# Epoch 15: val_loss improved from 0.29926 to 0.29364, saving model to sdp-tree-promise-2.weights.best.keras
# 20/20 - 0s - loss: 0.1799 - accuracy: 0.9355 - val_loss: 0.2936 - val_accuracy: 0.8696 - 109ms/epoch - 5ms/step
# Epoch 16/100
#
# Epoch 16: val_loss improved from 0.29364 to 0.26748, saving model to sdp-tree-promise-2.weights.best.keras
# 20/20 - 0s - loss: 0.1849 - accuracy: 0.9371 - val_loss: 0.2675 - val_accuracy: 0.8986 - 101ms/epoch - 5ms/step
# Epoch 17/100
#
# Epoch 17: val_loss improved from 0.26748 to 0.26004, saving model to sdp-tree-promise-2.weights.best.keras
# 20/20 - 0s - loss: 0.1432 - accuracy: 0.9532 - val_loss: 0.2600 - val_accuracy: 0.8986 - 99ms/epoch - 5ms/step
# Epoch 18/100
#
# Epoch 18: val_loss improved from 0.26004 to 0.25160, saving model to sdp-tree-promise-2.weights.best.keras
# 20/20 - 0s - loss: 0.1629 - accuracy: 0.9468 - val_loss: 0.2516 - val_accuracy: 0.8841 - 103ms/epoch - 5ms/step
# Epoch 19/100
#
# Epoch 19: val_loss improved from 0.25160 to 0.24953, saving model to sdp-tree-promise-2.weights.best.keras
# 20/20 - 0s - loss: 0.1504 - accuracy: 0.9516 - val_loss: 0.2495 - val_accuracy: 0.8841 - 101ms/epoch - 5ms/step
# Epoch 20/100
#
# Epoch 20: val_loss improved from 0.24953 to 0.24078, saving model to sdp-tree-promise-2.weights.best.keras
# 20/20 - 0s - loss: 0.1392 - accuracy: 0.9516 - val_loss: 0.2408 - val_accuracy: 0.8986 - 175ms/epoch - 9ms/step
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 0.24078
# 20/20 - 0s - loss: 0.1472 - accuracy: 0.9484 - val_loss: 0.2458 - val_accuracy: 0.8986 - 63ms/epoch - 3ms/step
# Epoch 22/100
#
# Epoch 22: val_loss improved from 0.24078 to 0.21725, saving model to sdp-tree-promise-2.weights.best.keras
# 20/20 - 0s - loss: 0.1406 - accuracy: 0.9516 - val_loss: 0.2173 - val_accuracy: 0.9130 - 103ms/epoch - 5ms/step
# Epoch 23/100
#
# Epoch 23: val_loss did not improve from 0.21725
# 20/20 - 0s - loss: 0.1263 - accuracy: 0.9468 - val_loss: 0.2196 - val_accuracy: 0.9130 - 62ms/epoch - 3ms/step
# Epoch 24/100
#
# Epoch 24: val_loss improved from 0.21725 to 0.19583, saving model to sdp-tree-promise-2.weights.best.keras
# 20/20 - 0s - loss: 0.1148 - accuracy: 0.9645 - val_loss: 0.1958 - val_accuracy: 0.9130 - 98ms/epoch - 5ms/step
# Epoch 25/100
#
# Epoch 25: val_loss improved from 0.19583 to 0.19558, saving model to sdp-tree-promise-2.weights.best.keras
# 20/20 - 0s - loss: 0.1153 - accuracy: 0.9597 - val_loss: 0.1956 - val_accuracy: 0.9130 - 100ms/epoch - 5ms/step
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.19558
# 20/20 - 0s - loss: 0.1039 - accuracy: 0.9710 - val_loss: 0.1987 - val_accuracy: 0.9130 - 61ms/epoch - 3ms/step
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 0.19558
# 20/20 - 0s - loss: 0.0987 - accuracy: 0.9613 - val_loss: 0.2000 - val_accuracy: 0.9130 - 57ms/epoch - 3ms/step
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 0.19558
# 20/20 - 0s - loss: 0.0913 - accuracy: 0.9742 - val_loss: 0.2126 - val_accuracy: 0.8986 - 60ms/epoch - 3ms/step
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 0.19558
# 20/20 - 0s - loss: 0.0900 - accuracy: 0.9694 - val_loss: 0.2067 - val_accuracy: 0.9130 - 58ms/epoch - 3ms/step
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 0.19558
# 20/20 - 0s - loss: 0.1023 - accuracy: 0.9468 - val_loss: 0.2047 - val_accuracy: 0.9130 - 63ms/epoch - 3ms/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 0.19558
# 20/20 - 0s - loss: 0.0949 - accuracy: 0.9661 - val_loss: 0.1972 - val_accuracy: 0.8986 - 63ms/epoch - 3ms/step
# Epoch 32/100
#
# Epoch 32: val_loss improved from 0.19558 to 0.18769, saving model to sdp-tree-promise-2.weights.best.keras
# 20/20 - 0s - loss: 0.1012 - accuracy: 0.9629 - val_loss: 0.1877 - val_accuracy: 0.9130 - 102ms/epoch - 5ms/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 0.18769
# 20/20 - 0s - loss: 0.0987 - accuracy: 0.9565 - val_loss: 0.1916 - val_accuracy: 0.9130 - 63ms/epoch - 3ms/step
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 0.18769
# 20/20 - 0s - loss: 0.0806 - accuracy: 0.9742 - val_loss: 0.2035 - val_accuracy: 0.9130 - 57ms/epoch - 3ms/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 0.18769
# 20/20 - 0s - loss: 0.1045 - accuracy: 0.9597 - val_loss: 0.1969 - val_accuracy: 0.9130 - 59ms/epoch - 3ms/step
# Epoch 36/100
#
# Epoch 36: val_loss did not improve from 0.18769
# 20/20 - 0s - loss: 0.0892 - accuracy: 0.9710 - val_loss: 0.1916 - val_accuracy: 0.9130 - 59ms/epoch - 3ms/step
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 0.18769
# 20/20 - 0s - loss: 0.0914 - accuracy: 0.9677 - val_loss: 0.2087 - val_accuracy: 0.9130 - 59ms/epoch - 3ms/step
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 0.18769
# 20/20 - 0s - loss: 0.0932 - accuracy: 0.9677 - val_loss: 0.1981 - val_accuracy: 0.9130 - 56ms/epoch - 3ms/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 0.18769
# 20/20 - 0s - loss: 0.0819 - accuracy: 0.9758 - val_loss: 0.2081 - val_accuracy: 0.9130 - 56ms/epoch - 3ms/step
# Epoch 40/100
#
# ...
# Epoch 15/100
#
# Epoch 15: val_loss improved from 0.30292 to 0.29043, saving model to sdp-tree-promise-9.weights.best.keras
# 20/20 - 0s - loss: 0.1735 - accuracy: 0.9308 - val_loss: 0.2904 - val_accuracy: 0.8406 - 122ms/epoch - 6ms/step
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.29043
# 20/20 - 0s - loss: 0.1716 - accuracy: 0.9436 - val_loss: 0.2978 - val_accuracy: 0.8406 - 63ms/epoch - 3ms/step
# Epoch 17/100
#
# Epoch 17: val_loss improved from 0.29043 to 0.28898, saving model to sdp-tree-promise-9.weights.best.keras
# 20/20 - 0s - loss: 0.1715 - accuracy: 0.9501 - val_loss: 0.2890 - val_accuracy: 0.8551 - 111ms/epoch - 6ms/step
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 0.28898
# 20/20 - 0s - loss: 0.1494 - accuracy: 0.9501 - val_loss: 0.2892 - val_accuracy: 0.8406 - 58ms/epoch - 3ms/step
# Epoch 19/100
#
# Epoch 19: val_loss improved from 0.28898 to 0.28427, saving model to sdp-tree-promise-9.weights.best.keras
# 20/20 - 0s - loss: 0.1307 - accuracy: 0.9630 - val_loss: 0.2843 - val_accuracy: 0.8261 - 96ms/epoch - 5ms/step
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 0.28427
# 20/20 - 0s - loss: 0.1416 - accuracy: 0.9501 - val_loss: 0.2853 - val_accuracy: 0.8406 - 62ms/epoch - 3ms/step
# Epoch 21/100
#
# Epoch 21: val_loss improved from 0.28427 to 0.28249, saving model to sdp-tree-promise-9.weights.best.keras
# 20/20 - 0s - loss: 0.1227 - accuracy: 0.9646 - val_loss: 0.2825 - val_accuracy: 0.8696 - 101ms/epoch - 5ms/step
# Epoch 22/100
#
# Epoch 22: val_loss improved from 0.28249 to 0.27286, saving model to sdp-tree-promise-9.weights.best.keras
# 20/20 - 0s - loss: 0.1119 - accuracy: 0.9646 - val_loss: 0.2729 - val_accuracy: 0.8551 - 100ms/epoch - 5ms/step
# Epoch 23/100
#
# Epoch 23: val_loss improved from 0.27286 to 0.26522, saving model to sdp-tree-promise-9.weights.best.keras
# 20/20 - 0s - loss: 0.1334 - accuracy: 0.9501 - val_loss: 0.2652 - val_accuracy: 0.8551 - 103ms/epoch - 5ms/step
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 0.26522
# 20/20 - 0s - loss: 0.1183 - accuracy: 0.9597 - val_loss: 0.2741 - val_accuracy: 0.8551 - 59ms/epoch - 3ms/step
# Epoch 25/100
#
# Epoch 25: val_loss improved from 0.26522 to 0.26002, saving model to sdp-tree-promise-9.weights.best.keras
# 20/20 - 0s - loss: 0.1230 - accuracy: 0.9485 - val_loss: 0.2600 - val_accuracy: 0.8841 - 124ms/epoch - 6ms/step
# Epoch 26/100
#
# Epoch 26: val_loss improved from 0.26002 to 0.25892, saving model to sdp-tree-promise-9.weights.best.keras
# 20/20 - 0s - loss: 0.1011 - accuracy: 0.9678 - val_loss: 0.2589 - val_accuracy: 0.8841 - 124ms/epoch - 6ms/step
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 0.25892
# 20/20 - 0s - loss: 0.1002 - accuracy: 0.9646 - val_loss: 0.2742 - val_accuracy: 0.8551 - 96ms/epoch - 5ms/step
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 0.25892
# 20/20 - 0s - loss: 0.0901 - accuracy: 0.9678 - val_loss: 0.2743 - val_accuracy: 0.8696 - 57ms/epoch - 3ms/step
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 0.25892
# 20/20 - 0s - loss: 0.0924 - accuracy: 0.9662 - val_loss: 0.2870 - val_accuracy: 0.8551 - 59ms/epoch - 3ms/step
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 0.25892
# 20/20 - 0s - loss: 0.0861 - accuracy: 0.9726 - val_loss: 0.2764 - val_accuracy: 0.8841 - 62ms/epoch - 3ms/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 0.25892
# 20/20 - 0s - loss: 0.0862 - accuracy: 0.9726 - val_loss: 0.2895 - val_accuracy: 0.8551 - 62ms/epoch - 3ms/step
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 0.25892
# 20/20 - 0s - loss: 0.0843 - accuracy: 0.9742 - val_loss: 0.2886 - val_accuracy: 0.8551 - 63ms/epoch - 3ms/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 0.25892
# 20/20 - 0s - loss: 0.0848 - accuracy: 0.9726 - val_loss: 0.2774 - val_accuracy: 0.8551 - 60ms/epoch - 3ms/step
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 0.25892
# 20/20 - 0s - loss: 0.0824 - accuracy: 0.9646 - val_loss: 0.2639 - val_accuracy: 0.8551 - 61ms/epoch - 3ms/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 0.25892
# 20/20 - 0s - loss: 0.0706 - accuracy: 0.9742 - val_loss: 0.2646 - val_accuracy: 0.8841 - 57ms/epoch - 3ms/step
# Epoch 36/100
#
# Epoch 36: val_loss improved from 0.25892 to 0.25463, saving model to sdp-tree-promise-9.weights.best.keras
# 20/20 - 0s - loss: 0.0821 - accuracy: 0.9710 - val_loss: 0.2546 - val_accuracy: 0.8696 - 99ms/epoch - 5ms/step
# Epoch 37/100
#
# Epoch 37: val_loss improved from 0.25463 to 0.25416, saving model to sdp-tree-promise-9.weights.best.keras
# 20/20 - 0s - loss: 0.0722 - accuracy: 0.9742 - val_loss: 0.2542 - val_accuracy: 0.8841 - 102ms/epoch - 5ms/step
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0817 - accuracy: 0.9662 - val_loss: 0.2556 - val_accuracy: 0.8841 - 59ms/epoch - 3ms/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0763 - accuracy: 0.9791 - val_loss: 0.2561 - val_accuracy: 0.8841 - 56ms/epoch - 3ms/step
# Epoch 40/100
#
# Epoch 40: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0571 - accuracy: 0.9839 - val_loss: 0.2645 - val_accuracy: 0.8841 - 59ms/epoch - 3ms/step
# Epoch 41/100
#
# Epoch 41: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0662 - accuracy: 0.9823 - val_loss: 0.2727 - val_accuracy: 0.8841 - 56ms/epoch - 3ms/step
# Epoch 42/100
#
# Epoch 42: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0514 - accuracy: 0.9839 - val_loss: 0.2747 - val_accuracy: 0.8841 - 57ms/epoch - 3ms/step
# Epoch 43/100
#
# Epoch 43: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0644 - accuracy: 0.9758 - val_loss: 0.2697 - val_accuracy: 0.8841 - 57ms/epoch - 3ms/step
# Epoch 44/100
#
# Epoch 44: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0615 - accuracy: 0.9839 - val_loss: 0.2630 - val_accuracy: 0.8696 - 58ms/epoch - 3ms/step
# Epoch 45/100
#
# Epoch 45: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0604 - accuracy: 0.9823 - val_loss: 0.2734 - val_accuracy: 0.8696 - 57ms/epoch - 3ms/step
# Epoch 46/100
#
# Epoch 46: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0662 - accuracy: 0.9710 - val_loss: 0.2674 - val_accuracy: 0.8696 - 58ms/epoch - 3ms/step
# Epoch 47/100
#
# Epoch 47: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0665 - accuracy: 0.9694 - val_loss: 0.2570 - val_accuracy: 0.8841 - 67ms/epoch - 3ms/step
# Epoch 48/100
#
# Epoch 48: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0616 - accuracy: 0.9839 - val_loss: 0.2575 - val_accuracy: 0.8841 - 76ms/epoch - 4ms/step
# Epoch 49/100
#
# Epoch 49: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0447 - accuracy: 0.9903 - val_loss: 0.2739 - val_accuracy: 0.8841 - 87ms/epoch - 4ms/step
# Epoch 50/100
#
# Epoch 50: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0581 - accuracy: 0.9855 - val_loss: 0.2711 - val_accuracy: 0.8841 - 78ms/epoch - 4ms/step
# Epoch 51/100
#
# Epoch 51: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0569 - accuracy: 0.9823 - val_loss: 0.2653 - val_accuracy: 0.8841 - 60ms/epoch - 3ms/step
# Epoch 52/100
#
# Epoch 52: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0554 - accuracy: 0.9807 - val_loss: 0.2590 - val_accuracy: 0.8841 - 64ms/epoch - 3ms/step
# Epoch 53/100
#
# Epoch 53: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0463 - accuracy: 0.9807 - val_loss: 0.2549 - val_accuracy: 0.8841 - 67ms/epoch - 3ms/step
# Epoch 54/100
#
# Epoch 54: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0609 - accuracy: 0.9758 - val_loss: 0.2730 - val_accuracy: 0.8841 - 74ms/epoch - 4ms/step
# Epoch 55/100
#
# Epoch 55: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0558 - accuracy: 0.9823 - val_loss: 0.2872 - val_accuracy: 0.8986 - 69ms/epoch - 3ms/step
# Epoch 56/100
#
# Epoch 56: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0452 - accuracy: 0.9839 - val_loss: 0.2867 - val_accuracy: 0.8986 - 62ms/epoch - 3ms/step
# Epoch 57/100
#
# Epoch 57: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0402 - accuracy: 0.9903 - val_loss: 0.2989 - val_accuracy: 0.8986 - 98ms/epoch - 5ms/step
# Epoch 58/100
#
# Epoch 58: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0455 - accuracy: 0.9823 - val_loss: 0.3223 - val_accuracy: 0.8841 - 78ms/epoch - 4ms/step
# Epoch 59/100
#
# Epoch 59: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0377 - accuracy: 0.9903 - val_loss: 0.3258 - val_accuracy: 0.8841 - 61ms/epoch - 3ms/step
# Epoch 60/100
#
# Epoch 60: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0439 - accuracy: 0.9871 - val_loss: 0.3228 - val_accuracy: 0.8841 - 57ms/epoch - 3ms/step
# Epoch 61/100
#
# Epoch 61: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0391 - accuracy: 0.9871 - val_loss: 0.3259 - val_accuracy: 0.8841 - 63ms/epoch - 3ms/step
# Epoch 62/100
#
# Epoch 62: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0389 - accuracy: 0.9903 - val_loss: 0.3313 - val_accuracy: 0.8841 - 63ms/epoch - 3ms/step
# Epoch 63/100
#
# Epoch 63: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0464 - accuracy: 0.9791 - val_loss: 0.3459 - val_accuracy: 0.8841 - 64ms/epoch - 3ms/step
# Epoch 64/100
#
# Epoch 64: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0460 - accuracy: 0.9823 - val_loss: 0.3557 - val_accuracy: 0.8696 - 63ms/epoch - 3ms/step
# Epoch 65/100
#
# Epoch 65: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0380 - accuracy: 0.9887 - val_loss: 0.3486 - val_accuracy: 0.8696 - 62ms/epoch - 3ms/step
# Epoch 66/100
#
# Epoch 66: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0420 - accuracy: 0.9871 - val_loss: 0.3420 - val_accuracy: 0.8696 - 61ms/epoch - 3ms/step
# Epoch 67/100
#
# Epoch 67: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0354 - accuracy: 0.9887 - val_loss: 0.3380 - val_accuracy: 0.8696 - 66ms/epoch - 3ms/step
# Epoch 68/100
#
# Epoch 68: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0430 - accuracy: 0.9791 - val_loss: 0.3398 - val_accuracy: 0.8696 - 63ms/epoch - 3ms/step
# Epoch 69/100
#
# Epoch 69: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0433 - accuracy: 0.9887 - val_loss: 0.3343 - val_accuracy: 0.8696 - 61ms/epoch - 3ms/step
# Epoch 70/100
#
# Epoch 70: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0489 - accuracy: 0.9807 - val_loss: 0.3379 - val_accuracy: 0.8696 - 62ms/epoch - 3ms/step
# Epoch 71/100
#
# Epoch 71: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0336 - accuracy: 0.9903 - val_loss: 0.3226 - val_accuracy: 0.8841 - 59ms/epoch - 3ms/step
# Epoch 72/100
#
# Epoch 72: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0564 - accuracy: 0.9823 - val_loss: 0.3456 - val_accuracy: 0.8841 - 58ms/epoch - 3ms/step
# Epoch 73/100
#
# Epoch 73: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0445 - accuracy: 0.9839 - val_loss: 0.3683 - val_accuracy: 0.8841 - 56ms/epoch - 3ms/step
# Epoch 74/100
#
# Epoch 74: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0347 - accuracy: 0.9903 - val_loss: 0.3697 - val_accuracy: 0.8841 - 57ms/epoch - 3ms/step
# Epoch 75/100
#
# Epoch 75: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0374 - accuracy: 0.9855 - val_loss: 0.3685 - val_accuracy: 0.8841 - 57ms/epoch - 3ms/step
# Epoch 76/100
#
# Epoch 76: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0317 - accuracy: 0.9936 - val_loss: 0.3624 - val_accuracy: 0.8841 - 57ms/epoch - 3ms/step
# Epoch 77/100
#
# Epoch 77: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0370 - accuracy: 0.9855 - val_loss: 0.3836 - val_accuracy: 0.8841 - 55ms/epoch - 3ms/step
# Epoch 78/100
#
# Epoch 78: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0343 - accuracy: 0.9871 - val_loss: 0.4013 - val_accuracy: 0.8841 - 57ms/epoch - 3ms/step
# Epoch 79/100
#
# Epoch 79: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0385 - accuracy: 0.9823 - val_loss: 0.4123 - val_accuracy: 0.8841 - 56ms/epoch - 3ms/step
# Epoch 80/100
#
# Epoch 80: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0288 - accuracy: 0.9936 - val_loss: 0.3995 - val_accuracy: 0.8841 - 56ms/epoch - 3ms/step
# Epoch 81/100
#
# Epoch 81: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0442 - accuracy: 0.9791 - val_loss: 0.3898 - val_accuracy: 0.8841 - 57ms/epoch - 3ms/step
# Epoch 82/100
#
# Epoch 82: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0302 - accuracy: 0.9887 - val_loss: 0.3648 - val_accuracy: 0.8841 - 55ms/epoch - 3ms/step
# Epoch 83/100
#
# Epoch 83: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0414 - accuracy: 0.9839 - val_loss: 0.3886 - val_accuracy: 0.8841 - 55ms/epoch - 3ms/step
# Epoch 84/100
#
# Epoch 84: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0309 - accuracy: 0.9903 - val_loss: 0.4168 - val_accuracy: 0.8841 - 58ms/epoch - 3ms/step
# Epoch 85/100
#
# Epoch 85: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0377 - accuracy: 0.9855 - val_loss: 0.4126 - val_accuracy: 0.8841 - 55ms/epoch - 3ms/step
# Epoch 86/100
#
# Epoch 86: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0438 - accuracy: 0.9823 - val_loss: 0.4167 - val_accuracy: 0.8841 - 57ms/epoch - 3ms/step
# Epoch 87/100
#
# Epoch 87: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0295 - accuracy: 0.9855 - val_loss: 0.4071 - val_accuracy: 0.8841 - 56ms/epoch - 3ms/step
# Epoch 88/100
#
# Epoch 88: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0314 - accuracy: 0.9919 - val_loss: 0.4203 - val_accuracy: 0.8841 - 55ms/epoch - 3ms/step
# Epoch 89/100
#
# Epoch 89: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0324 - accuracy: 0.9887 - val_loss: 0.4227 - val_accuracy: 0.8841 - 67ms/epoch - 3ms/step
# Epoch 90/100
#
# Epoch 90: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0363 - accuracy: 0.9887 - val_loss: 0.4015 - val_accuracy: 0.8696 - 61ms/epoch - 3ms/step
# Epoch 91/100
#
# Epoch 91: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0350 - accuracy: 0.9871 - val_loss: 0.4057 - val_accuracy: 0.8696 - 59ms/epoch - 3ms/step
# Epoch 92/100
#
# Epoch 92: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0316 - accuracy: 0.9919 - val_loss: 0.4069 - val_accuracy: 0.8696 - 80ms/epoch - 4ms/step
# Epoch 93/100
#
# Epoch 93: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0246 - accuracy: 0.9903 - val_loss: 0.4062 - val_accuracy: 0.8696 - 57ms/epoch - 3ms/step
# Epoch 94/100
#
# Epoch 94: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0349 - accuracy: 0.9871 - val_loss: 0.3919 - val_accuracy: 0.8696 - 55ms/epoch - 3ms/step
# Epoch 95/100
#
# Epoch 95: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0311 - accuracy: 0.9855 - val_loss: 0.4043 - val_accuracy: 0.8696 - 55ms/epoch - 3ms/step
# Epoch 96/100
#
# Epoch 96: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0251 - accuracy: 0.9903 - val_loss: 0.3996 - val_accuracy: 0.8696 - 55ms/epoch - 3ms/step
# Epoch 97/100
#
# Epoch 97: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0260 - accuracy: 0.9903 - val_loss: 0.4050 - val_accuracy: 0.8696 - 57ms/epoch - 3ms/step
# Epoch 98/100
#
# Epoch 98: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0284 - accuracy: 0.9871 - val_loss: 0.4149 - val_accuracy: 0.8551 - 56ms/epoch - 3ms/step
# Epoch 99/100
#
# Epoch 99: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0358 - accuracy: 0.9871 - val_loss: 0.3960 - val_accuracy: 0.8841 - 57ms/epoch - 3ms/step
# Epoch 100/100
#
# Epoch 100: val_loss did not improve from 0.25416
# 20/20 - 0s - loss: 0.0372 - accuracy: 0.9855 - val_loss: 0.3977 - val_accuracy: 0.8841 - 55ms/epoch - 3ms/step
# 22/22 [==============================] - 0s 1ms/step
# 3/3 [==============================] - 0s 2ms/step
# Evaluate on training data
# 22/22 [==============================] - 0s 1ms/step - loss: 0.0648 - accuracy: 0.9783
# test loss, test acc: [0.06481673568487167, 0.97826087474823]
# Evaluate on test data
# 3/3 [==============================] - 0s 3ms/step - loss: 0.3076 - accuracy: 0.8816
# test loss, test acc: [0.3076133131980896, 0.8815789222717285]

# %%
dict_test_result
# Out:
#    train_accu  train_precision  train_recall  train_auc  train_f1  test_accu  \
# 0    0.989840         0.989945      0.989840   0.989851  0.989840   0.844156
# 1    0.976778         0.977855      0.976778   0.976812  0.976766   0.818182
# 2    0.981132         0.981170      0.981132   0.981138  0.981132   0.935065
# 3    0.986938         0.987144      0.986938   0.986923  0.986936   0.870130
# 4    0.988389         0.988659      0.988389   0.988372  0.988387   0.818182
# 5    0.988389         0.988541      0.988389   0.988376  0.988388   0.909091
# 6    0.985507         0.985776      0.985507   0.985507  0.985505   0.894737
# 7    0.981159         0.981500      0.981159   0.981159  0.981156   0.868421
# 8    0.988406         0.988473      0.988406   0.988406  0.988405   0.868421
# 9    0.978261         0.978769      0.978261   0.978261  0.978255   0.881579
#
#    test_precision  test_recall  test_auc   test_f1  Input  RTE
# 0        0.844156     0.844156  0.844130  0.844156     20  100
# 1        0.823825     0.818182  0.817476  0.818798     20  100
# 2        0.938036     0.935065  0.935560  0.935131     20  100
# 3        0.875703     0.870130  0.869433  0.870570     20  100
# 4        0.819409     0.818182  0.818489  0.818243     20  100
# 5        0.909459     0.909091  0.908907  0.909122     20  100
# 6        0.894737     0.894737  0.894737  0.894737     20  100
# 7        0.868421     0.868421  0.868421  0.868421     20  100
# 8        0.873961     0.868421  0.868421  0.868787     20  100
# 9        0.884695     0.881579  0.881579  0.881764     20  100

# %%
best = 8

dbfile = open('rte-tree-promise-{0}.pickle'.format(best), 'rb')    
rte = pickle.load(dbfile)
dbfile.close()

dbfile = open('manifold-tree-promise-{0}.pickle'.format(best), 'rb')    
manifold = pickle.load(dbfile)
dbfile.close()

dbfile = open('scaler-tree-promise-{0}.pickle'.format(best), 'rb')    
scaler2 = pickle.load(dbfile)
dbfile.close()

dbfile = open('sdp-classifier-tree-promise-{0}.pickle'.format(best), 'rb')    
sdp_classifier = pickle.load(dbfile)
dbfile.close()
sdp_classifier.load_weights('sdp-tree-promise-{0}.weights.best.keras'.format(best))

# %%
X_sparse_embedding = rte.transform(X_norm_scale)
X_sparse_manifold = manifold.transform(X_sparse_embedding)
X_sparse_manifold = scaler2.transform(X_sparse_manifold)
X_sparse_embedding.shape
# Out:
# (452, 118966)

# %%
X_norm_scale.shape, df.shape
# Out:
# ((452, 20), (452, 21))

# %% [raw]
# from MulticoreTSNE import MulticoreTSNE as TSNE
# tsne = TSNE(n_jobs=4, n_components=2, verbose = 1)
# Y  = tsne.fit_transform(X_sparse_manifold)
#
# #tsne = TSNE(n_jobs=4, n_components=2, verbose = 1)
# #Y  = tsne.fit_transform(encoded_train_tcga)

# %% [raw]
# tsne_ori = pd.DataFrame(Y, columns = ["tsne1", "tsne2"])
# defect = pd.DataFrame(df, columns = ["Defective"])
# tsne_ori = pd.concat([tsne_ori,defect.reset_index(drop=True)], axis = 1, sort = False)
# tsne_ori = tsne_ori.sort_values(by = "Defective")

# %% [raw]
# import plotly_express as px
#
# figx = px.scatter(
#     tsne_ori,
#     x="tsne1",
#     y="tsne2",
#     color="Defective",
#     hover_name="Defective",
#     width=970,
#     height=800,
#     template="ggplot2",
#     color_discrete_sequence= px.colors.qualitative.Alphabet,
#     #facet_col="group_label",
#     size_max=0.1,
# )
#
# figx.show()

# %%
print("Evaluate on training data")
results = sdp_classifier.evaluate([X_sparse_manifold, X_norm_scale], y, batch_size=128)
print("test loss, test acc:", results)
# Out:
# Evaluate on training data
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0831 - accuracy: 0.9735
# test loss, test acc: [0.08305399119853973, 0.9734513163566589]

# %%
from sklearn.metrics import classification_report

results = sdp_classifier.predict([X_sparse_manifold,X_norm_scale])
results=np.round(results)
print(classification_report(y,results))
# Out:
# 15/15 [==============================] - 0s 1ms/step
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.98      0.98       383
#          1.0       0.88      0.96      0.92        69
#
#     accuracy                           0.97       452
#    macro avg       0.94      0.97      0.95       452
# weighted avg       0.97      0.97      0.97       452

# %%
list_result = []

for label in my_dataset:
    dt = adjustdataset(my_dataset[label], df)
    pt, scaler, imputer, X_norm_scale_dt, y_dt = preprocessing(dt,imputer,pt, scaler, show=False)
    x_sparse_embedding_dt = rte.transform(X_norm_scale_dt)
    x_sparse_manifold_dt = manifold.transform(x_sparse_embedding_dt)
    x_sparse_manifold_dt = scaler2.transform(x_sparse_manifold_dt)
    results = sdp_classifier.predict([x_sparse_manifold_dt,X_norm_scale_dt])
    result  = np.round(results)
    fpr, tpr, thresholds = roc_curve(y_dt, result)
    list_result.append({'label':label, 'accuracy' : accuracy_score(y_dt, result),'precision':precision_score(y_dt, result, average='weighted'),
                  'recall': recall_score(y_dt, result, average='weighted'), 'auc':auc(fpr, tpr),
                        'f1-score':f1_score(y_dt, result, average='weighted')})
    #heat_map(y_dt,result,label)
# Out:
# 38/38 [==============================] - 0s 953us/step
# 18/18 [==============================] - 0s 1ms/step
# 20/20 [==============================] - 0s 1ms/step
# 24/24 [==============================] - 0s 1ms/step
# 26/26 [==============================] - 0s 1ms/step
# 45/45 [==============================] - 0s 849us/step
# 25/25 [==============================] - 0s 1ms/step
# 34/34 [==============================] - 0s 1ms/step
# 42/42 [==============================] - 0s 911us/step
# 26/26 [==============================] - 0s 1ms/step
# 18/18 [==============================] - 0s 1ms/step
# 22/22 [==============================] - 0s 2ms/step
# 26/26 [==============================] - 0s 1ms/step
# 30/30 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 1ms/step
# 24/24 [==============================] - 0s 1ms/step
# 24/24 [==============================] - 0s 1ms/step
# 26/26 [==============================] - 0s 2ms/step
# 21/21 [==============================] - 0s 2ms/step
# 19/19 [==============================] - 0s 1ms/step
# 18/18 [==============================] - 0s 1ms/step
# 25/25 [==============================] - 0s 924us/step
# 21/21 [==============================] - 0s 1ms/step
# 22/22 [==============================] - 0s 951us/step
# 28/28 [==============================] - 0s 1ms/step
# 22/22 [==============================] - 0s 1ms/step
# 24/24 [==============================] - 0s 1ms/step
# 27/27 [==============================] - 0s 1ms/step
# 23/23 [==============================] - 0s 914us/step
# 19/19 [==============================] - 0s 2ms/step
# 22/22 [==============================] - 0s 1ms/step
# 22/22 [==============================] - 0s 1ms/step
# 21/21 [==============================] - 0s 968us/step
# 21/21 [==============================] - 0s 952us/step
# 43/43 [==============================] - 0s 896us/step
# 37/37 [==============================] - 0s 911us/step
# 40/40 [==============================] - 0s 909us/step
# 42/42 [==============================] - 0s 904us/step
# 33/33 [==============================] - 0s 908us/step
# 20/20 [==============================] - 0s 1ms/step
# 28/28 [==============================] - 0s 887us/step
# 29/29 [==============================] - 0s 898us/step

# %%
df_result = pd.DataFrame(list_result)
df_result
# Out:
#            label  accuracy  precision    recall       auc  f1-score
# 0            ant  0.729097   0.808499  0.729097  0.718910  0.752866
# 1        ant_1_3  0.875000   0.909218  0.875000  0.870983  0.885035
# 2        ant_1_4  0.860095   0.884231  0.860095  0.828370  0.868143
# 3        ant_1_5  0.819892   0.899179  0.819892  0.836832  0.843012
# 4        ant_1_6  0.798005   0.842021  0.798005  0.780613  0.811603
# 5          camel  0.686441   0.769592  0.686441  0.626761  0.715856
# 6      camel_1_0  0.824051   0.918168  0.824051  0.847923  0.852972
# 7      camel_1_2  0.712937   0.721400  0.712937  0.649551  0.716746
# 8      camel_1_4  0.713530   0.809591  0.713530  0.669934  0.745931
# 9            ivy  0.838107   0.889700  0.838107  0.808720  0.855041
# 10       ivy_1_0  0.884342   0.880623  0.884342  0.814165  0.881107
# 11       ivy_1_1  0.864162   0.918650  0.864162  0.871984  0.880351
# 12       ivy_2_0  0.838107   0.889700  0.838107  0.808720  0.855041
# 13         jedit  0.786850   0.923048  0.786850  0.821169  0.830793
# 14     jedit_3_2  0.836791   0.844076  0.836791  0.782484  0.839839
# 15     jedit_4_0  0.819022   0.845163  0.819022  0.771366  0.828412
# 16     jedit_4_1  0.812582   0.838544  0.812582  0.763167  0.822003
# 17     jedit_4_2  0.801956   0.878057  0.801956  0.795445  0.825412
# 18         log4j  0.800305   0.824090  0.800305  0.754137  0.786282
# 19     log4j_1_0  0.885666   0.899041  0.885666  0.850439  0.890334
# 20     log4j_1_1  0.900000   0.907199  0.900000  0.865201  0.902645
# 21        lucene  0.773704   0.767966  0.773704  0.721867  0.765624
# 22    lucene_2_0  0.854489   0.850892  0.854489  0.790098  0.852194
# 23    lucene_2_2  0.800860   0.793836  0.800860  0.733335  0.793039
# 24           poi  0.734602   0.735802  0.734602  0.691271  0.720764
# 25       poi_1_5  0.803779   0.797926  0.803779  0.725580  0.792422
# 26       poi_2_0  0.841830   0.881280  0.841830  0.789447  0.855663
# 27       poi_2_5  0.722488   0.721768  0.722488  0.666431  0.703400
# 28       synapse  0.840170   0.855825  0.840170  0.806469  0.845713
# 29   synapse_1_0  0.853618   0.914911  0.853618  0.880430  0.870371
# 30   synapse_1_1  0.846954   0.866559  0.846954  0.807755  0.853858
# 31      velocity  0.830882   0.836706  0.830882  0.765417  0.833445
# 32  velocity_1_4  0.795981   0.793668  0.795981  0.731573  0.784725
# 33  velocity_1_5  0.809023   0.805774  0.809023  0.738645  0.798354
# 34         xalan  0.583088   0.801804  0.583088  0.694499  0.587553
# 35     xalan_2_4  0.734242   0.840497  0.734242  0.721805  0.767432
# 36     xalan_2_5  0.689793   0.686620  0.689793  0.659108  0.687972
# 37     xalan_2_6  0.712575   0.707526  0.712575  0.677435  0.709253
# 38        xerces  0.666987   0.744736  0.666987  0.658716  0.633622
# 39    xerces_1_1  0.838499   0.830004  0.838499  0.739537  0.831423
# 40    xerces_1_2  0.869809   0.872918  0.869809  0.765865  0.871269
# 41    xerces_1_3  0.973451   0.974939  0.973451  0.966512  0.973900

# %%
df_result[['accuracy','precision','recall','auc','f1-score']].mean()
# Out:
# accuracy     0.807235
# precision    0.838836
# recall       0.807235
# auc          0.769224
# f1-score     0.812375
# dtype: float64

# %%
sdp_classifier.summary()
# Out:
# Model: "model_92"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  X_train1 (InputLayer)       [(None, 100)]                0         []
#
#  X_train2 (InputLayer)       [(None, 20)]                 0         []
#
#  X_train1_layer (Dense)      (None, 64)                   6464      ['X_train1[0][0]']
#
#  X_train2_layer (Dense)      (None, 64)                   1344      ['X_train2[0][0]']
#
#  batch_normalization_184 (B  (None, 64)                   256       ['X_train1_layer[0][0]']
#  atchNormalization)
#
#  batch_normalization_185 (B  (None, 64)                   256       ['X_train2_layer[0][0]']
#  atchNormalization)
#
#  dropout_184 (Dropout)       (None, 64)                   0         ['batch_normalization_184[0][0
#                                                                     ]']
#
#  dropout_185 (Dropout)       (None, 64)                   0         ['batch_normalization_185[0][0
#                                                                     ]']
#
#  concatenate_92 (Concatenat  (None, 128)                  0         ['dropout_184[0][0]',
#  e)                                                                  'dropout_185[0][0]']
#
#  classifier (Dense)          (None, 1)                    129       ['concatenate_92[0][0]']
#
# ==================================================================================================
# Total params: 8449 (33.00 KB)
# Trainable params: 8193 (32.00 KB)
# Non-trainable params: 256 (1.00 KB)
# __________________________________________________________________________________________________

# %%
list_result = []

for label in my_dataset:
    dt = my_dataset[label]
    list_result.append({'Dataset':label, 'Instances':dt.shape[0], 'Features':dt.shape[1],
                        'Defective Instances': dt[dt['Defective'] == 'Y'].shape[0],
                        'Non-Defective Instances': dt[dt['Defective'] == 'N'].shape[0],})

# %%
df_result = pd.DataFrame(list_result)
df_result
# Out:
#          Dataset  Instances  Features  Defective Instances  \
# 0            ant        744        21                  166
# 1        ant_1_3        124        21                   20
# 2        ant_1_4        177        21                   40
# 3        ant_1_5        292        21                   31
# 4        ant_1_6        350        21                   92
# 5          camel        964        21                  188
# 6      camel_1_0        338        21                   13
# 7      camel_1_2        607        21                  216
# 8      camel_1_4        871        21                  144
# 9            ivy        351        21                   39
# 10       ivy_1_0        110        21                   63
# 11       ivy_1_1        240        21                   16
# 12       ivy_2_0        351        23                   39
# 13         jedit        491        21                   11
# 14     jedit_3_2        271        21                   90
# 15     jedit_4_0        305        21                   75
# 16     jedit_4_1        311        21                   79
# 17     jedit_4_2        366        21                   48
# 18         log4j        204        21                  188
# 19     log4j_1_0        134        21                   34
# 20     log4j_1_1        108        21                   36
# 21        lucene        339        21                  202
# 22    lucene_2_0        194        21                   91
# 23    lucene_2_2        246        21                  143
# 24           poi        441        21                  280
# 25       poi_1_5        236        21                  140
# 26       poi_2_0        313        21                   37
# 27       poi_2_5        384        21                  247
# 28       synapse        255        21                   85
# 29   synapse_1_0        156        21                   16
# 30   synapse_1_1        221        21                   60
# 31      velocity        228        21                   77
# 32  velocity_1_4        195        21                  146
# 33  velocity_1_5        213        21                  141
# 34         xalan        908        21                  897
# 35     xalan_2_4        722        21                  110
# 36     xalan_2_5        802        21                  386
# 37     xalan_2_6        884        21                  410
# 38        xerces        587        21                  436
# 39    xerces_1_1        161        21                   76
# 40    xerces_1_2        439        21                   71
# 41    xerces_1_3        452        21                   69
#
#     Non-Defective Instances
# 0                       578
# 1                       104
# 2                       137
# 3                       261
# 4                       258
# 5                       776
# 6                       325
# 7                       391
# 8                       727
# 9                       312
# 10                       47
# 11                      224
# 12                      312
# 13                      480
# 14                      181
# 15                      230
# 16                      232
# 17                      318
# 18                       16
# 19                      100
# 20                       72
# 21                      137
# 22                      103
# 23                      103
# 24                      161
# 25                       96
# 26                      276
# 27                      137
# 28                      170
# 29                      140
# 30                      161
# 31                      151
# 32                       49
# 33                       72
# 34                       11
# 35                      612
# 36                      416
# 37                      474
# 38                      151
# 39                       85
# 40                      368
# 41                      383
